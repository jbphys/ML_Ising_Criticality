# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os,pickle
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/isingdata-h5py-jb/G1_J1_data.h5py
# /kaggle/input/isingdata-h5py-jb/Gp5_data.h5py
# /kaggle/input/isingdata-h5py-jb/Gp1_data.h5py
# /kaggle/input/isingdata-h5py-jb/G1_Jp01_data.h5py
# /kaggle/input/isingdata-h5py-jb/G0_data.h5py

# %%
import os,pickle
for dirname, _, filenames in os.walk('./'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# ./__notebook__.ipynb

# %%
# Imports
import torch
import torch.nn as nn                               # to access build-in functions to build the NN
import torch.nn.functional as F                     # to access activation functions
from torchvision import datasets,transforms        # to access the MNIST dataset
import torch.optim as optim                         # to build out optimizer

import numpy as np
import matplotlib.pyplot as plt # for plotting
# %matplotlib inline
import seaborn as sns
import sklearn.metrics

torch.set_default_tensor_type(torch.cuda.FloatTensor) #This is new for CUDA

from torch.optim.lr_scheduler import ReduceLROnPlateau

# %%
#h5py data read
import h5py
f5 = h5py.File('/kaggle/input/isingdata-h5py-jb/G0_data.h5py','r')
#Tc = 2.35

# -----
f5_new = h5py.File('/kaggle/input/isingdata-h5py-jb/Gp1_data.h5py','r')
f5_new_2 = h5py.File('/kaggle/input/isingdata-h5py-jb/Gp5_data.h5py','r')
f5_new_3 = h5py.File('../input/isingdata-h5py-jb/G1_J1_data.h5py','r')
f5_new_4 = h5py.File('../input/isingdata-h5py-jb/G1_Jp01_data.h5py','r')

# %%
Ts_G_0=f5['Ts'][:]
Ts_G_0_1=f5_new['Ts'][:]
Ts_G_0_5=f5_new_2['Ts'][:]
Ts_G_1=f5_new_3['Ts'][:]
Ts_G_1_J_0=f5_new_4['Ts'][:]
#Other Targs
#Targs=np.concatenate((np.arange(1,20,1),np.where(f5['xiBs'][:]>0.12)[0],np.arange(34,61,3)))
#Tsn=np.arange(1.1,3.1,0.1)
#Targs=np.concatenate([np.where(Ts==Tn)[0] for Tn in Tsn])

Targs=np.arange(61)
Targs_new=np.arange(80)

#xiBs,labels
xiBs=f5['xiBs'][:]
factor=0.30
cut=np.amax(xiBs)*factor

labels_tmp=np.heaviside(xiBs[Targs]-cut,1.0)
labels_train=torch.tensor(np.repeat(labels_tmp,8000)) #This is new for CUDA
labels_validate=torch.tensor(np.repeat(labels_tmp,2000)) #This is new for CUDA
# labels_train=np.repeat(labels_tmp,8000)
# labels_validate=np.repeat(labels_tmp,2000)

T0,T1=Ts_G_0[np.where(labels_tmp==1.0)[0][[0,-1]]]

T0,T1
# Out:
# (2.2, 2.625)

# %% [markdown]
# ## Checking labels

# %%
print(f5['arrs'].shape)
import matplotlib.pyplot as plt 

plt.figure(dpi=150)
plt.plot(Ts_G_0[8:-9],labels_tmp[8:-9],'.-')
# plt.plot(labels_train)
plt.xticks(Ts_G_0[8:-9],rotation=90)
plt.tight_layout()
plt.grid(True)
plt.show()
# Out:
# (61, 10000, 1600)

# %%
#Alternative labels (do not run this module if you do not need it)

# factor=0.3
# cut=np.amax(xiBs)*factor
# labels_tmp=((Ts[Targs] <= 2.5) & (Ts[Targs]>=2.10)).astype(np.float32) # Arbitrty region
# #labels_tmp=np.heaviside(xiBs[Targs]-cut,1.0) # Cut region

# labels_train=np.repeat(labels_tmp,8000)
# labels_validate=np.repeat(labels_tmp,2000)
# T0,T1=Ts[np.where(labels_tmp==1.0)[0][[0,-1]]]

# plt.plot(Ts[Targs],labels_tmp)
# T0,T1

# %%
#h5py data read

data_train=f5['arrs'][Targs,:8000,:]
data_validate=f5['arrs'][Targs,8000:,:]
#labels_train=np.heaviside(xiBs[Targs]-cut,1.0)

data_train=data_train.reshape(Targs.shape[0]*8000,1600)
data_train=torch.tensor(data_train) #This is new for CUDA
data_validate=torch.tensor(data_validate) #This is new for CUDA

# # --------------------------Edited by Dileep ------------------------------------------
# data_validate_new=f5_new['arrs'][Targs,8000:,:]
# data_validate_new2=f5_new_2['arrs'][Targs,8000:,:]
# data_validate_new3=f5_new_3['arrs'][Targs_new,8000:,:]
# data_validate_new4=f5_new_4['arrs'][Targs,8000:,:]
# # -------------------------------------------------------------------------------------

# %%
# Creating the Network:
inner_dim=128
class VDNN(nn.Module):                           # nn.Module is a subclass from which we inherit
    def __init__(self,nl=6):                                     # Here you define the structure
        super(VDNN, self).__init__()
        layers=[]
        layers.append(nn.Linear(40*40, inner_dim))
        layers.append(nn.ReLU())
        for ln in range(nl-1):
            layers.append(nn.Linear(inner_dim, inner_dim))
            layers.append(nn.ReLU())
        layers.extend((nn.Linear(inner_dim,1), nn.Sigmoid()))
        self.layers = nn.Sequential(*layers)
    def forward(self,x):
        return self.layers(x)

class VDNN_one(nn.Module):                           # nn.Module is a subclass from which we inherit
    def __init__(self,nl=1):                                     # Here you define the structure
        super(VDNN_one, self).__init__()
        layers=[]
        layers.append(nn.Linear(40*40, inner_dim))
        layers.append(nn.ReLU())
        for ln in range(nl-1):
            layers.append(nn.Linear(inner_dim, inner_dim))
            layers.append(nn.ReLU())
        layers.extend((nn.Linear(inner_dim,1), nn.Sigmoid()))
        self.layers = nn.Sequential(*layers)
    def forward(self,x):
        return self.layers(x)

    

class SimpleNet(nn.Module):                           # nn.Module is a subclass from which we inherit
    def __init__(self,nl=2):                                     # Here you define the structure
        super(SimpleNet, self).__init__()
        layers=[]
        layers.extend((nn.Linear(1,inner_dim), nn.ReLU(), nn.Linear(inner_dim,1), nn.Sigmoid()))
        self.layers = nn.Sequential(*layers)
    def forward(self,x):
        return self.layers(x)
    
class VCNN(nn.Module): # A CNN based classifier
    def __init__(self):
        super(VCNN, self).__init__()
        self.cnn=m = nn.Sequential(nn.Conv2d(1,4, kernel_size=3, stride=1,padding_mode='circular'),
                  nn.BatchNorm2d(4),
                  nn.ReLU(),
                  nn.MaxPool2d(3, stride=2),
                  nn.Conv2d(4,4, kernel_size=3, stride=1,padding_mode='circular'),
                  nn.BatchNorm2d(4),
                  nn.ReLU(),
                  nn.MaxPool2d(3, stride=2)) # last outs (-1,4,7,7)
        self.classifier=nn.Sequential(nn.Linear(4*7*7,1),nn.Sigmoid())
        
    def forward(self,x):
        x=x.view(-1,40,40)
        x=x.view(-1,1,40,40) # Extra channel for CNN
        x=self.cnn(x)
        x=x.view(-1,4*7*7) # Reducing the dimension 
        x=self.classifier(x)
        return x

# %%
#Define NN and training parameters
depth=4
net=VCNN()
net.cuda()
loss_fn = nn.BCELoss(reduction='none')
count=0

losses=[]

NN_test=Targs.shape[0]*8000

model_type=type(net).__name__

# %%
#scheduler
lr=5e-6

optim_step=500


optimizer = optim.Adam(net.parameters(),lr=lr,weight_decay=0)
scheduler = ReduceLROnPlateau(optimizer,"min",patience=5)
#scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=5000, gamma=0.85)
from collections import deque
osfnames=deque()

# %%
# %%time
#------------Loss variable for each iteration-----------
Loss_epoch = []
#Loss_batch = 0
#------------
#training
net.train()
batch_size=150
is_theta=True
is_ab=False
is_shuffling=True
batch_no=np.int32(NN_test/batch_size)

shuffle_injection_frequency=50
while (count<optim_step):
    Loss_batch = 0 #for loss plot
    optimizer.zero_grad()
    NNs=torch.randperm(NN_test)
    for k in np.arange(batch_no):
        optimizer.zero_grad()
        inds = NNs[k*batch_size:(k+1)*batch_size]
        inds = inds[:batch_size]
        datas2 = data_train[inds]
        labels2 = labels_train[inds]
        
        sgn=(2*torch.bernoulli(torch.ones(batch_size)*0.5)-1).unsqueeze(-1)
        dt=torch.tensor(datas2,dtype=torch.float32)
        dt=dt*sgn
    # Adversarial 
        if is_ab:
            a,b=torch.rand(2,batch_size)
            a=0.25+2*torch.unsqueeze(a,-1)
            b=1*(torch.unsqueeze(b,-1)-0.5)
            #a,b=1,0 #no a,b
            dt=(dt*a)
            sgn=(2*torch.bernoulli(torch.ones(batch_size)*0.5)-1).unsqueeze(-1)
            dt=(dt*sgn)+b
   
    #shuffling
        if is_shuffling:
            s_inds=torch.randperm(1600)
            dt[:shuffle_injection_frequency,:]=dt[:shuffle_injection_frequency,s_inds]
            labels2[:shuffle_injection_frequency]=0
    
        #A random shift x and y
        i,j=torch.randint(40,[2])
        dt2=dt.reshape(batch_size,40,40)
        dt=torch.roll(dt2,[i,j],dims=[1,2]).reshape(batch_size,1600)

        #Training
        poutputs=net(dt)
        targets=torch.tensor(labels2,dtype=torch.float32,requires_grad=False)

        with torch.no_grad():
            w1=0.5
            wghts=(w1*targets+(1-w1)*(1-targets))
            wghts=wghts/torch.sum(wghts)
        loss_tmp=loss_fn(poutputs,torch.unsqueeze(targets,1))
        loss=torch.sum(loss_tmp.squeeze(1)*wghts)
        loss.backward()
        if k%1000==0:
            losses.append(loss.detach().cpu())
            with torch.no_grad():
                d=torch.tensor(data_validate.reshape(61*2000,1600))
                output_v=net(d)
                labels_v=torch.tensor(labels_validate)
                loss_v=loss_fn(output_v,labels_v.unsqueeze(-1))
                loss_v=torch.mean(loss_v)
            print(count,k,loss.detach().cpu(),loss_v.detach().cpu(),end='\n')
        optimizer.step()
        #------averaging loss-------
        Loss_batch += loss.detach().cpu().item()
        
    
    Loss_batch /= batch_no     
    scheduler.step(Loss_batch)
    Loss_epoch.append(Loss_batch)
    
    if count%1==0 and count>0: #Saving last five models 
        sfname="./trained_%s_%d_D_%d_%.0f"%(model_type,count,depth,100*factor)
        if is_theta:
            sfname=sfname+"_theta"
        else:
            sfname=sfname+"full_curve"
        if is_ab:
            sfname=sfname+"_ab"
        if is_shuffling:
            sfname=sfname+"_shuffling"
        sfname=sfname+".dat"
        
        if len(osfnames)>5:
            osfname=osfnames.popleft()
            if os.path.exists(osfname):
                print("Removing:%s"%osfname)
                os.remove(osfname)
            
        with open(sfname,"wb") as fl:
            print(sfname)
            pickle.dump(net.state_dict(),fl)
            pickle.dump({'T0':T0,'T1':T1,'Targs':Targs,'epochs':count,'losses':losses,'batch_size': batch_size, 'epoch_size': NN_test},fl)
            osfnames.append(sfname)
            fl.close()
    count=count+1
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:26: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:51: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:63: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:65: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# 0 0 tensor(0.8913, device='cpu') tensor(0.8414, device='cpu')
# 0 1000 tensor(0.5889, device='cpu') tensor(0.6575, device='cpu')
# 0 2000 tensor(0.5626, device='cpu') tensor(0.6506, device='cpu')
# 0 3000 tensor(0.4414, device='cpu') tensor(0.6690, device='cpu')
# 1 0 tensor(0.4972, device='cpu') tensor(0.6717, device='cpu')
# 1 1000 tensor(0.4588, device='cpu') tensor(0.6803, device='cpu')
# 1 2000 tensor(0.4622, device='cpu') tensor(0.6778, device='cpu')
# 1 3000 tensor(0.4211, device='cpu') tensor(0.6766, device='cpu')
# ./trained_VCNN_1_D_4_30_theta_shuffling.dat
# 2 0 tensor(0.4688, device='cpu') tensor(0.6746, device='cpu')
# 2 1000 tensor(0.5276, device='cpu') tensor(0.6725, device='cpu')
# 2 2000 tensor(0.4997, device='cpu') tensor(0.6674, device='cpu')
# 2 3000 tensor(0.4810, device='cpu') tensor(0.6627, device='cpu')
# ./trained_VCNN_2_D_4_30_theta_shuffling.dat
# 3 0 tensor(0.4948, device='cpu') tensor(0.6640, device='cpu')
# 3 1000 tensor(0.4040, device='cpu') tensor(0.6603, device='cpu')
# 3 2000 tensor(0.4013, device='cpu') tensor(0.6583, device='cpu')
# 3 3000 tensor(0.3793, device='cpu') tensor(0.6610, device='cpu')
# ./trained_VCNN_3_D_4_30_theta_shuffling.dat
# 4 0 tensor(0.4420, device='cpu') tensor(0.6584, device='cpu')
# 4 1000 tensor(0.3894, device='cpu') tensor(0.6696, device='cpu')
# 4 2000 tensor(0.3936, device='cpu') tensor(0.6777, device='cpu')
# 4 3000 tensor(0.4393, device='cpu') tensor(0.6890, device='cpu')
# ./trained_VCNN_4_D_4_30_theta_shuffling.dat
# 5 0 tensor(0.3586, device='cpu') tensor(0.6963, device='cpu')
# 5 1000 tensor(0.3921, device='cpu') tensor(0.7138, device='cpu')
# 5 2000 tensor(0.3148, device='cpu') tensor(0.7269, device='cpu')
# 5 3000 tensor(0.3684, device='cpu') tensor(0.7391, device='cpu')
# ./trained_VCNN_5_D_4_30_theta_shuffling.dat
# 6 0 tensor(0.3409, device='cpu') tensor(0.7396, device='cpu')
# 6 1000 tensor(0.3739, device='cpu') tensor(0.7538, device='cpu')
# 6 2000 tensor(0.3339, device='cpu') tensor(0.7699, device='cpu')
# 6 3000 tensor(0.3757, device='cpu') tensor(0.7806, device='cpu')
# ./trained_VCNN_6_D_4_30_theta_shuffling.dat
# 7 0 tensor(0.3634, device='cpu') tensor(0.7843, device='cpu')
# 7 1000 tensor(0.3710, device='cpu') tensor(0.7907, device='cpu')
# 7 2000 tensor(0.3447, device='cpu') tensor(0.8104, device='cpu')
# 7 3000 tensor(0.3740, device='cpu') tensor(0.8176, device='cpu')
# Removing:./trained_VCNN_1_D_4_30_theta_shuffling.dat
# ./trained_VCNN_7_D_4_30_theta_shuffling.dat
# 8 0 tensor(0.3591, device='cpu') tensor(0.8232, device='cpu')
# 8 1000 tensor(0.3484, device='cpu') tensor(0.8260, device='cpu')
# 8 2000 tensor(0.3111, device='cpu') tensor(0.8286, device='cpu')
# 8 3000 tensor(0.3481, device='cpu') tensor(0.8269, device='cpu')
# Removing:./trained_VCNN_2_D_4_30_theta_shuffling.dat
# ./trained_VCNN_8_D_4_30_theta_shuffling.dat
# 9 0 tensor(0.3465, device='cpu') tensor(0.8260, device='cpu')
# 9 1000 tensor(0.2705, device='cpu') tensor(0.8302, device='cpu')
# 9 2000 tensor(0.3088, device='cpu') tensor(0.8333, device='cpu')
# 9 3000 tensor(0.3040, device='cpu') tensor(0.8429, device='cpu')
# Removing:./trained_VCNN_3_D_4_30_theta_shuffling.dat
# ./trained_VCNN_9_D_4_30_theta_shuffling.dat
# 10 0 tensor(0.3107, device='cpu') tensor(0.8385, device='cpu')
# 10 1000 tensor(0.3387, device='cpu') tensor(0.8421, device='cpu')
# 10 2000 tensor(0.3378, device='cpu') tensor(0.8502, device='cpu')
# 10 3000 tensor(0.3068, device='cpu') tensor(0.8537, device='cpu')
# Removing:./trained_VCNN_4_D_4_30_theta_shuffling.dat
# ./trained_VCNN_10_D_4_30_theta_shuffling.dat
# 11 0 tensor(0.3303, device='cpu') tensor(0.8533, device='cpu')
# 11 1000 tensor(0.3060, device='cpu') tensor(0.8570, device='cpu')
# 11 2000 tensor(0.2935, device='cpu') tensor(0.8585, device='cpu')
# 11 3000 tensor(0.2904, device='cpu') tensor(0.8636, device='cpu')
# Removing:./trained_VCNN_5_D_4_30_theta_shuffling.dat
# ./trained_VCNN_11_D_4_30_theta_shuffling.dat
# 12 0 tensor(0.2800, device='cpu') tensor(0.8637, device='cpu')
# 12 1000 tensor(0.2505, device='cpu') tensor(0.8705, device='cpu')
# 12 2000 tensor(0.2888, device='cpu') tensor(0.8730, device='cpu')
# 12 3000 tensor(0.2841, device='cpu') tensor(0.8759, device='cpu')
# Removing:./trained_VCNN_6_D_4_30_theta_shuffling.dat
# ./trained_VCNN_12_D_4_30_theta_shuffling.dat
# 13 0 tensor(0.2777, device='cpu') tensor(0.8825, device='cpu')
# 13 1000 tensor(0.3154, device='cpu') tensor(0.8821, device='cpu')
# 13 2000 tensor(0.2823, device='cpu') tensor(0.8878, device='cpu')
# 13 3000 tensor(0.3041, device='cpu') tensor(0.8944, device='cpu')
# Removing:./trained_VCNN_7_D_4_30_theta_shuffling.dat
# ./trained_VCNN_13_D_4_30_theta_shuffling.dat
# 14 0 tensor(0.2958, device='cpu') tensor(0.8974, device='cpu')
# 14 1000 tensor(0.2880, device='cpu') tensor(0.8877, device='cpu')
# 14 2000 tensor(0.2871, device='cpu') tensor(0.8937, device='cpu')
# 14 3000 tensor(0.2318, device='cpu') tensor(0.9045, device='cpu')
# Removing:./trained_VCNN_8_D_4_30_theta_shuffling.dat
# ./trained_VCNN_14_D_4_30_theta_shuffling.dat
# 15 0 tensor(0.2724, device='cpu') tensor(0.9021, device='cpu')
# 15 1000 tensor(0.2718, device='cpu') tensor(0.9124, device='cpu')
# 15 2000 tensor(0.2597, device='cpu') tensor(0.9073, device='cpu')
# 15 3000 tensor(0.2949, device='cpu') tensor(0.9120, device='cpu')
# Removing:./trained_VCNN_9_D_4_30_theta_shuffling.dat
# ./trained_VCNN_15_D_4_30_theta_shuffling.dat
# 16 0 tensor(0.2940, device='cpu') tensor(0.9100, device='cpu')
# 16 1000 tensor(0.2827, device='cpu') tensor(0.9156, device='cpu')
# 16 2000 tensor(0.2482, device='cpu') tensor(0.9199, device='cpu')
# 16 3000 tensor(0.2887, device='cpu') tensor(0.9194, device='cpu')
# Removing:./trained_VCNN_10_D_4_30_theta_shuffling.dat
# ./trained_VCNN_16_D_4_30_theta_shuffling.dat
# 17 0 tensor(0.2867, device='cpu') tensor(0.9194, device='cpu')
# 17 1000 tensor(0.2645, device='cpu') tensor(0.9301, device='cpu')
# 17 2000 tensor(0.2643, device='cpu') tensor(0.9276, device='cpu')
# 17 3000 tensor(0.2644, device='cpu') tensor(0.9367, device='cpu')
# Removing:./trained_VCNN_11_D_4_30_theta_shuffling.dat
# ./trained_VCNN_17_D_4_30_theta_shuffling.dat
# 18 0 tensor(0.2613, device='cpu') tensor(0.9288, device='cpu')
# 18 1000 tensor(0.3417, device='cpu') tensor(0.9368, device='cpu')
# 18 2000 tensor(0.2490, device='cpu') tensor(0.9377, device='cpu')
# 18 3000 tensor(0.2109, device='cpu') tensor(0.9471, device='cpu')
# Removing:./trained_VCNN_12_D_4_30_theta_shuffling.dat
# ./trained_VCNN_18_D_4_30_theta_shuffling.dat
# 19 0 tensor(0.2294, device='cpu') tensor(0.9536, device='cpu')
# 19 1000 tensor(0.2422, device='cpu') tensor(0.9486, device='cpu')
# 19 2000 tensor(0.3756, device='cpu') tensor(0.9416, device='cpu')
# 19 3000 tensor(0.2541, device='cpu') tensor(0.9577, device='cpu')
# Removing:./trained_VCNN_13_D_4_30_theta_shuffling.dat
# ./trained_VCNN_19_D_4_30_theta_shuffling.dat
# 20 0 tensor(0.2452, device='cpu') tensor(0.9567, device='cpu')
# 20 1000 tensor(0.3241, device='cpu') tensor(0.9557, device='cpu')
# 20 2000 tensor(0.2485, device='cpu') tensor(0.9592, device='cpu')
# 20 3000 tensor(0.2383, device='cpu') tensor(0.9694, device='cpu')
# Removing:./trained_VCNN_14_D_4_30_theta_shuffling.dat
# ./trained_VCNN_20_D_4_30_theta_shuffling.dat
# 21 0 tensor(0.2175, device='cpu') tensor(0.9714, device='cpu')
# 21 1000 tensor(0.2849, device='cpu') tensor(0.9706, device='cpu')
# 21 2000 tensor(0.2486, device='cpu') tensor(0.9660, device='cpu')
# 21 3000 tensor(0.2295, device='cpu') tensor(0.9719, device='cpu')
# Removing:./trained_VCNN_15_D_4_30_theta_shuffling.dat
# ./trained_VCNN_21_D_4_30_theta_shuffling.dat
# 22 0 tensor(0.2082, device='cpu') tensor(0.9750, device='cpu')
# 22 1000 tensor(0.2628, device='cpu') tensor(0.9789, device='cpu')
# 22 2000 tensor(0.2538, device='cpu') tensor(0.9839, device='cpu')
# 22 3000 tensor(0.3165, device='cpu') tensor(0.9809, device='cpu')
# Removing:./trained_VCNN_16_D_4_30_theta_shuffling.dat
# ./trained_VCNN_22_D_4_30_theta_shuffling.dat
# 23 0 tensor(0.2558, device='cpu') tensor(0.9773, device='cpu')
# 23 1000 tensor(0.2429, device='cpu') tensor(0.9821, device='cpu')
# 23 2000 tensor(0.2397, device='cpu') tensor(0.9883, device='cpu')
# 23 3000 tensor(0.2545, device='cpu') tensor(0.9905, device='cpu')
# Removing:./trained_VCNN_17_D_4_30_theta_shuffling.dat
# ./trained_VCNN_23_D_4_30_theta_shuffling.dat
# 24 0 tensor(0.2396, device='cpu') tensor(0.9957, device='cpu')
# 24 1000 tensor(0.3085, device='cpu') tensor(0.9863, device='cpu')
# 24 2000 tensor(0.2462, device='cpu') tensor(0.9982, device='cpu')
# 24 3000 tensor(0.2440, device='cpu') tensor(0.9998, device='cpu')
# Removing:./trained_VCNN_18_D_4_30_theta_shuffling.dat
# ./trained_VCNN_24_D_4_30_theta_shuffling.dat
# 25 0 tensor(0.2436, device='cpu') tensor(1.0065, device='cpu')
# 25 1000 tensor(0.2633, device='cpu') tensor(1.0101, device='cpu')
# 25 2000 tensor(0.1776, device='cpu') tensor(1.0031, device='cpu')
# 25 3000 tensor(0.2413, device='cpu') tensor(1.0068, device='cpu')
# Removing:./trained_VCNN_19_D_4_30_theta_shuffling.dat
# ./trained_VCNN_25_D_4_30_theta_shuffling.dat
# 26 0 tensor(0.3048, device='cpu') tensor(1.0050, device='cpu')
# 26 1000 tensor(0.2292, device='cpu') tensor(1.0129, device='cpu')
# 26 2000 tensor(0.2516, device='cpu') tensor(1.0140, device='cpu')
# 26 3000 tensor(0.2891, device='cpu') tensor(1.0233, device='cpu')
# Removing:./trained_VCNN_20_D_4_30_theta_shuffling.dat
# ./trained_VCNN_26_D_4_30_theta_shuffling.dat
# 27 0 tensor(0.2675, device='cpu') tensor(1.0163, device='cpu')
# 27 1000 tensor(0.2179, device='cpu') tensor(1.0239, device='cpu')
# 27 2000 tensor(0.2824, device='cpu') tensor(1.0262, device='cpu')
# 27 3000 tensor(0.2376, device='cpu') tensor(1.0235, device='cpu')
# Removing:./trained_VCNN_21_D_4_30_theta_shuffling.dat
# ./trained_VCNN_27_D_4_30_theta_shuffling.dat
# 28 0 tensor(0.2223, device='cpu') tensor(1.0321, device='cpu')
# 28 1000 tensor(0.2404, device='cpu') tensor(1.0298, device='cpu')
# 28 2000 tensor(0.2341, device='cpu') tensor(1.0341, device='cpu')
# 28 3000 tensor(0.2441, device='cpu') tensor(1.0386, device='cpu')
# Removing:./trained_VCNN_22_D_4_30_theta_shuffling.dat
# ./trained_VCNN_28_D_4_30_theta_shuffling.dat
# 29 0 tensor(0.2228, device='cpu') tensor(1.0410, device='cpu')
# 29 1000 tensor(0.2571, device='cpu') tensor(1.0466, device='cpu')
# 29 2000 tensor(0.2293, device='cpu') tensor(1.0399, device='cpu')
# 29 3000 tensor(0.2146, device='cpu') tensor(1.0503, device='cpu')
# Removing:./trained_VCNN_23_D_4_30_theta_shuffling.dat
# ./trained_VCNN_29_D_4_30_theta_shuffling.dat
# 30 0 tensor(0.3089, device='cpu') tensor(1.0533, device='cpu')
# 30 1000 tensor(0.2646, device='cpu') tensor(1.0596, device='cpu')
# 30 2000 tensor(0.2094, device='cpu') tensor(1.0499, device='cpu')
# 30 3000 tensor(0.2892, device='cpu') tensor(1.0475, device='cpu')
# Removing:./trained_VCNN_24_D_4_30_theta_shuffling.dat
# ./trained_VCNN_30_D_4_30_theta_shuffling.dat
# 31 0 tensor(0.2264, device='cpu') tensor(1.0458, device='cpu')
# 31 1000 tensor(0.2487, device='cpu') tensor(1.0557, device='cpu')
# 31 2000 tensor(0.2218, device='cpu') tensor(1.0691, device='cpu')
# 31 3000 tensor(0.2377, device='cpu') tensor(1.0718, device='cpu')
# Removing:./trained_VCNN_25_D_4_30_theta_shuffling.dat
# ./trained_VCNN_31_D_4_30_theta_shuffling.dat
# 32 0 tensor(0.2415, device='cpu') tensor(1.0681, device='cpu')
# 32 1000 tensor(0.2501, device='cpu') tensor(1.0707, device='cpu')
# 32 2000 tensor(0.2298, device='cpu') tensor(1.0806, device='cpu')
# 32 3000 tensor(0.1892, device='cpu') tensor(1.0830, device='cpu')
# Removing:./trained_VCNN_26_D_4_30_theta_shuffling.dat
# ./trained_VCNN_32_D_4_30_theta_shuffling.dat
# 33 0 tensor(0.2201, device='cpu') tensor(1.0794, device='cpu')
# 33 1000 tensor(0.2504, device='cpu') tensor(1.0755, device='cpu')
# 33 2000 tensor(0.2588, device='cpu') tensor(1.0801, device='cpu')
# 33 3000 tensor(0.2231, device='cpu') tensor(1.0954, device='cpu')
# Removing:./trained_VCNN_27_D_4_30_theta_shuffling.dat
# ./trained_VCNN_33_D_4_30_theta_shuffling.dat
# 34 0 tensor(0.1805, device='cpu') tensor(1.0843, device='cpu')
# 34 1000 tensor(0.2168, device='cpu') tensor(1.0919, device='cpu')
# 34 2000 tensor(0.3014, device='cpu') tensor(1.0932, device='cpu')
# 34 3000 tensor(0.1909, device='cpu') tensor(1.0982, device='cpu')
# Removing:./trained_VCNN_28_D_4_30_theta_shuffling.dat
# ./trained_VCNN_34_D_4_30_theta_shuffling.dat
# 35 0 tensor(0.2495, device='cpu') tensor(1.0931, device='cpu')
# 35 1000 tensor(0.2690, device='cpu') tensor(1.0983, device='cpu')
# 35 2000 tensor(0.1993, device='cpu') tensor(1.0977, device='cpu')
# 35 3000 tensor(0.3038, device='cpu') tensor(1.0989, device='cpu')
# Removing:./trained_VCNN_29_D_4_30_theta_shuffling.dat
# ./trained_VCNN_35_D_4_30_theta_shuffling.dat
# 36 0 tensor(0.2052, device='cpu') tensor(1.1042, device='cpu')
# 36 1000 tensor(0.2915, device='cpu') tensor(1.1100, device='cpu')
# 36 2000 tensor(0.2397, device='cpu') tensor(1.1131, device='cpu')
# 36 3000 tensor(0.2582, device='cpu') tensor(1.1074, device='cpu')
# Removing:./trained_VCNN_30_D_4_30_theta_shuffling.dat
# ./trained_VCNN_36_D_4_30_theta_shuffling.dat
# 37 0 tensor(0.2632, device='cpu') tensor(1.1053, device='cpu')
# 37 1000 tensor(0.2173, device='cpu') tensor(1.1186, device='cpu')
# 37 2000 tensor(0.1889, device='cpu') tensor(1.1132, device='cpu')
# 37 3000 tensor(0.2227, device='cpu') tensor(1.1189, device='cpu')
# Removing:./trained_VCNN_31_D_4_30_theta_shuffling.dat
# ./trained_VCNN_37_D_4_30_theta_shuffling.dat
# 38 0 tensor(0.2361, device='cpu') tensor(1.1228, device='cpu')
# 38 1000 tensor(0.1801, device='cpu') tensor(1.1146, device='cpu')
# 38 2000 tensor(0.1765, device='cpu') tensor(1.1195, device='cpu')
# 38 3000 tensor(0.2229, device='cpu') tensor(1.1274, device='cpu')
# Removing:./trained_VCNN_32_D_4_30_theta_shuffling.dat
# ./trained_VCNN_38_D_4_30_theta_shuffling.dat
# 39 0 tensor(0.2286, device='cpu') tensor(1.1249, device='cpu')
# 39 1000 tensor(0.2229, device='cpu') tensor(1.1279, device='cpu')
# 39 2000 tensor(0.2369, device='cpu') tensor(1.1311, device='cpu')
# 39 3000 tensor(0.2385, device='cpu') tensor(1.1390, device='cpu')
# Removing:./trained_VCNN_33_D_4_30_theta_shuffling.dat
# ./trained_VCNN_39_D_4_30_theta_shuffling.dat
# 40 0 tensor(0.2469, device='cpu') tensor(1.1355, device='cpu')
# 40 1000 tensor(0.2244, device='cpu') tensor(1.1407, device='cpu')
# 40 2000 tensor(0.2307, device='cpu') tensor(1.1361, device='cpu')
# 40 3000 tensor(0.1971, device='cpu') tensor(1.1430, device='cpu')
# Removing:./trained_VCNN_34_D_4_30_theta_shuffling.dat
# ./trained_VCNN_40_D_4_30_theta_shuffling.dat
# 41 0 tensor(0.2270, device='cpu') tensor(1.1416, device='cpu')
# 41 1000 tensor(0.1597, device='cpu') tensor(1.1406, device='cpu')
# 41 2000 tensor(0.2099, device='cpu') tensor(1.1498, device='cpu')
# 41 3000 tensor(0.2715, device='cpu') tensor(1.1477, device='cpu')
# Removing:./trained_VCNN_35_D_4_30_theta_shuffling.dat
# ./trained_VCNN_41_D_4_30_theta_shuffling.dat
# 42 0 tensor(0.3103, device='cpu') tensor(1.1545, device='cpu')
# 42 1000 tensor(0.2350, device='cpu') tensor(1.1489, device='cpu')
# 42 2000 tensor(0.2533, device='cpu') tensor(1.1553, device='cpu')
# 42 3000 tensor(0.2354, device='cpu') tensor(1.1510, device='cpu')
# Removing:./trained_VCNN_36_D_4_30_theta_shuffling.dat
# ./trained_VCNN_42_D_4_30_theta_shuffling.dat
# 43 0 tensor(0.2271, device='cpu') tensor(1.1588, device='cpu')
# 43 1000 tensor(0.2250, device='cpu') tensor(1.1625, device='cpu')
# 43 2000 tensor(0.2129, device='cpu') tensor(1.1712, device='cpu')
# 43 3000 tensor(0.2365, device='cpu') tensor(1.1620, device='cpu')
# Removing:./trained_VCNN_37_D_4_30_theta_shuffling.dat
# ./trained_VCNN_43_D_4_30_theta_shuffling.dat
# 44 0 tensor(0.2158, device='cpu') tensor(1.1607, device='cpu')
# 44 1000 tensor(0.2004, device='cpu') tensor(1.1604, device='cpu')
# 44 2000 tensor(0.1977, device='cpu') tensor(1.1645, device='cpu')
# 44 3000 tensor(0.2120, device='cpu') tensor(1.1738, device='cpu')
# Removing:./trained_VCNN_38_D_4_30_theta_shuffling.dat
# ./trained_VCNN_44_D_4_30_theta_shuffling.dat
# 45 0 tensor(0.2190, device='cpu') tensor(1.1832, device='cpu')
# 45 1000 tensor(0.2097, device='cpu') tensor(1.1738, device='cpu')
# 45 2000 tensor(0.2020, device='cpu') tensor(1.1775, device='cpu')
# 45 3000 tensor(0.1787, device='cpu') tensor(1.1698, device='cpu')
# Removing:./trained_VCNN_39_D_4_30_theta_shuffling.dat
# ./trained_VCNN_45_D_4_30_theta_shuffling.dat
# 46 0 tensor(0.2145, device='cpu') tensor(1.1723, device='cpu')
# 46 1000 tensor(0.1972, device='cpu') tensor(1.1823, device='cpu')
# 46 2000 tensor(0.1880, device='cpu') tensor(1.1735, device='cpu')
# 46 3000 tensor(0.2502, device='cpu') tensor(1.1883, device='cpu')
# Removing:./trained_VCNN_40_D_4_30_theta_shuffling.dat
# ./trained_VCNN_46_D_4_30_theta_shuffling.dat
# 47 0 tensor(0.1983, device='cpu') tensor(1.1906, device='cpu')
# 47 1000 tensor(0.2503, device='cpu') tensor(1.1819, device='cpu')
# 47 2000 tensor(0.2268, device='cpu') tensor(1.1897, device='cpu')
# 47 3000 tensor(0.1674, device='cpu') tensor(1.1899, device='cpu')
# Removing:./trained_VCNN_41_D_4_30_theta_shuffling.dat
# ./trained_VCNN_47_D_4_30_theta_shuffling.dat
# 48 0 tensor(0.2848, device='cpu') tensor(1.1886, device='cpu')
# 48 1000 tensor(0.2854, device='cpu') tensor(1.1897, device='cpu')
# 48 2000 tensor(0.1813, device='cpu') tensor(1.2010, device='cpu')
# 48 3000 tensor(0.1741, device='cpu') tensor(1.1911, device='cpu')
# Removing:./trained_VCNN_42_D_4_30_theta_shuffling.dat
# ./trained_VCNN_48_D_4_30_theta_shuffling.dat
# 49 0 tensor(0.1923, device='cpu') tensor(1.1878, device='cpu')
# 49 1000 tensor(0.2342, device='cpu') tensor(1.2025, device='cpu')
# 49 2000 tensor(0.2730, device='cpu') tensor(1.1916, device='cpu')
# 49 3000 tensor(0.2025, device='cpu') tensor(1.1976, device='cpu')
# Removing:./trained_VCNN_43_D_4_30_theta_shuffling.dat
# ./trained_VCNN_49_D_4_30_theta_shuffling.dat
# 50 0 tensor(0.2573, device='cpu') tensor(1.2007, device='cpu')
# 50 1000 tensor(0.2484, device='cpu') tensor(1.2043, device='cpu')
# 50 2000 tensor(0.1682, device='cpu') tensor(1.2017, device='cpu')
# 50 3000 tensor(0.2656, device='cpu') tensor(1.2018, device='cpu')
# Removing:./trained_VCNN_44_D_4_30_theta_shuffling.dat
# ./trained_VCNN_50_D_4_30_theta_shuffling.dat
# 51 0 tensor(0.2269, device='cpu') tensor(1.2094, device='cpu')
# 51 1000 tensor(0.1893, device='cpu') tensor(1.2114, device='cpu')
# 51 2000 tensor(0.2135, device='cpu') tensor(1.2157, device='cpu')
# 51 3000 tensor(0.2186, device='cpu') tensor(1.2125, device='cpu')
# Removing:./trained_VCNN_45_D_4_30_theta_shuffling.dat
# ./trained_VCNN_51_D_4_30_theta_shuffling.dat
# 52 0 tensor(0.1933, device='cpu') tensor(1.2171, device='cpu')
# 52 1000 tensor(0.2004, device='cpu') tensor(1.2198, device='cpu')
# 52 2000 tensor(0.2232, device='cpu') tensor(1.2168, device='cpu')
# 52 3000 tensor(0.1892, device='cpu') tensor(1.2275, device='cpu')
# Removing:./trained_VCNN_46_D_4_30_theta_shuffling.dat
# ./trained_VCNN_52_D_4_30_theta_shuffling.dat
# 53 0 tensor(0.2558, device='cpu') tensor(1.2170, device='cpu')
# 53 1000 tensor(0.1777, device='cpu') tensor(1.2168, device='cpu')
# 53 2000 tensor(0.2055, device='cpu') tensor(1.2262, device='cpu')
# 53 3000 tensor(0.2231, device='cpu') tensor(1.2218, device='cpu')
# Removing:./trained_VCNN_47_D_4_30_theta_shuffling.dat
# ./trained_VCNN_53_D_4_30_theta_shuffling.dat
# 54 0 tensor(0.1312, device='cpu') tensor(1.2322, device='cpu')
# 54 1000 tensor(0.2190, device='cpu') tensor(1.2281, device='cpu')
# 54 2000 tensor(0.2140, device='cpu') tensor(1.2329, device='cpu')
# 54 3000 tensor(0.2259, device='cpu') tensor(1.2334, device='cpu')
# Removing:./trained_VCNN_48_D_4_30_theta_shuffling.dat
# ./trained_VCNN_54_D_4_30_theta_shuffling.dat
# 55 0 tensor(0.2350, device='cpu') tensor(1.2202, device='cpu')
# 55 1000 tensor(0.2863, device='cpu') tensor(1.2331, device='cpu')
# 55 2000 tensor(0.2262, device='cpu') tensor(1.2317, device='cpu')
# 55 3000 tensor(0.1766, device='cpu') tensor(1.2377, device='cpu')
# Removing:./trained_VCNN_49_D_4_30_theta_shuffling.dat
# ./trained_VCNN_55_D_4_30_theta_shuffling.dat
# 56 0 tensor(0.1671, device='cpu') tensor(1.2329, device='cpu')
# 56 1000 tensor(0.1987, device='cpu') tensor(1.2390, device='cpu')
# 56 2000 tensor(0.2256, device='cpu') tensor(1.2341, device='cpu')
# 56 3000 tensor(0.2245, device='cpu') tensor(1.2319, device='cpu')
# Removing:./trained_VCNN_50_D_4_30_theta_shuffling.dat
# ./trained_VCNN_56_D_4_30_theta_shuffling.dat
# 57 0 tensor(0.2253, device='cpu') tensor(1.2381, device='cpu')
# 57 1000 tensor(0.1978, device='cpu') tensor(1.2396, device='cpu')
# 57 2000 tensor(0.2360, device='cpu') tensor(1.2458, device='cpu')
# 57 3000 tensor(0.2291, device='cpu') tensor(1.2512, device='cpu')
# Removing:./trained_VCNN_51_D_4_30_theta_shuffling.dat
# ./trained_VCNN_57_D_4_30_theta_shuffling.dat
# 58 0 tensor(0.2362, device='cpu') tensor(1.2476, device='cpu')
# 58 1000 tensor(0.2343, device='cpu') tensor(1.2484, device='cpu')
# 58 2000 tensor(0.2842, device='cpu') tensor(1.2521, device='cpu')
# 58 3000 tensor(0.1618, device='cpu') tensor(1.2518, device='cpu')
# Removing:./trained_VCNN_52_D_4_30_theta_shuffling.dat
# ./trained_VCNN_58_D_4_30_theta_shuffling.dat
# 59 0 tensor(0.2733, device='cpu') tensor(1.2507, device='cpu')
# 59 1000 tensor(0.2684, device='cpu') tensor(1.2616, device='cpu')
# 59 2000 tensor(0.2064, device='cpu') tensor(1.2503, device='cpu')
# 59 3000 tensor(0.1638, device='cpu') tensor(1.2511, device='cpu')
# Removing:./trained_VCNN_53_D_4_30_theta_shuffling.dat
# ./trained_VCNN_59_D_4_30_theta_shuffling.dat
# 60 0 tensor(0.1645, device='cpu') tensor(1.2536, device='cpu')
# 60 1000 tensor(0.1694, device='cpu') tensor(1.2595, device='cpu')
# 60 2000 tensor(0.1934, device='cpu') tensor(1.2536, device='cpu')
# 60 3000 tensor(0.2597, device='cpu') tensor(1.2551, device='cpu')
# Removing:./trained_VCNN_54_D_4_30_theta_shuffling.dat
# ./trained_VCNN_60_D_4_30_theta_shuffling.dat
# 61 0 tensor(0.2313, device='cpu') tensor(1.2599, device='cpu')
# 61 1000 tensor(0.2219, device='cpu') tensor(1.2687, device='cpu')
# 61 2000 tensor(0.2446, device='cpu') tensor(1.2639, device='cpu')
# 61 3000 tensor(0.2028, device='cpu') tensor(1.2584, device='cpu')
# Removing:./trained_VCNN_55_D_4_30_theta_shuffling.dat
# ./trained_VCNN_61_D_4_30_theta_shuffling.dat
# 62 0 tensor(0.2306, device='cpu') tensor(1.2663, device='cpu')
# 62 1000 tensor(0.2907, device='cpu') tensor(1.2629, device='cpu')
# 62 2000 tensor(0.1651, device='cpu') tensor(1.2642, device='cpu')
# 62 3000 tensor(0.1697, device='cpu') tensor(1.2645, device='cpu')
# Removing:./trained_VCNN_56_D_4_30_theta_shuffling.dat
# ./trained_VCNN_62_D_4_30_theta_shuffling.dat
# 63 0 tensor(0.2206, device='cpu') tensor(1.2643, device='cpu')
# 63 1000 tensor(0.2237, device='cpu') tensor(1.2651, device='cpu')
# 63 2000 tensor(0.2022, device='cpu') tensor(1.2738, device='cpu')
# 63 3000 tensor(0.1976, device='cpu') tensor(1.2602, device='cpu')
# Removing:./trained_VCNN_57_D_4_30_theta_shuffling.dat
# ./trained_VCNN_63_D_4_30_theta_shuffling.dat
# 64 0 tensor(0.1629, device='cpu') tensor(1.2788, device='cpu')
# 64 1000 tensor(0.2739, device='cpu') tensor(1.2704, device='cpu')
# 64 2000 tensor(0.2680, device='cpu') tensor(1.2770, device='cpu')
# 64 3000 tensor(0.1782, device='cpu') tensor(1.2734, device='cpu')
# Removing:./trained_VCNN_58_D_4_30_theta_shuffling.dat
# ./trained_VCNN_64_D_4_30_theta_shuffling.dat
# 65 0 tensor(0.2005, device='cpu') tensor(1.2775, device='cpu')
# 65 1000 tensor(0.2343, device='cpu') tensor(1.2730, device='cpu')
# 65 2000 tensor(0.1862, device='cpu') tensor(1.2787, device='cpu')
# 65 3000 tensor(0.2121, device='cpu') tensor(1.2760, device='cpu')
# Removing:./trained_VCNN_59_D_4_30_theta_shuffling.dat
# ./trained_VCNN_65_D_4_30_theta_shuffling.dat
# 66 0 tensor(0.2406, device='cpu') tensor(1.2796, device='cpu')
# 66 1000 tensor(0.2015, device='cpu') tensor(1.2730, device='cpu')
# 66 2000 tensor(0.2069, device='cpu') tensor(1.2856, device='cpu')
# 66 3000 tensor(0.1951, device='cpu') tensor(1.2862, device='cpu')
# Removing:./trained_VCNN_60_D_4_30_theta_shuffling.dat
# ./trained_VCNN_66_D_4_30_theta_shuffling.dat
# 67 0 tensor(0.2108, device='cpu') tensor(1.2846, device='cpu')
# 67 1000 tensor(0.2156, device='cpu') tensor(1.2916, device='cpu')
# 67 2000 tensor(0.1912, device='cpu') tensor(1.2859, device='cpu')
# 67 3000 tensor(0.2364, device='cpu') tensor(1.2783, device='cpu')
# Removing:./trained_VCNN_61_D_4_30_theta_shuffling.dat
# ./trained_VCNN_67_D_4_30_theta_shuffling.dat
# 68 0 tensor(0.2116, device='cpu') tensor(1.2884, device='cpu')
# 68 1000 tensor(0.1958, device='cpu') tensor(1.2863, device='cpu')
# 68 2000 tensor(0.2614, device='cpu') tensor(1.2888, device='cpu')
# 68 3000 tensor(0.1930, device='cpu') tensor(1.2874, device='cpu')
# Removing:./trained_VCNN_62_D_4_30_theta_shuffling.dat
# ./trained_VCNN_68_D_4_30_theta_shuffling.dat
# 69 0 tensor(0.2389, device='cpu') tensor(1.2932, device='cpu')
# 69 1000 tensor(0.2083, device='cpu') tensor(1.2885, device='cpu')
# 69 2000 tensor(0.1856, device='cpu') tensor(1.2964, device='cpu')
# 69 3000 tensor(0.1670, device='cpu') tensor(1.2912, device='cpu')
# Removing:./trained_VCNN_63_D_4_30_theta_shuffling.dat
# ./trained_VCNN_69_D_4_30_theta_shuffling.dat
# 70 0 tensor(0.2207, device='cpu') tensor(1.2920, device='cpu')
# 70 1000 tensor(0.1941, device='cpu') tensor(1.2929, device='cpu')
# 70 2000 tensor(0.1839, device='cpu') tensor(1.2980, device='cpu')
# 70 3000 tensor(0.2115, device='cpu') tensor(1.2989, device='cpu')
# Removing:./trained_VCNN_64_D_4_30_theta_shuffling.dat
# ./trained_VCNN_70_D_4_30_theta_shuffling.dat
# 71 0 tensor(0.1859, device='cpu') tensor(1.2896, device='cpu')
# 71 1000 tensor(0.2766, device='cpu') tensor(1.2961, device='cpu')
# 71 2000 tensor(0.1827, device='cpu') tensor(1.2931, device='cpu')
# 71 3000 tensor(0.2751, device='cpu') tensor(1.2987, device='cpu')
# Removing:./trained_VCNN_65_D_4_30_theta_shuffling.dat
# ./trained_VCNN_71_D_4_30_theta_shuffling.dat
# 72 0 tensor(0.1798, device='cpu') tensor(1.3095, device='cpu')
# 72 1000 tensor(0.1914, device='cpu') tensor(1.2951, device='cpu')
# 72 2000 tensor(0.2565, device='cpu') tensor(1.2958, device='cpu')
# 72 3000 tensor(0.2146, device='cpu') tensor(1.3044, device='cpu')
# Removing:./trained_VCNN_66_D_4_30_theta_shuffling.dat
# ./trained_VCNN_72_D_4_30_theta_shuffling.dat
# 73 0 tensor(0.2210, device='cpu') tensor(1.3012, device='cpu')
# 73 1000 tensor(0.1845, device='cpu') tensor(1.3006, device='cpu')
# 73 2000 tensor(0.1960, device='cpu') tensor(1.3077, device='cpu')
# 73 3000 tensor(0.1931, device='cpu') tensor(1.3135, device='cpu')
# Removing:./trained_VCNN_67_D_4_30_theta_shuffling.dat
# ./trained_VCNN_73_D_4_30_theta_shuffling.dat
# 74 0 tensor(0.1634, device='cpu') tensor(1.3082, device='cpu')
# 74 1000 tensor(0.2422, device='cpu') tensor(1.3129, device='cpu')
# 74 2000 tensor(0.2271, device='cpu') tensor(1.3090, device='cpu')
# 74 3000 tensor(0.2064, device='cpu') tensor(1.2994, device='cpu')
# Removing:./trained_VCNN_68_D_4_30_theta_shuffling.dat
# ./trained_VCNN_74_D_4_30_theta_shuffling.dat
# 75 0 tensor(0.2063, device='cpu') tensor(1.3037, device='cpu')
# 75 1000 tensor(0.1900, device='cpu') tensor(1.3025, device='cpu')
# 75 2000 tensor(0.2040, device='cpu') tensor(1.3162, device='cpu')
# 75 3000 tensor(0.2819, device='cpu') tensor(1.3090, device='cpu')
# Removing:./trained_VCNN_69_D_4_30_theta_shuffling.dat
# ./trained_VCNN_75_D_4_30_theta_shuffling.dat
# 76 0 tensor(0.2032, device='cpu') tensor(1.3131, device='cpu')
# 76 1000 tensor(0.2044, device='cpu') tensor(1.3113, device='cpu')
# 76 2000 tensor(0.1954, device='cpu') tensor(1.3206, device='cpu')
# 76 3000 tensor(0.1889, device='cpu') tensor(1.3107, device='cpu')
# Removing:./trained_VCNN_70_D_4_30_theta_shuffling.dat
# ./trained_VCNN_76_D_4_30_theta_shuffling.dat
# 77 0 tensor(0.2120, device='cpu') tensor(1.3131, device='cpu')
# 77 1000 tensor(0.2091, device='cpu') tensor(1.3140, device='cpu')
# 77 2000 tensor(0.2245, device='cpu') tensor(1.3202, device='cpu')
# 77 3000 tensor(0.1990, device='cpu') tensor(1.3212, device='cpu')
# Removing:./trained_VCNN_71_D_4_30_theta_shuffling.dat
# ./trained_VCNN_77_D_4_30_theta_shuffling.dat
# 78 0 tensor(0.1557, device='cpu') tensor(1.3220, device='cpu')
# 78 1000 tensor(0.2134, device='cpu') tensor(1.3164, device='cpu')
# 78 2000 tensor(0.1864, device='cpu') tensor(1.3247, device='cpu')
# 78 3000 tensor(0.2661, device='cpu') tensor(1.3247, device='cpu')
# Removing:./trained_VCNN_72_D_4_30_theta_shuffling.dat
# ./trained_VCNN_78_D_4_30_theta_shuffling.dat
# 79 0 tensor(0.1777, device='cpu') tensor(1.3250, device='cpu')
# 79 1000 tensor(0.3397, device='cpu') tensor(1.3233, device='cpu')
# 79 2000 tensor(0.1963, device='cpu') tensor(1.3245, device='cpu')
# 79 3000 tensor(0.2324, device='cpu') tensor(1.3217, device='cpu')
# Removing:./trained_VCNN_73_D_4_30_theta_shuffling.dat
# ./trained_VCNN_79_D_4_30_theta_shuffling.dat
# 80 0 tensor(0.1854, device='cpu') tensor(1.3166, device='cpu')
# 80 1000 tensor(0.1992, device='cpu') tensor(1.3216, device='cpu')
# 80 2000 tensor(0.2560, device='cpu') tensor(1.3262, device='cpu')
# 80 3000 tensor(0.2044, device='cpu') tensor(1.3173, device='cpu')
# Removing:./trained_VCNN_74_D_4_30_theta_shuffling.dat
# ./trained_VCNN_80_D_4_30_theta_shuffling.dat
# 81 0 tensor(0.1883, device='cpu') tensor(1.3280, device='cpu')
# 81 1000 tensor(0.1578, device='cpu') tensor(1.3294, device='cpu')
# 81 2000 tensor(0.1656, device='cpu') tensor(1.3297, device='cpu')
# 81 3000 tensor(0.2050, device='cpu') tensor(1.3235, device='cpu')
# Removing:./trained_VCNN_75_D_4_30_theta_shuffling.dat
# ./trained_VCNN_81_D_4_30_theta_shuffling.dat
# 82 0 tensor(0.1700, device='cpu') tensor(1.3246, device='cpu')
# 82 1000 tensor(0.1992, device='cpu') tensor(1.3310, device='cpu')
# 82 2000 tensor(0.2550, device='cpu') tensor(1.3326, device='cpu')
# 82 3000 tensor(0.2572, device='cpu') tensor(1.3299, device='cpu')
# Removing:./trained_VCNN_76_D_4_30_theta_shuffling.dat
# ./trained_VCNN_82_D_4_30_theta_shuffling.dat
# 83 0 tensor(0.2214, device='cpu') tensor(1.3301, device='cpu')
# 83 1000 tensor(0.1707, device='cpu') tensor(1.3274, device='cpu')
# 83 2000 tensor(0.2332, device='cpu') tensor(1.3311, device='cpu')
# 83 3000 tensor(0.2254, device='cpu') tensor(1.3322, device='cpu')
# Removing:./trained_VCNN_77_D_4_30_theta_shuffling.dat
# ./trained_VCNN_83_D_4_30_theta_shuffling.dat
# 84 0 tensor(0.1911, device='cpu') tensor(1.3293, device='cpu')
# 84 1000 tensor(0.2143, device='cpu') tensor(1.3256, device='cpu')
# 84 2000 tensor(0.2192, device='cpu') tensor(1.3398, device='cpu')
# 84 3000 tensor(0.1651, device='cpu') tensor(1.3381, device='cpu')
# Removing:./trained_VCNN_78_D_4_30_theta_shuffling.dat
# ./trained_VCNN_84_D_4_30_theta_shuffling.dat
# 85 0 tensor(0.2390, device='cpu') tensor(1.3415, device='cpu')
# 85 1000 tensor(0.1696, device='cpu') tensor(1.3362, device='cpu')
# 85 2000 tensor(0.1768, device='cpu') tensor(1.3246, device='cpu')
# 85 3000 tensor(0.2168, device='cpu') tensor(1.3392, device='cpu')
# Removing:./trained_VCNN_79_D_4_30_theta_shuffling.dat
# ./trained_VCNN_85_D_4_30_theta_shuffling.dat
# 86 0 tensor(0.1762, device='cpu') tensor(1.3449, device='cpu')
# 86 1000 tensor(0.1718, device='cpu') tensor(1.3363, device='cpu')
# 86 2000 tensor(0.2200, device='cpu') tensor(1.3359, device='cpu')
# 86 3000 tensor(0.2371, device='cpu') tensor(1.3474, device='cpu')
# Removing:./trained_VCNN_80_D_4_30_theta_shuffling.dat
# ./trained_VCNN_86_D_4_30_theta_shuffling.dat
# 87 0 tensor(0.2383, device='cpu') tensor(1.3385, device='cpu')
# 87 1000 tensor(0.1825, device='cpu') tensor(1.3413, device='cpu')
# 87 2000 tensor(0.2818, device='cpu') tensor(1.3424, device='cpu')
# 87 3000 tensor(0.2210, device='cpu') tensor(1.3450, device='cpu')
# Removing:./trained_VCNN_81_D_4_30_theta_shuffling.dat
# ./trained_VCNN_87_D_4_30_theta_shuffling.dat
# 88 0 tensor(0.2176, device='cpu') tensor(1.3400, device='cpu')
# 88 1000 tensor(0.1938, device='cpu') tensor(1.3398, device='cpu')
# 88 2000 tensor(0.1810, device='cpu') tensor(1.3491, device='cpu')
# 88 3000 tensor(0.2220, device='cpu') tensor(1.3503, device='cpu')
# Removing:./trained_VCNN_82_D_4_30_theta_shuffling.dat
# ./trained_VCNN_88_D_4_30_theta_shuffling.dat
# 89 0 tensor(0.2478, device='cpu') tensor(1.3488, device='cpu')
# 89 1000 tensor(0.1460, device='cpu') tensor(1.3413, device='cpu')
# 89 2000 tensor(0.1734, device='cpu') tensor(1.3370, device='cpu')
# 89 3000 tensor(0.2026, device='cpu') tensor(1.3451, device='cpu')
# Removing:./trained_VCNN_83_D_4_30_theta_shuffling.dat
# ./trained_VCNN_89_D_4_30_theta_shuffling.dat
# 90 0 tensor(0.1836, device='cpu') tensor(1.3490, device='cpu')
# 90 1000 tensor(0.2512, device='cpu') tensor(1.3362, device='cpu')
# 90 2000 tensor(0.2238, device='cpu') tensor(1.3424, device='cpu')
# 90 3000 tensor(0.2020, device='cpu') tensor(1.3448, device='cpu')
# Removing:./trained_VCNN_84_D_4_30_theta_shuffling.dat
# ./trained_VCNN_90_D_4_30_theta_shuffling.dat
# 91 0 tensor(0.2011, device='cpu') tensor(1.3428, device='cpu')
# 91 1000 tensor(0.2157, device='cpu') tensor(1.3482, device='cpu')
# 91 2000 tensor(0.1843, device='cpu') tensor(1.3473, device='cpu')
# 91 3000 tensor(0.2245, device='cpu') tensor(1.3469, device='cpu')
# Removing:./trained_VCNN_85_D_4_30_theta_shuffling.dat
# ./trained_VCNN_91_D_4_30_theta_shuffling.dat
# 92 0 tensor(0.1959, device='cpu') tensor(1.3481, device='cpu')
# 92 1000 tensor(0.1839, device='cpu') tensor(1.3584, device='cpu')
# 92 2000 tensor(0.1756, device='cpu') tensor(1.3465, device='cpu')
# 92 3000 tensor(0.1975, device='cpu') tensor(1.3500, device='cpu')
# Removing:./trained_VCNN_86_D_4_30_theta_shuffling.dat
# ./trained_VCNN_92_D_4_30_theta_shuffling.dat
# 93 0 tensor(0.1892, device='cpu') tensor(1.3521, device='cpu')
# 93 1000 tensor(0.1655, device='cpu') tensor(1.3519, device='cpu')
# 93 2000 tensor(0.1644, device='cpu') tensor(1.3549, device='cpu')
# 93 3000 tensor(0.1803, device='cpu') tensor(1.3591, device='cpu')
# Removing:./trained_VCNN_87_D_4_30_theta_shuffling.dat
# ./trained_VCNN_93_D_4_30_theta_shuffling.dat
# 94 0 tensor(0.2241, device='cpu') tensor(1.3624, device='cpu')
# 94 1000 tensor(0.1590, device='cpu') tensor(1.3549, device='cpu')
# 94 2000 tensor(0.1895, device='cpu') tensor(1.3620, device='cpu')
# 94 3000 tensor(0.2515, device='cpu') tensor(1.3623, device='cpu')
# Removing:./trained_VCNN_88_D_4_30_theta_shuffling.dat
# ./trained_VCNN_94_D_4_30_theta_shuffling.dat
# 95 0 tensor(0.1906, device='cpu') tensor(1.3549, device='cpu')
# 95 1000 tensor(0.2257, device='cpu') tensor(1.3553, device='cpu')
# 95 2000 tensor(0.1662, device='cpu') tensor(1.3568, device='cpu')
# 95 3000 tensor(0.2473, device='cpu') tensor(1.3609, device='cpu')
# Removing:./trained_VCNN_89_D_4_30_theta_shuffling.dat
# ./trained_VCNN_95_D_4_30_theta_shuffling.dat
# 96 0 tensor(0.1874, device='cpu') tensor(1.3607, device='cpu')
# 96 1000 tensor(0.1890, device='cpu') tensor(1.3624, device='cpu')
# 96 2000 tensor(0.2172, device='cpu') tensor(1.3648, device='cpu')
# 96 3000 tensor(0.2200, device='cpu') tensor(1.3550, device='cpu')
# Removing:./trained_VCNN_90_D_4_30_theta_shuffling.dat
# ./trained_VCNN_96_D_4_30_theta_shuffling.dat
# 97 0 tensor(0.1543, device='cpu') tensor(1.3621, device='cpu')
# 97 1000 tensor(0.2116, device='cpu') tensor(1.3601, device='cpu')
# 97 2000 tensor(0.1996, device='cpu') tensor(1.3610, device='cpu')
# 97 3000 tensor(0.1708, device='cpu') tensor(1.3506, device='cpu')
# Removing:./trained_VCNN_91_D_4_30_theta_shuffling.dat
# ./trained_VCNN_97_D_4_30_theta_shuffling.dat
# 98 0 tensor(0.2052, device='cpu') tensor(1.3622, device='cpu')
# 98 1000 tensor(0.1696, device='cpu') tensor(1.3714, device='cpu')
# 98 2000 tensor(0.1476, device='cpu') tensor(1.3642, device='cpu')
# 98 3000 tensor(0.2035, device='cpu') tensor(1.3605, device='cpu')
# Removing:./trained_VCNN_92_D_4_30_theta_shuffling.dat
# ./trained_VCNN_98_D_4_30_theta_shuffling.dat
# 99 0 tensor(0.2815, device='cpu') tensor(1.3592, device='cpu')
# 99 1000 tensor(0.2361, device='cpu') tensor(1.3647, device='cpu')
# 99 2000 tensor(0.1687, device='cpu') tensor(1.3629, device='cpu')
# 99 3000 tensor(0.1654, device='cpu') tensor(1.3698, device='cpu')
# Removing:./trained_VCNN_93_D_4_30_theta_shuffling.dat
# ./trained_VCNN_99_D_4_30_theta_shuffling.dat
# 100 0 tensor(0.1275, device='cpu') tensor(1.3653, device='cpu')
# 100 1000 tensor(0.2122, device='cpu') tensor(1.3646, device='cpu')
# 100 2000 tensor(0.2442, device='cpu') tensor(1.3638, device='cpu')
# 100 3000 tensor(0.2003, device='cpu') tensor(1.3653, device='cpu')
# Removing:./trained_VCNN_94_D_4_30_theta_shuffling.dat
# ./trained_VCNN_100_D_4_30_theta_shuffling.dat
# 101 0 tensor(0.2762, device='cpu') tensor(1.3651, device='cpu')
# 101 1000 tensor(0.1755, device='cpu') tensor(1.3646, device='cpu')
# 101 2000 tensor(0.2013, device='cpu') tensor(1.3648, device='cpu')
# 101 3000 tensor(0.1742, device='cpu') tensor(1.3661, device='cpu')
# Removing:./trained_VCNN_95_D_4_30_theta_shuffling.dat
# ./trained_VCNN_101_D_4_30_theta_shuffling.dat
# 102 0 tensor(0.2103, device='cpu') tensor(1.3659, device='cpu')
# 102 1000 tensor(0.1939, device='cpu') tensor(1.3644, device='cpu')
# 102 2000 tensor(0.2036, device='cpu') tensor(1.3652, device='cpu')
# 102 3000 tensor(0.2682, device='cpu') tensor(1.3642, device='cpu')
# Removing:./trained_VCNN_96_D_4_30_theta_shuffling.dat
# ./trained_VCNN_102_D_4_30_theta_shuffling.dat
# 103 0 tensor(0.2340, device='cpu') tensor(1.3653, device='cpu')
# 103 1000 tensor(0.2215, device='cpu') tensor(1.3664, device='cpu')
# 103 2000 tensor(0.1801, device='cpu') tensor(1.3655, device='cpu')
# 103 3000 tensor(0.2275, device='cpu') tensor(1.3665, device='cpu')
# Removing:./trained_VCNN_97_D_4_30_theta_shuffling.dat
# ./trained_VCNN_103_D_4_30_theta_shuffling.dat
# 104 0 tensor(0.2341, device='cpu') tensor(1.3657, device='cpu')
# 104 1000 tensor(0.2585, device='cpu') tensor(1.3677, device='cpu')
# 104 2000 tensor(0.1833, device='cpu') tensor(1.3666, device='cpu')
# 104 3000 tensor(0.2328, device='cpu') tensor(1.3673, device='cpu')
# Removing:./trained_VCNN_98_D_4_30_theta_shuffling.dat
# ./trained_VCNN_104_D_4_30_theta_shuffling.dat
# 105 0 tensor(0.1708, device='cpu') tensor(1.3680, device='cpu')
# 105 1000 tensor(0.1842, device='cpu') tensor(1.3670, device='cpu')
# 105 2000 tensor(0.2387, device='cpu') tensor(1.3684, device='cpu')
# 105 3000 tensor(0.2192, device='cpu') tensor(1.3667, device='cpu')
# Removing:./trained_VCNN_99_D_4_30_theta_shuffling.dat
# ./trained_VCNN_105_D_4_30_theta_shuffling.dat
# 106 0 tensor(0.2266, device='cpu') tensor(1.3668, device='cpu')
# 106 1000 tensor(0.1720, device='cpu') tensor(1.3666, device='cpu')
# 106 2000 tensor(0.1773, device='cpu') tensor(1.3666, device='cpu')
# 106 3000 tensor(0.2411, device='cpu') tensor(1.3665, device='cpu')
# Removing:./trained_VCNN_100_D_4_30_theta_shuffling.dat
# ./trained_VCNN_106_D_4_30_theta_shuffling.dat
# 107 0 tensor(0.2013, device='cpu') tensor(1.3667, device='cpu')
# 107 1000 tensor(0.1987, device='cpu') tensor(1.3666, device='cpu')
# 107 2000 tensor(0.2682, device='cpu') tensor(1.3666, device='cpu')
# 107 3000 tensor(0.2303, device='cpu') tensor(1.3666, device='cpu')
# Removing:./trained_VCNN_101_D_4_30_theta_shuffling.dat
# ./trained_VCNN_107_D_4_30_theta_shuffling.dat
# 108 0 tensor(0.2498, device='cpu') tensor(1.3667, device='cpu')
# 108 1000 tensor(0.2071, device='cpu') tensor(1.3667, device='cpu')
# 108 2000 tensor(0.1685, device='cpu') tensor(1.3666, device='cpu')
# 108 3000 tensor(0.2529, device='cpu') tensor(1.3664, device='cpu')
# Removing:./trained_VCNN_102_D_4_30_theta_shuffling.dat
# ./trained_VCNN_108_D_4_30_theta_shuffling.dat
# 109 0 tensor(0.2087, device='cpu') tensor(1.3664, device='cpu')
# 109 1000 tensor(0.1511, device='cpu') tensor(1.3663, device='cpu')
# 109 2000 tensor(0.1939, device='cpu') tensor(1.3665, device='cpu')
# 109 3000 tensor(0.1865, device='cpu') tensor(1.3665, device='cpu')
# Removing:./trained_VCNN_103_D_4_30_theta_shuffling.dat
# ./trained_VCNN_109_D_4_30_theta_shuffling.dat
# 110 0 tensor(0.2059, device='cpu') tensor(1.3665, device='cpu')
# 110 1000 tensor(0.1991, device='cpu') tensor(1.3664, device='cpu')
# 110 2000 tensor(0.2037, device='cpu') tensor(1.3663, device='cpu')
# 110 3000 tensor(0.1774, device='cpu') tensor(1.3664, device='cpu')
# Removing:./trained_VCNN_104_D_4_30_theta_shuffling.dat
# ./trained_VCNN_110_D_4_30_theta_shuffling.dat
# 111 0 tensor(0.2235, device='cpu') tensor(1.3664, device='cpu')
# 111 1000 tensor(0.2468, device='cpu') tensor(1.3666, device='cpu')
# 111 2000 tensor(0.1832, device='cpu') tensor(1.3664, device='cpu')
# 111 3000 tensor(0.2041, device='cpu') tensor(1.3664, device='cpu')
# Removing:./trained_VCNN_105_D_4_30_theta_shuffling.dat
# ./trained_VCNN_111_D_4_30_theta_shuffling.dat
# 112 0 tensor(0.2023, device='cpu') tensor(1.3663, device='cpu')
# 112 1000 tensor(0.1489, device='cpu') tensor(1.3663, device='cpu')
# 112 2000 tensor(0.2041, device='cpu') tensor(1.3663, device='cpu')
# 112 3000 tensor(0.2027, device='cpu') tensor(1.3663, device='cpu')
# Removing:./trained_VCNN_106_D_4_30_theta_shuffling.dat
# ./trained_VCNN_112_D_4_30_theta_shuffling.dat
# 113 0 tensor(0.1992, device='cpu') tensor(1.3663, device='cpu')
# 113 1000 tensor(0.1854, device='cpu') tensor(1.3663, device='cpu')
# 113 2000 tensor(0.1728, device='cpu') tensor(1.3663, device='cpu')
# 113 3000 tensor(0.2041, device='cpu') tensor(1.3663, device='cpu')
# Removing:./trained_VCNN_107_D_4_30_theta_shuffling.dat
# ./trained_VCNN_113_D_4_30_theta_shuffling.dat
# 114 0 tensor(0.2457, device='cpu') tensor(1.3663, device='cpu')
# 114 1000 tensor(0.1942, device='cpu') tensor(1.3663, device='cpu')
# 114 2000 tensor(0.2324, device='cpu') tensor(1.3663, device='cpu')
# 114 3000 tensor(0.2606, device='cpu') tensor(1.3663, device='cpu')
# Removing:./trained_VCNN_108_D_4_30_theta_shuffling.dat
# ./trained_VCNN_114_D_4_30_theta_shuffling.dat
# 115 0 tensor(0.1507, device='cpu') tensor(1.3663, device='cpu')
# 115 1000 tensor(0.2282, device='cpu') tensor(1.3663, device='cpu')
# 115 2000 tensor(0.1698, device='cpu') tensor(1.3663, device='cpu')
# 115 3000 tensor(0.2497, device='cpu') tensor(1.3663, device='cpu')
# Removing:./trained_VCNN_109_D_4_30_theta_shuffling.dat
# ./trained_VCNN_115_D_4_30_theta_shuffling.dat
# 116 0 tensor(0.2366, device='cpu') tensor(1.3663, device='cpu')
# 116 1000 tensor(0.2098, device='cpu') tensor(1.3663, device='cpu')
# 116 2000 tensor(0.2115, device='cpu') tensor(1.3663, device='cpu')
# 116 3000 tensor(0.2097, device='cpu') tensor(1.3663, device='cpu')
# Removing:./trained_VCNN_110_D_4_30_theta_shuffling.dat
# ./trained_VCNN_116_D_4_30_theta_shuffling.dat
# 117 0 tensor(0.1834, device='cpu') tensor(1.3663, device='cpu')
# 117 1000 tensor(0.1787, device='cpu') tensor(1.3663, device='cpu')
# 117 2000 tensor(0.2249, device='cpu') tensor(1.3663, device='cpu')
# 117 3000 tensor(0.2292, device='cpu') tensor(1.3663, device='cpu')
# Removing:./trained_VCNN_111_D_4_30_theta_shuffling.dat
# ./trained_VCNN_117_D_4_30_theta_shuffling.dat
# 118 0 tensor(0.2190, device='cpu') tensor(1.3663, device='cpu')
# 118 1000 tensor(0.1733, device='cpu') tensor(1.3663, device='cpu')
# 118 2000 tensor(0.2209, device='cpu') tensor(1.3663, device='cpu')
# 118 3000 tensor(0.2517, device='cpu') tensor(1.3663, device='cpu')
# Removing:./trained_VCNN_112_D_4_30_theta_shuffling.dat
# ./trained_VCNN_118_D_4_30_theta_shuffling.dat
# 119 0 tensor(0.2173, device='cpu') tensor(1.3663, device='cpu')
# 119 1000 tensor(0.2024, device='cpu') tensor(1.3663, device='cpu')
# 119 2000 tensor(0.2177, device='cpu') tensor(1.3663, device='cpu')
# 119 3000 tensor(0.1922, device='cpu') tensor(1.3663, device='cpu')
# Removing:./trained_VCNN_113_D_4_30_theta_shuffling.dat
# ./trained_VCNN_119_D_4_30_theta_shuffling.dat
# 120 0 tensor(0.1746, device='cpu') tensor(1.3663, device='cpu')
# 120 1000 tensor(0.2069, device='cpu') tensor(1.3663, device='cpu')
# 120 2000 tensor(0.2080, device='cpu') tensor(1.3663, device='cpu')
# 120 3000 tensor(0.1958, device='cpu') tensor(1.3663, device='cpu')
# Removing:./trained_VCNN_114_D_4_30_theta_shuffling.dat
# ./trained_VCNN_120_D_4_30_theta_shuffling.dat
# 121 0 tensor(0.2341, device='cpu') tensor(1.3663, device='cpu')
# 121 1000 tensor(0.2326, device='cpu') tensor(1.3663, device='cpu')
# 121 2000 tensor(0.2561, device='cpu') tensor(1.3663, device='cpu')
# 121 3000 tensor(0.1966, device='cpu') tensor(1.3663, device='cpu')
# Removing:./trained_VCNN_115_D_4_30_theta_shuffling.dat
# ./trained_VCNN_121_D_4_30_theta_shuffling.dat
# 122 0 tensor(0.2433, device='cpu') tensor(1.3663, device='cpu')
# 122 1000 tensor(0.1400, device='cpu') tensor(1.3663, device='cpu')
# 122 2000 tensor(0.2016, device='cpu') tensor(1.3663, device='cpu')
# 122 3000 tensor(0.1638, device='cpu') tensor(1.3663, device='cpu')
# Removing:./trained_VCNN_116_D_4_30_theta_shuffling.dat
# ./trained_VCNN_122_D_4_30_theta_shuffling.dat
# 123 0 tensor(0.1726, device='cpu') tensor(1.3663, device='cpu')
# 123 1000 tensor(0.2286, device='cpu') tensor(1.3663, device='cpu')
# 123 2000 tensor(0.2005, device='cpu') tensor(1.3663, device='cpu')
# 123 3000 tensor(0.1865, device='cpu') tensor(1.3663, device='cpu')
# Removing:./trained_VCNN_117_D_4_30_theta_shuffling.dat
# ./trained_VCNN_123_D_4_30_theta_shuffling.dat
# 124 0 tensor(0.1690, device='cpu') tensor(1.3663, device='cpu')
# 124 1000 tensor(0.2168, device='cpu') tensor(1.3663, device='cpu')
# 124 2000 tensor(0.1748, device='cpu') tensor(1.3663, device='cpu')
# 124 3000 tensor(0.1681, device='cpu') tensor(1.3663, device='cpu')
# Removing:./trained_VCNN_118_D_4_30_theta_shuffling.dat
# ./trained_VCNN_124_D_4_30_theta_shuffling.dat
# 125 0 tensor(0.2227, device='cpu') tensor(1.3663, device='cpu')
# 125 1000 tensor(0.2049, device='cpu') tensor(1.3663, device='cpu')
# 125 2000 tensor(0.1865, device='cpu') tensor(1.3663, device='cpu')
# 125 3000 tensor(0.2053, device='cpu') tensor(1.3663, device='cpu')
# Removing:./trained_VCNN_119_D_4_30_theta_shuffling.dat
# ./trained_VCNN_125_D_4_30_theta_shuffling.dat
# 126 0 tensor(0.2378, device='cpu') tensor(1.3663, device='cpu')
# 126 1000 tensor(0.2385, device='cpu') tensor(1.3663, device='cpu')
# 126 2000 tensor(0.1849, device='cpu') tensor(1.3663, device='cpu')
# 126 3000 tensor(0.1845, device='cpu') tensor(1.3663, device='cpu')
# Removing:./trained_VCNN_120_D_4_30_theta_shuffling.dat
# ./trained_VCNN_126_D_4_30_theta_shuffling.dat
# 127 0 tensor(0.2236, device='cpu') tensor(1.3663, device='cpu')
# 127 1000 tensor(0.1362, device='cpu') tensor(1.3663, device='cpu')
# 127 2000 tensor(0.1898, device='cpu') tensor(1.3663, device='cpu')
# 127 3000 tensor(0.2304, device='cpu') tensor(1.3663, device='cpu')
# Removing:./trained_VCNN_121_D_4_30_theta_shuffling.dat
# ./trained_VCNN_127_D_4_30_theta_shuffling.dat
# 128 0 tensor(0.1518, device='cpu') tensor(1.3663, device='cpu')
# 128 1000 tensor(0.2222, device='cpu') tensor(1.3663, device='cpu')
# 128 2000 tensor(0.1843, device='cpu') tensor(1.3663, device='cpu')
# 128 3000 tensor(0.2024, device='cpu') tensor(1.3663, device='cpu')
# Removing:./trained_VCNN_122_D_4_30_theta_shuffling.dat
# ./trained_VCNN_128_D_4_30_theta_shuffling.dat
# 129 0 tensor(0.1386, device='cpu') tensor(1.3663, device='cpu')
# 129 1000 tensor(0.1770, device='cpu') tensor(1.3663, device='cpu')
# 129 2000 tensor(0.2075, device='cpu') tensor(1.3663, device='cpu')
# 129 3000 tensor(0.1925, device='cpu') tensor(1.3663, device='cpu')
# Removing:./trained_VCNN_123_D_4_30_theta_shuffling.dat
# ./trained_VCNN_129_D_4_30_theta_shuffling.dat
# 130 0 tensor(0.2066, device='cpu') tensor(1.3663, device='cpu')
# 130 1000 tensor(0.2035, device='cpu') tensor(1.3663, device='cpu')
# 130 2000 tensor(0.1722, device='cpu') tensor(1.3663, device='cpu')
# 130 3000 tensor(0.2480, device='cpu') tensor(1.3663, device='cpu')
# Removing:./trained_VCNN_124_D_4_30_theta_shuffling.dat
# ./trained_VCNN_130_D_4_30_theta_shuffling.dat
# 131 0 tensor(0.2262, device='cpu') tensor(1.3663, device='cpu')
# ...
# 456 3000 tensor(0.2806, device='cpu') tensor(1.3663, device='cpu')
# Removing:./trained_VCNN_450_D_4_30_theta_shuffling.dat
# ./trained_VCNN_456_D_4_30_theta_shuffling.dat
# 457 0 tensor(0.1955, device='cpu') tensor(1.3663, device='cpu')
# 457 1000 tensor(0.2396, device='cpu') tensor(1.3663, device='cpu')
# 457 2000 tensor(0.2112, device='cpu') tensor(1.3663, device='cpu')
# 457 3000 tensor(0.1971, device='cpu') tensor(1.3663, device='cpu')
# Removing:./trained_VCNN_451_D_4_30_theta_shuffling.dat
# ./trained_VCNN_457_D_4_30_theta_shuffling.dat
# 458 0 tensor(0.3087, device='cpu') tensor(1.3663, device='cpu')
# 458 1000 tensor(0.2524, device='cpu') tensor(1.3663, device='cpu')
# 458 2000 tensor(0.1650, device='cpu') tensor(1.3663, device='cpu')
# 458 3000 tensor(0.1855, device='cpu') tensor(1.3663, device='cpu')
# Removing:./trained_VCNN_452_D_4_30_theta_shuffling.dat
# ./trained_VCNN_458_D_4_30_theta_shuffling.dat
# 459 0 tensor(0.1956, device='cpu') tensor(1.3663, device='cpu')
# 459 1000 tensor(0.2201, device='cpu') tensor(1.3663, device='cpu')
# 459 2000 tensor(0.1838, device='cpu') tensor(1.3663, device='cpu')
# 459 3000 tensor(0.2234, device='cpu') tensor(1.3663, device='cpu')
# Removing:./trained_VCNN_453_D_4_30_theta_shuffling.dat
# ./trained_VCNN_459_D_4_30_theta_shuffling.dat
# 460 0 tensor(0.1586, device='cpu') tensor(1.3663, device='cpu')
# 460 1000 tensor(0.1707, device='cpu') tensor(1.3663, device='cpu')
# 460 2000 tensor(0.2137, device='cpu') tensor(1.3663, device='cpu')
# 460 3000 tensor(0.1903, device='cpu') tensor(1.3663, device='cpu')
# Removing:./trained_VCNN_454_D_4_30_theta_shuffling.dat
# ./trained_VCNN_460_D_4_30_theta_shuffling.dat
# 461 0 tensor(0.2204, device='cpu') tensor(1.3663, device='cpu')
# 461 1000 tensor(0.2859, device='cpu') tensor(1.3663, device='cpu')
# 461 2000 tensor(0.2141, device='cpu') tensor(1.3663, device='cpu')
# 461 3000 tensor(0.1808, device='cpu') tensor(1.3663, device='cpu')
# Removing:./trained_VCNN_455_D_4_30_theta_shuffling.dat
# ./trained_VCNN_461_D_4_30_theta_shuffling.dat
# 462 0 tensor(0.1658, device='cpu') tensor(1.3663, device='cpu')
# 462 1000 tensor(0.2863, device='cpu') tensor(1.3663, device='cpu')
# 462 2000 tensor(0.2827, device='cpu') tensor(1.3663, device='cpu')
# 462 3000 tensor(0.1950, device='cpu') tensor(1.3663, device='cpu')
# Removing:./trained_VCNN_456_D_4_30_theta_shuffling.dat
# ./trained_VCNN_462_D_4_30_theta_shuffling.dat
# 463 0 tensor(0.1973, device='cpu') tensor(1.3663, device='cpu')
# 463 1000 tensor(0.1803, device='cpu') tensor(1.3663, device='cpu')
# 463 2000 tensor(0.1770, device='cpu') tensor(1.3663, device='cpu')
# 463 3000 tensor(0.2519, device='cpu') tensor(1.3663, device='cpu')
# Removing:./trained_VCNN_457_D_4_30_theta_shuffling.dat
# ./trained_VCNN_463_D_4_30_theta_shuffling.dat
# 464 0 tensor(0.2039, device='cpu') tensor(1.3663, device='cpu')
# 464 1000 tensor(0.1669, device='cpu') tensor(1.3663, device='cpu')
# 464 2000 tensor(0.1693, device='cpu') tensor(1.3663, device='cpu')
# 464 3000 tensor(0.1175, device='cpu') tensor(1.3663, device='cpu')
# Removing:./trained_VCNN_458_D_4_30_theta_shuffling.dat
# ./trained_VCNN_464_D_4_30_theta_shuffling.dat
# 465 0 tensor(0.2102, device='cpu') tensor(1.3663, device='cpu')
# 465 1000 tensor(0.1802, device='cpu') tensor(1.3663, device='cpu')
# 465 2000 tensor(0.1537, device='cpu') tensor(1.3663, device='cpu')
# 465 3000 tensor(0.1814, device='cpu') tensor(1.3663, device='cpu')
# Removing:./trained_VCNN_459_D_4_30_theta_shuffling.dat
# ./trained_VCNN_465_D_4_30_theta_shuffling.dat
# 466 0 tensor(0.1843, device='cpu') tensor(1.3663, device='cpu')
# 466 1000 tensor(0.1830, device='cpu') tensor(1.3663, device='cpu')
# 466 2000 tensor(0.2074, device='cpu') tensor(1.3663, device='cpu')
# 466 3000 tensor(0.2280, device='cpu') tensor(1.3663, device='cpu')
# Removing:./trained_VCNN_460_D_4_30_theta_shuffling.dat
# ./trained_VCNN_466_D_4_30_theta_shuffling.dat
# 467 0 tensor(0.2387, device='cpu') tensor(1.3663, device='cpu')
# 467 1000 tensor(0.2423, device='cpu') tensor(1.3663, device='cpu')
# 467 2000 tensor(0.1857, device='cpu') tensor(1.3663, device='cpu')
# 467 3000 tensor(0.1976, device='cpu') tensor(1.3663, device='cpu')
# Removing:./trained_VCNN_461_D_4_30_theta_shuffling.dat
# ./trained_VCNN_467_D_4_30_theta_shuffling.dat
# 468 0 tensor(0.2015, device='cpu') tensor(1.3663, device='cpu')
# 468 1000 tensor(0.1999, device='cpu') tensor(1.3663, device='cpu')
# 468 2000 tensor(0.2427, device='cpu') tensor(1.3663, device='cpu')
# 468 3000 tensor(0.1918, device='cpu') tensor(1.3663, device='cpu')
# Removing:./trained_VCNN_462_D_4_30_theta_shuffling.dat
# ./trained_VCNN_468_D_4_30_theta_shuffling.dat
# 469 0 tensor(0.2400, device='cpu') tensor(1.3663, device='cpu')
# 469 1000 tensor(0.2458, device='cpu') tensor(1.3663, device='cpu')
# 469 2000 tensor(0.2019, device='cpu') tensor(1.3663, device='cpu')
# 469 3000 tensor(0.1586, device='cpu') tensor(1.3663, device='cpu')
# Removing:./trained_VCNN_463_D_4_30_theta_shuffling.dat
# ./trained_VCNN_469_D_4_30_theta_shuffling.dat
# 470 0 tensor(0.2411, device='cpu') tensor(1.3663, device='cpu')
# 470 1000 tensor(0.2495, device='cpu') tensor(1.3663, device='cpu')
# 470 2000 tensor(0.1828, device='cpu') tensor(1.3663, device='cpu')
# 470 3000 tensor(0.2034, device='cpu') tensor(1.3663, device='cpu')
# Removing:./trained_VCNN_464_D_4_30_theta_shuffling.dat
# ./trained_VCNN_470_D_4_30_theta_shuffling.dat
# 471 0 tensor(0.1657, device='cpu') tensor(1.3663, device='cpu')
# 471 1000 tensor(0.1771, device='cpu') tensor(1.3663, device='cpu')
# 471 2000 tensor(0.1947, device='cpu') tensor(1.3663, device='cpu')
# 471 3000 tensor(0.2019, device='cpu') tensor(1.3663, device='cpu')
# Removing:./trained_VCNN_465_D_4_30_theta_shuffling.dat
# ./trained_VCNN_471_D_4_30_theta_shuffling.dat
# 472 0 tensor(0.1994, device='cpu') tensor(1.3663, device='cpu')
# 472 1000 tensor(0.2520, device='cpu') tensor(1.3663, device='cpu')
# 472 2000 tensor(0.1716, device='cpu') tensor(1.3663, device='cpu')
# 472 3000 tensor(0.2038, device='cpu') tensor(1.3663, device='cpu')
# Removing:./trained_VCNN_466_D_4_30_theta_shuffling.dat
# ./trained_VCNN_472_D_4_30_theta_shuffling.dat
# 473 0 tensor(0.1384, device='cpu') tensor(1.3663, device='cpu')
# 473 1000 tensor(0.2053, device='cpu') tensor(1.3663, device='cpu')
# 473 2000 tensor(0.1812, device='cpu') tensor(1.3663, device='cpu')
# 473 3000 tensor(0.1866, device='cpu') tensor(1.3663, device='cpu')
# Removing:./trained_VCNN_467_D_4_30_theta_shuffling.dat
# ./trained_VCNN_473_D_4_30_theta_shuffling.dat
# 474 0 tensor(0.2072, device='cpu') tensor(1.3663, device='cpu')
# 474 1000 tensor(0.2007, device='cpu') tensor(1.3663, device='cpu')
# 474 2000 tensor(0.2051, device='cpu') tensor(1.3663, device='cpu')
# 474 3000 tensor(0.2091, device='cpu') tensor(1.3663, device='cpu')
# Removing:./trained_VCNN_468_D_4_30_theta_shuffling.dat
# ./trained_VCNN_474_D_4_30_theta_shuffling.dat
# 475 0 tensor(0.1648, device='cpu') tensor(1.3663, device='cpu')
# 475 1000 tensor(0.2464, device='cpu') tensor(1.3663, device='cpu')
# 475 2000 tensor(0.1938, device='cpu') tensor(1.3664, device='cpu')
# 475 3000 tensor(0.1900, device='cpu') tensor(1.3664, device='cpu')
# Removing:./trained_VCNN_469_D_4_30_theta_shuffling.dat
# ./trained_VCNN_475_D_4_30_theta_shuffling.dat
# 476 0 tensor(0.2673, device='cpu') tensor(1.3664, device='cpu')
# 476 1000 tensor(0.2388, device='cpu') tensor(1.3664, device='cpu')
# 476 2000 tensor(0.2682, device='cpu') tensor(1.3664, device='cpu')
# 476 3000 tensor(0.2646, device='cpu') tensor(1.3664, device='cpu')
# Removing:./trained_VCNN_470_D_4_30_theta_shuffling.dat
# ./trained_VCNN_476_D_4_30_theta_shuffling.dat
# 477 0 tensor(0.1491, device='cpu') tensor(1.3664, device='cpu')
# 477 1000 tensor(0.2271, device='cpu') tensor(1.3664, device='cpu')
# 477 2000 tensor(0.2318, device='cpu') tensor(1.3664, device='cpu')
# 477 3000 tensor(0.2405, device='cpu') tensor(1.3664, device='cpu')
# Removing:./trained_VCNN_471_D_4_30_theta_shuffling.dat
# ./trained_VCNN_477_D_4_30_theta_shuffling.dat
# 478 0 tensor(0.1818, device='cpu') tensor(1.3664, device='cpu')
# 478 1000 tensor(0.1909, device='cpu') tensor(1.3664, device='cpu')
# 478 2000 tensor(0.2081, device='cpu') tensor(1.3664, device='cpu')
# 478 3000 tensor(0.1799, device='cpu') tensor(1.3664, device='cpu')
# Removing:./trained_VCNN_472_D_4_30_theta_shuffling.dat
# ./trained_VCNN_478_D_4_30_theta_shuffling.dat
# 479 0 tensor(0.1611, device='cpu') tensor(1.3664, device='cpu')
# 479 1000 tensor(0.2222, device='cpu') tensor(1.3664, device='cpu')
# 479 2000 tensor(0.2234, device='cpu') tensor(1.3664, device='cpu')
# 479 3000 tensor(0.2060, device='cpu') tensor(1.3664, device='cpu')
# Removing:./trained_VCNN_473_D_4_30_theta_shuffling.dat
# ./trained_VCNN_479_D_4_30_theta_shuffling.dat
# 480 0 tensor(0.2354, device='cpu') tensor(1.3664, device='cpu')
# 480 1000 tensor(0.2122, device='cpu') tensor(1.3664, device='cpu')
# 480 2000 tensor(0.2153, device='cpu') tensor(1.3664, device='cpu')
# 480 3000 tensor(0.2202, device='cpu') tensor(1.3664, device='cpu')
# Removing:./trained_VCNN_474_D_4_30_theta_shuffling.dat
# ./trained_VCNN_480_D_4_30_theta_shuffling.dat
# 481 0 tensor(0.2099, device='cpu') tensor(1.3664, device='cpu')
# 481 1000 tensor(0.1895, device='cpu') tensor(1.3664, device='cpu')
# 481 2000 tensor(0.2689, device='cpu') tensor(1.3664, device='cpu')
# 481 3000 tensor(0.2215, device='cpu') tensor(1.3664, device='cpu')
# Removing:./trained_VCNN_475_D_4_30_theta_shuffling.dat
# ./trained_VCNN_481_D_4_30_theta_shuffling.dat
# 482 0 tensor(0.1642, device='cpu') tensor(1.3664, device='cpu')
# 482 1000 tensor(0.1709, device='cpu') tensor(1.3664, device='cpu')
# 482 2000 tensor(0.2144, device='cpu') tensor(1.3664, device='cpu')
# 482 3000 tensor(0.2104, device='cpu') tensor(1.3664, device='cpu')
# Removing:./trained_VCNN_476_D_4_30_theta_shuffling.dat
# ./trained_VCNN_482_D_4_30_theta_shuffling.dat
# 483 0 tensor(0.2422, device='cpu') tensor(1.3664, device='cpu')
# 483 1000 tensor(0.2562, device='cpu') tensor(1.3664, device='cpu')
# 483 2000 tensor(0.2280, device='cpu') tensor(1.3664, device='cpu')
# 483 3000 tensor(0.2088, device='cpu') tensor(1.3664, device='cpu')
# Removing:./trained_VCNN_477_D_4_30_theta_shuffling.dat
# ./trained_VCNN_483_D_4_30_theta_shuffling.dat
# 484 0 tensor(0.1734, device='cpu') tensor(1.3664, device='cpu')
# 484 1000 tensor(0.2521, device='cpu') tensor(1.3663, device='cpu')
# 484 2000 tensor(0.2064, device='cpu') tensor(1.3664, device='cpu')
# 484 3000 tensor(0.2346, device='cpu') tensor(1.3664, device='cpu')
# Removing:./trained_VCNN_478_D_4_30_theta_shuffling.dat
# ./trained_VCNN_484_D_4_30_theta_shuffling.dat
# 485 0 tensor(0.1935, device='cpu') tensor(1.3664, device='cpu')
# 485 1000 tensor(0.1917, device='cpu') tensor(1.3663, device='cpu')
# 485 2000 tensor(0.2324, device='cpu') tensor(1.3663, device='cpu')
# 485 3000 tensor(0.1891, device='cpu') tensor(1.3664, device='cpu')
# Removing:./trained_VCNN_479_D_4_30_theta_shuffling.dat
# ./trained_VCNN_485_D_4_30_theta_shuffling.dat
# 486 0 tensor(0.1674, device='cpu') tensor(1.3664, device='cpu')
# 486 1000 tensor(0.2161, device='cpu') tensor(1.3664, device='cpu')
# 486 2000 tensor(0.1829, device='cpu') tensor(1.3664, device='cpu')
# 486 3000 tensor(0.2147, device='cpu') tensor(1.3664, device='cpu')
# Removing:./trained_VCNN_480_D_4_30_theta_shuffling.dat
# ./trained_VCNN_486_D_4_30_theta_shuffling.dat
# 487 0 tensor(0.1906, device='cpu') tensor(1.3664, device='cpu')
# 487 1000 tensor(0.1974, device='cpu') tensor(1.3664, device='cpu')
# 487 2000 tensor(0.1803, device='cpu') tensor(1.3664, device='cpu')
# 487 3000 tensor(0.2165, device='cpu') tensor(1.3664, device='cpu')
# Removing:./trained_VCNN_481_D_4_30_theta_shuffling.dat
# ./trained_VCNN_487_D_4_30_theta_shuffling.dat
# 488 0 tensor(0.2261, device='cpu') tensor(1.3664, device='cpu')
# 488 1000 tensor(0.2198, device='cpu') tensor(1.3664, device='cpu')
# 488 2000 tensor(0.1733, device='cpu') tensor(1.3664, device='cpu')
# 488 3000 tensor(0.2192, device='cpu') tensor(1.3664, device='cpu')
# Removing:./trained_VCNN_482_D_4_30_theta_shuffling.dat
# ./trained_VCNN_488_D_4_30_theta_shuffling.dat
# 489 0 tensor(0.1975, device='cpu') tensor(1.3664, device='cpu')
# 489 1000 tensor(0.1719, device='cpu') tensor(1.3664, device='cpu')
# 489 2000 tensor(0.2282, device='cpu') tensor(1.3664, device='cpu')
# 489 3000 tensor(0.1729, device='cpu') tensor(1.3664, device='cpu')
# Removing:./trained_VCNN_483_D_4_30_theta_shuffling.dat
# ./trained_VCNN_489_D_4_30_theta_shuffling.dat
# 490 0 tensor(0.1431, device='cpu') tensor(1.3664, device='cpu')
# 490 1000 tensor(0.2190, device='cpu') tensor(1.3664, device='cpu')
# 490 2000 tensor(0.2226, device='cpu') tensor(1.3664, device='cpu')
# 490 3000 tensor(0.1869, device='cpu') tensor(1.3664, device='cpu')
# Removing:./trained_VCNN_484_D_4_30_theta_shuffling.dat
# ./trained_VCNN_490_D_4_30_theta_shuffling.dat
# 491 0 tensor(0.1906, device='cpu') tensor(1.3664, device='cpu')
# 491 1000 tensor(0.1755, device='cpu') tensor(1.3664, device='cpu')
# 491 2000 tensor(0.1748, device='cpu') tensor(1.3664, device='cpu')
# 491 3000 tensor(0.2392, device='cpu') tensor(1.3664, device='cpu')
# Removing:./trained_VCNN_485_D_4_30_theta_shuffling.dat
# ./trained_VCNN_491_D_4_30_theta_shuffling.dat
# 492 0 tensor(0.2161, device='cpu') tensor(1.3663, device='cpu')
# 492 1000 tensor(0.2529, device='cpu') tensor(1.3663, device='cpu')
# 492 2000 tensor(0.2315, device='cpu') tensor(1.3663, device='cpu')
# 492 3000 tensor(0.2408, device='cpu') tensor(1.3664, device='cpu')
# Removing:./trained_VCNN_486_D_4_30_theta_shuffling.dat
# ./trained_VCNN_492_D_4_30_theta_shuffling.dat
# 493 0 tensor(0.1512, device='cpu') tensor(1.3664, device='cpu')
# 493 1000 tensor(0.2687, device='cpu') tensor(1.3664, device='cpu')
# 493 2000 tensor(0.2210, device='cpu') tensor(1.3664, device='cpu')
# 493 3000 tensor(0.2164, device='cpu') tensor(1.3664, device='cpu')
# Removing:./trained_VCNN_487_D_4_30_theta_shuffling.dat
# ./trained_VCNN_493_D_4_30_theta_shuffling.dat
# 494 0 tensor(0.1992, device='cpu') tensor(1.3664, device='cpu')
# 494 1000 tensor(0.2331, device='cpu') tensor(1.3664, device='cpu')
# 494 2000 tensor(0.1762, device='cpu') tensor(1.3664, device='cpu')
# 494 3000 tensor(0.1783, device='cpu') tensor(1.3664, device='cpu')
# Removing:./trained_VCNN_488_D_4_30_theta_shuffling.dat
# ./trained_VCNN_494_D_4_30_theta_shuffling.dat
# 495 0 tensor(0.2395, device='cpu') tensor(1.3664, device='cpu')
# 495 1000 tensor(0.2351, device='cpu') tensor(1.3664, device='cpu')
# 495 2000 tensor(0.1984, device='cpu') tensor(1.3664, device='cpu')
# 495 3000 tensor(0.1837, device='cpu') tensor(1.3664, device='cpu')
# Removing:./trained_VCNN_489_D_4_30_theta_shuffling.dat
# ./trained_VCNN_495_D_4_30_theta_shuffling.dat
# 496 0 tensor(0.1572, device='cpu') tensor(1.3664, device='cpu')
# 496 1000 tensor(0.3153, device='cpu') tensor(1.3664, device='cpu')
# 496 2000 tensor(0.2179, device='cpu') tensor(1.3664, device='cpu')
# 496 3000 tensor(0.2341, device='cpu') tensor(1.3664, device='cpu')
# Removing:./trained_VCNN_490_D_4_30_theta_shuffling.dat
# ./trained_VCNN_496_D_4_30_theta_shuffling.dat
# 497 0 tensor(0.1457, device='cpu') tensor(1.3664, device='cpu')
# 497 1000 tensor(0.2026, device='cpu') tensor(1.3664, device='cpu')
# 497 2000 tensor(0.2179, device='cpu') tensor(1.3664, device='cpu')
# 497 3000 tensor(0.2076, device='cpu') tensor(1.3664, device='cpu')
# Removing:./trained_VCNN_491_D_4_30_theta_shuffling.dat
# ./trained_VCNN_497_D_4_30_theta_shuffling.dat
# 498 0 tensor(0.1978, device='cpu') tensor(1.3664, device='cpu')
# 498 1000 tensor(0.1826, device='cpu') tensor(1.3664, device='cpu')
# 498 2000 tensor(0.1998, device='cpu') tensor(1.3664, device='cpu')
# 498 3000 tensor(0.1681, device='cpu') tensor(1.3664, device='cpu')
# Removing:./trained_VCNN_492_D_4_30_theta_shuffling.dat
# ./trained_VCNN_498_D_4_30_theta_shuffling.dat
# 499 0 tensor(0.2264, device='cpu') tensor(1.3664, device='cpu')
# 499 1000 tensor(0.2225, device='cpu') tensor(1.3664, device='cpu')
# 499 2000 tensor(0.2204, device='cpu') tensor(1.3664, device='cpu')
# 499 3000 tensor(0.1621, device='cpu') tensor(1.3664, device='cpu')
# Removing:./trained_VCNN_493_D_4_30_theta_shuffling.dat
# ./trained_VCNN_499_D_4_30_theta_shuffling.dat
# CPU times: user 2h 29min 59s, sys: 2min 41s, total: 2h 32min 41s
# Wall time: 2h 33min 7s

# %%
import scipy
sns.set_style("whitegrid")
plt.figure
plt.plot(Loss_epoch,".")
plt.ylabel("Training Loss")
plt.xlabel("epoch")
x_val=np.linspace(0,np.size(Loss_epoch)-1,np.size(Loss_epoch))
y_val=Loss_epoch
int_fnc = scipy.interpolate.make_interp_spline(x_val,y_val)
x_new = np.linspace(0,np.size(Loss_epoch)-1, np.size(Loss_epoch)*10)
y_new = int_fnc(x_new)
plt.plot(x_new,y_new,"--")
plt.show()

# %% [markdown]
# ## G=0 Testing

# %%
#Plot the output
outputs=[]
outputs_01=[]
outputs2=[]
net.eval()
with torch.no_grad():
    for i in torch.arange(Targs.shape[0]):
        d=data_validate[i,:,:]
        output=net(torch.tensor(d,dtype=torch.float32))
        output_01=(output>0.5)
        outputs_01.append(output_01.squeeze().detach().cpu().numpy())
        shfl=np.random.permutation(np.arange(1600))
        output2=net(torch.tensor(d[:,shfl],dtype=torch.float32))
        outputs.append(output.squeeze().detach().cpu().numpy())
        outputs2.append(output2.squeeze().detach().cpu().numpy())
    
#plt.plot(outputs.squeeze(),"o",alpha=0.02,color='red')
#plt.plot(labels_validate)
#depth=6
sns.set_style("whitegrid")
mu=np.average(np.fabs(np.average(data_validate[:,:2000,:].cpu(),axis=2)),axis=1)
outputs=np.array(outputs)
outputs2=np.array(outputs2)
Tsn=Ts_G_0[Targs]
ax=plt.axes()

ax.scatter(np.repeat(Tsn,2000),np.concatenate(outputs),alpha=0.002,s=8.0,color='springgreen')

#plt.plot(Tsn,labels_tmp,"g.--")
ax.plot(Tsn,mu,"r--",alpha=0.4,label="\mu")
#plt.plot(Tsn,np.average(outputs,axis=1),"o-",markersize=4,color='darkgreen')
ax.plot(Tsn,np.average(outputs_01,axis=1),"o-",markersize=4,color='darkgreen',label='Model output')
T0,T1=Tsn[np.where(labels_tmp==1.0)[0][[0,-1]]]
ax.vlines(T0,0,1,color='magenta',linestyle='dashed')
ax.vlines(T1,0,1,color='magenta',linestyle='dashed')
ax.plot(Tsn,np.average(outputs2,axis=1),"*-",color='purple',label='Model output shuffled')
#plt.plot(Ts,probs)
# ax.plot(Tc,mu_avc,"r",alpha=0.4) # Ask Pallab - what is mu_avc

#plt.legend(loc="upper right")/
handles, labels = ax.get_legend_handles_labels()
plt.savefig("%s_testdata_g0.pdf"%(sfname[:-4]),dpi=300)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:9: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   if __name__ == '__main__':
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   del sys.path[0]

# %% [markdown]
# ## G = 0.1 Testing

# %%
# --------------------------Edited by Dileep ------------------------------------------
data_validate_new=f5_new['arrs'][Targs,8000:,:]
data_validate_new=torch.tensor(data_validate_new) #This is new for CUDA
# -------------------------------------------------------------------------------------


#---------------------------Critical region for G=0.1 ------------------
#xiBs,labels
xiBs=f5_new['xiBs'][:]
factor=0.30
cut=np.amax(xiBs)*factor

labels_tmp=np.heaviside(xiBs[Targs]-cut,1.0)
labels_train=torch.tensor(np.repeat(labels_tmp,8000)) #This is new for CUDA
labels_validate=torch.tensor(np.repeat(labels_tmp,2000)) #This is new for CUDA
# labels_train=np.repeat(labels_tmp,8000)
# labels_validate=np.repeat(labels_tmp,2000)

T0,T1=Ts_G_0_1[np.where(labels_tmp==1.0)[0][[0,-1]]]
#---------------------

#Plot the output
outputs=[]
outputs_01=[]
outputs2=[]
net.eval()
with torch.no_grad():
    for i in torch.arange(Targs.shape[0]):
        d=data_validate_new[i,:,:]
        output=net(torch.tensor(d,dtype=torch.float32))
        output_01=(output>0.5)
        outputs_01.append(output_01.squeeze().detach().cpu().numpy())
        shfl=np.random.permutation(np.arange(1600))
        output2=net(torch.tensor(d[:,shfl],dtype=torch.float32))
        outputs.append(output.squeeze().detach().cpu().numpy())
        outputs2.append(output2.squeeze().detach().cpu().numpy())
    
#plt.plot(outputs.squeeze(),"o",alpha=0.02,color='red')
#plt.plot(labels_validate)
#depth=6
sns.set_style("whitegrid")
mu=np.average(np.fabs(np.average(data_validate_new[:,:2000,:].cpu(),axis=2)),axis=1)
outputs=np.array(outputs)
outputs2=np.array(outputs2)
Tsn=Ts_G_0_1[Targs]
ax=plt.axes()

ax.scatter(np.repeat(Tsn,2000),np.concatenate(outputs),alpha=0.002,s=8.0,color='springgreen')

#plt.plot(Tsn,labels_tmp,"g.--")
ax.plot(Tsn,mu,"r--",alpha=0.4,label="\mu")
#plt.plot(Tsn,np.average(outputs,axis=1),"o-",markersize=4,color='darkgreen')
ax.plot(Tsn,np.average(outputs_01,axis=1),"o-",markersize=4,color='darkgreen',label='Model output')
T0,T1=Tsn[np.where(labels_tmp==1.0)[0][[0,-1]]]
ax.vlines(T0,0,1,color='magenta',linestyle='dashed')
ax.vlines(T1,0,1,color='magenta',linestyle='dashed')
ax.plot(Tsn,np.average(outputs2,axis=1),"*-",color='purple',label='Model output shuffled')
#plt.plot(Ts,probs)
# ax.plot(Tc,mu_avc,"r",alpha=0.4) # Ask Pallab - what is mu_avc

#plt.legend(loc="upper right")/
handles, labels = ax.get_legend_handles_labels()
plt.savefig("%s_testdata_g0.pdf"%(sfname[:-4]),dpi=300)

del data_validate_new
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).

# %% [markdown]
# # G = 0.5 Testing

# %%
# --------------------------Edited by Dileep ------------------------------------------
data_validate_new2=f5_new_2['arrs'][Targs,8000:,:]
data_validate_new2=torch.tensor(data_validate_new2) #This is new for CUDA
# -------------------------------------------------------------------------------------

#---------------------------Critical region for G=0.5 ------------------
#xiBs,labels
xiBs=f5_new_2['xiBs'][:]
factor=0.30
cut=np.amax(xiBs)*factor

labels_tmp=np.heaviside(xiBs[Targs]-cut,1.0)
labels_train=torch.tensor(np.repeat(labels_tmp,8000)) #This is new for CUDA
labels_validate=torch.tensor(np.repeat(labels_tmp,2000)) #This is new for CUDA
# labels_train=np.repeat(labels_tmp,8000)
# labels_validate=np.repeat(labels_tmp,2000)

T0,T1=Ts_G_0_5[np.where(labels_tmp==1.0)[0][[0,-1]]]
#---------------------


#Plot the output
outputs=[]
outputs_01=[]
outputs2=[]
net.eval()
with torch.no_grad():
    for i in torch.arange(Targs.shape[0]):
        d=data_validate_new2[i,:,:]
        output=net(torch.tensor(d,dtype=torch.float32))
        output_01=(output>0.5)
        outputs_01.append(output_01.squeeze().detach().cpu().numpy())
        shfl=np.random.permutation(np.arange(1600))
        output2=net(torch.tensor(d[:,shfl],dtype=torch.float32))
        outputs.append(output.squeeze().detach().cpu().numpy())
        outputs2.append(output2.squeeze().detach().cpu().numpy())
    
#plt.plot(outputs.squeeze(),"o",alpha=0.02,color='red')
#plt.plot(labels_validate)
#depth=6
sns.set_style("whitegrid")
mu=np.average(np.fabs(np.average(data_validate_new2[:,:2000,:].cpu(),axis=2)),axis=1)
outputs=np.array(outputs)
outputs2=np.array(outputs2)
Tsn=Ts_G_0_5[Targs]
ax=plt.axes()

ax.scatter(np.repeat(Tsn,2000),np.concatenate(outputs),alpha=0.002,s=8.0,color='springgreen')

#plt.plot(Tsn,labels_tmp,"g.--")
ax.plot(Tsn,mu,"r--",alpha=0.4,label="\mu")
#plt.plot(Tsn,np.average(outputs,axis=1),"o-",markersize=4,color='darkgreen')
ax.plot(Tsn,np.average(outputs_01,axis=1),"o-",markersize=4,color='darkgreen',label='Model output')
T0,T1=Tsn[np.where(labels_tmp==1.0)[0][[0,-1]]]
ax.vlines(T0,0,1,color='magenta',linestyle='dashed')
ax.vlines(T1,0,1,color='magenta',linestyle='dashed')
ax.plot(Tsn,np.average(outputs2,axis=1),"*-",color='purple',label='Model output shuffled')
#plt.plot(Ts,probs)
# ax.plot(Tc,mu_avc,"r",alpha=0.4) # Ask Pallab - what is mu_avc

#plt.legend(loc="upper right")/
handles, labels = ax.get_legend_handles_labels()
plt.savefig("%s_testdata_g0.pdf"%(sfname[:-4]),dpi=300)

del data_validate_new2
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).

# %% [markdown]
# ## G=1, J=1 testing

# %%
# --------------------------Edited by Dileep ------------------------------------------
data_validate_new3=f5_new_3['arrs'][Targs_new,8000:,:]
data_validate_new3=torch.tensor(data_validate_new3) #This is new for CUDA
# -------------------------------------------------------------------------------------


#---------------------------Critical region for G=0.5 ------------------
#xiBs,labels
xiBs=f5_new_3['xiBs'][:]
factor=0.30
cut=np.amax(xiBs)*factor

labels_tmp=np.heaviside(xiBs[Targs_new]-cut,1.0)
labels_train=torch.tensor(np.repeat(labels_tmp,8000)) #This is new for CUDA
labels_validate=torch.tensor(np.repeat(labels_tmp,2000)) #This is new for CUDA
# labels_train=np.repeat(labels_tmp,8000)
# labels_validate=np.repeat(labels_tmp,2000)

T0,T1=Ts_G_1[np.where(labels_tmp==1.0)[0][[0,-1]]]
#---------------------


#Plot the output
outputs=[]
outputs_01=[]
outputs2=[]
net.eval()
with torch.no_grad():
    for i in torch.arange(Targs_new.shape[0]):
        d=data_validate_new3[i,:,:]
        output=net(torch.tensor(d,dtype=torch.float32))
        output_01=(output>0.5)
        outputs_01.append(output_01.squeeze().detach().cpu().numpy())
        shfl=np.random.permutation(np.arange(1600))
        output2=net(torch.tensor(d[:,shfl],dtype=torch.float32))
        outputs.append(output.squeeze().detach().cpu().numpy())
        outputs2.append(output2.squeeze().detach().cpu().numpy())
    
#plt.plot(outputs.squeeze(),"o",alpha=0.02,color='red')
#plt.plot(labels_validate)
#depth=6
sns.set_style("whitegrid")
mu=np.average(np.fabs(np.average(data_validate_new3[:,:2000,:].cpu(),axis=2)),axis=1)
outputs=np.array(outputs)
outputs2=np.array(outputs2)
Tsn=Ts_G_1[Targs_new]
ax=plt.axes()

ax.scatter(np.repeat(Tsn,2000),np.concatenate(outputs),alpha=0.002,s=8.0,color='springgreen')

#plt.plot(Tsn,labels_tmp,"g.--")
ax.plot(Tsn,mu,"r--",alpha=0.4,label="\mu")
#plt.plot(Tsn,np.average(outputs,axis=1),"o-",markersize=4,color='darkgreen')
ax.plot(Tsn,np.average(outputs_01,axis=1),"o-",markersize=4,color='darkgreen',label='Model output')
T0,T1=Tsn[np.where(labels_tmp==1.0)[0][[0,-1]]]
ax.vlines(T0,0,1,color='magenta',linestyle='dashed')
ax.vlines(T1,0,1,color='magenta',linestyle='dashed')
ax.plot(Tsn,np.average(outputs2,axis=1),"*-",color='purple',label='Model output shuffled')
#plt.plot(Ts,probs)
# ax.plot(Tc,mu_avc,"r",alpha=0.4) # Ask Pallab - what is mu_avc

#plt.legend(loc="upper right")/
handles, labels = ax.get_legend_handles_labels()
plt.savefig("%s_testdata_g0.pdf"%(sfname[:-4]),dpi=300)

del data_validate_new3
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:35: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).

# %% [markdown]
# ## G=1, J=0.01 testing

# %%
# --------------------------Edited by Dileep ------------------------------------------
data_validate_new4=f5_new_4['arrs'][Targs,8000:,:]
data_validate_new4=torch.tensor(data_validate_new4) #This is new for CUDA
# -------------------------------------------------------------------------------------


#---------------------------Critical region for G=0.5 ------------------
#xiBs,labels
xiBs=f5_new_4['xiBs'][:]
factor=0.30
cut=np.amax(xiBs)*factor

labels_tmp=np.heaviside(xiBs[Targs]-cut,1.0)
labels_train=torch.tensor(np.repeat(labels_tmp,8000)) #This is new for CUDA
labels_validate=torch.tensor(np.repeat(labels_tmp,2000)) #This is new for CUDA
# labels_train=np.repeat(labels_tmp,8000)
# labels_validate=np.repeat(labels_tmp,2000)

T0,T1=Ts_G_1_J_0[np.where(labels_tmp==1.0)[0][[0,-1]]]
#---------------------


#Plot the output
outputs=[]
outputs_01=[]
outputs2=[]
net.eval()
with torch.no_grad():
    for i in torch.arange(Targs.shape[0]):
        d=data_validate_new4[i,:,:]
        output=net(torch.tensor(d,dtype=torch.float32))
        output_01=(output>0.5)
        outputs_01.append(output_01.squeeze().detach().cpu().numpy())
        shfl=np.random.permutation(np.arange(1600))
        output2=net(torch.tensor(d[:,shfl],dtype=torch.float32))
        outputs.append(output.squeeze().detach().cpu().numpy())
        outputs2.append(output2.squeeze().detach().cpu().numpy())
    
#plt.plot(outputs.squeeze(),"o",alpha=0.02,color='red')
#plt.plot(labels_validate)
#depth=6
sns.set_style("whitegrid")
mu=np.average(np.fabs(np.average(data_validate_new4[:,:2000,:].cpu(),axis=2)),axis=1)
outputs=np.array(outputs)
outputs2=np.array(outputs2)
Tsn=Ts_G_1_J_0[Targs]
ax=plt.axes()

ax.scatter(np.repeat(Tsn,2000),np.concatenate(outputs),alpha=0.002,s=8.0,color='springgreen')

#plt.plot(Tsn,labels_tmp,"g.--")
ax.plot(Tsn,mu,"r--",alpha=0.4,label="\mu")
#plt.plot(Tsn,np.average(outputs,axis=1),"o-",markersize=4,color='darkgreen')
ax.plot(Tsn,np.average(outputs_01,axis=1),"o-",markersize=4,color='darkgreen',label='Model output')
T0,T1=Tsn[np.where(labels_tmp==1.0)[0][[0,-1]]]
ax.vlines(T0,0,1,color='magenta',linestyle='dashed')
ax.vlines(T1,0,1,color='magenta',linestyle='dashed')
ax.plot(Tsn,np.average(outputs2,axis=1),"*-",color='purple',label='Model output shuffled')
#plt.plot(Ts,probs)
# ax.plot(Tc,mu_avc,"r",alpha=0.4) # Ask Pallab - what is mu_avc

#plt.legend(loc="upper right")/
handles, labels = ax.get_legend_handles_labels()
plt.savefig("%s_testdata_g0.pdf"%(sfname[:-4]),dpi=300)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:35: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
