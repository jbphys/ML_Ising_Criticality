# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os,pickle
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/isingdata-h5py-jb/G1_J1_data.h5py
# /kaggle/input/isingdata-h5py-jb/Gp5_data.h5py
# /kaggle/input/isingdata-h5py-jb/Gp1_data.h5py
# /kaggle/input/isingdata-h5py-jb/G1_Jp01_data.h5py
# /kaggle/input/isingdata-h5py-jb/G0_data.h5py

# %%
import os,pickle
for dirname, _, filenames in os.walk('./'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# ./__notebook__.ipynb

# %%
# Imports
import torch
import torch.nn as nn                               # to access build-in functions to build the NN
import torch.nn.functional as F                     # to access activation functions
from torchvision import datasets,transforms        # to access the MNIST dataset
import torch.optim as optim                         # to build out optimizer

import numpy as np
import matplotlib.pyplot as plt # for plotting
# %matplotlib inline
import seaborn as sns
import sklearn.metrics

from torch.optim.lr_scheduler import ReduceLROnPlateau

# %%
#h5py data read
import h5py
f5 = h5py.File('/kaggle/input/isingdata-h5py-jb/G0_data.h5py','r')
#Tc = 2.35

# -----
f5_new = h5py.File('/kaggle/input/isingdata-h5py-jb/Gp1_data.h5py','r')
f5_new_2 = h5py.File('/kaggle/input/isingdata-h5py-jb/Gp5_data.h5py','r')
f5_new_3 = h5py.File('../input/isingdata-h5py-jb/G1_J1_data.h5py','r')
f5_new_4 = h5py.File('../input/isingdata-h5py-jb/G1_Jp01_data.h5py','r')

# %%
Ts_G_0=f5['Ts'][:]
Ts_G_0_1=f5_new['Ts'][:]
Ts_G_0_5=f5_new_2['Ts'][:]
Ts_G_1=f5_new_3['Ts'][:]
Ts_G_1_J_0=f5_new_4['Ts'][:]
#Other Targs
#Targs=np.concatenate((np.arange(1,20,1),np.where(f5['xiBs'][:]>0.12)[0],np.arange(34,61,3)))
#Tsn=np.arange(1.1,3.1,0.1)
#Targs=np.concatenate([np.where(Ts==Tn)[0] for Tn in Tsn])

Targs=np.arange(61)
Targs_new=np.arange(80)

#xiBs,labels
xiBs=f5['xiBs'][:]
factor=0.30
cut=np.amax(xiBs)*factor

labels_tmp=np.heaviside(xiBs[Targs]-cut,1.0)
labels_train=np.repeat(labels_tmp,8000)
labels_validate=np.repeat(labels_tmp,2000)

T0,T1=Ts_G_0[np.where(labels_tmp==1.0)[0][[0,-1]]]

T0,T1
# Out:
# (2.2, 2.625)

# %% [markdown]
# ## Checking labels

# %%
print(f5['arrs'].shape)
import matplotlib.pyplot as plt 

plt.figure(dpi=150)
plt.plot(Ts_G_0[8:-9],labels_tmp[8:-9],'.-')
# plt.plot(labels_train)
plt.xticks(Ts_G_0[8:-9],rotation=90)
plt.tight_layout()
plt.grid(True)
plt.show()
# Out:
# (61, 10000, 1600)

# %%
#Alternative labels (do not run this module if you do not need it)

# factor=0.3
# cut=np.amax(xiBs)*factor
# labels_tmp=((Ts[Targs] <= 2.5) & (Ts[Targs]>=2.10)).astype(np.float32) # Arbitrty region
# #labels_tmp=np.heaviside(xiBs[Targs]-cut,1.0) # Cut region

# labels_train=np.repeat(labels_tmp,8000)
# labels_validate=np.repeat(labels_tmp,2000)
# T0,T1=Ts[np.where(labels_tmp==1.0)[0][[0,-1]]]

# plt.plot(Ts[Targs],labels_tmp)
# T0,T1

# %%
#h5py data read

data_train=f5['arrs'][Targs,:8000,:]
data_validate=f5['arrs'][Targs,8000:,:]
#labels_train=np.heaviside(xiBs[Targs]-cut,1.0)

data_train=data_train.reshape(Targs.shape[0]*8000,1600)


# --------------------------Edited by Dileep ------------------------------------------
data_validate_new=f5_new['arrs'][Targs,8000:,:]
data_validate_new2=f5_new_2['arrs'][Targs,8000:,:]
data_validate_new3=f5_new_3['arrs'][Targs_new,8000:,:]
data_validate_new4=f5_new_4['arrs'][Targs,8000:,:]
# -------------------------------------------------------------------------------------

# %%
# Creating the Network:
inner_dim=128
class VDNN(nn.Module):                           # nn.Module is a subclass from which we inherit
    def __init__(self,nl=6):                                     # Here you define the structure
        super(VDNN, self).__init__()
        layers=[]
        layers.append(nn.Linear(40*40, inner_dim))
        layers.append(nn.ReLU())
        for ln in range(nl-1):
            layers.append(nn.Linear(inner_dim, inner_dim))
            layers.append(nn.ReLU())
        layers.extend((nn.Linear(inner_dim,1), nn.Sigmoid()))
        self.layers = nn.Sequential(*layers)
    def forward(self,x):
        return self.layers(x)

class VDNN_one(nn.Module):                           # nn.Module is a subclass from which we inherit
    def __init__(self,nl=1):                                     # Here you define the structure
        super(VDNN_one, self).__init__()
        layers=[]
        layers.append(nn.Linear(40*40, inner_dim))
        layers.append(nn.ReLU())
        for ln in range(nl-1):
            layers.append(nn.Linear(inner_dim, inner_dim))
            layers.append(nn.ReLU())
        layers.extend((nn.Linear(inner_dim,1), nn.Sigmoid()))
        self.layers = nn.Sequential(*layers)
    def forward(self,x):
        return self.layers(x)

    

class SimpleNet(nn.Module):                           # nn.Module is a subclass from which we inherit
    def __init__(self,nl=2):                                     # Here you define the structure
        super(SimpleNet, self).__init__()
        layers=[]
        layers.extend((nn.Linear(1,inner_dim), nn.ReLU(), nn.Linear(inner_dim,1), nn.Sigmoid()))
        self.layers = nn.Sequential(*layers)
    def forward(self,x):
        return self.layers(x)
class VCNN(nn.Module): # A CNN based classifier
    def __init__(self):
        super(VCNN, self).__init__()
        self.cnn=m = nn.Sequential(nn.Conv2d(1,4, kernel_size=3, stride=1,padding_mode='circular'),
                  nn.BatchNorm2d(4),
                  nn.ReLU(),
                  nn.MaxPool2d(3, stride=2),
                  nn.Conv2d(4,4, kernel_size=3, stride=1,padding_mode='circular'),
                  nn.BatchNorm2d(4),
                  nn.ReLU(),
                  nn.MaxPool2d(3, stride=2)) # last outs (-1,4,7,7)
        self.classifier=nn.Sequential(nn.Linear(4*7*7,1),nn.Sigmoid())
        
    def forward(self,x):
        x=x.view(-1,40,40)
        x=x.view(-1,1,40,40) # Extra channel for CNN
        x=self.cnn(x)
        x=x.view(-1,4*7*7) # Reducing the dimension 
        x=self.classifier(x)
        return x

# %%
#Define NN and training parameters
depth=4
net=VDNN(depth)
loss_fn = nn.BCELoss(reduction='none')
count=0

#-------------------------------------------
#No of epochs during training
optim_step=500
#-------------------------------------------

losses=[]

NN_test=Targs.shape[0]*8000

model_type=type(net).__name__

# %%
#scheduler
lr=5e-6

optimizer = optim.Adam(net.parameters(),lr=lr,weight_decay=0)
scheduler = ReduceLROnPlateau(optimizer,"min",patience=5)
from collections import deque
osfnames=deque()

# %%
# %%time
#------------Loss variable for each iteration-----------
Loss_epoch = []
#Loss_batch = 0
#------------
#training
net.train()
batch_size=150
is_theta=True
is_ab=False
is_shuffling=True
batch_no=np.int32(NN_test/batch_size)

shuffle_injection_frequency=50
while (count<optim_step):
    Loss_batch = 0 #for loss plot
    optimizer.zero_grad()
    NNs=torch.randperm(NN_test)
    for k in np.arange(batch_no):
        optimizer.zero_grad()
        inds = NNs[k*batch_size:(k+1)*batch_size]
        inds = inds[:batch_size]
        datas2 = data_train[inds]
        labels2 = labels_train[inds]
        
        sgn=(2*torch.bernoulli(torch.ones(batch_size)*0.5)-1).unsqueeze(-1)
        dt=torch.tensor(datas2,dtype=torch.float32)
        dt=dt*sgn
    # Adversarial 
        if is_ab:
            a,b=torch.rand(2,batch_size)
            a=0.25+2*torch.unsqueeze(a,-1)
            b=1*(torch.unsqueeze(b,-1)-0.5)
            #a,b=1,0 #no a,b
            dt=(dt*a)
            sgn=(2*torch.bernoulli(torch.ones(batch_size)*0.5)-1).unsqueeze(-1)
            dt=(dt*sgn)+b
   
    #shuffling
        if is_shuffling:
            s_inds=torch.randperm(1600)
            dt[:shuffle_injection_frequency,:]=dt[:shuffle_injection_frequency,s_inds]
            labels2[:shuffle_injection_frequency]=0
    
        #A random shift x and y
        i,j=torch.randint(40,[2])
        dt2=dt.reshape(batch_size,40,40)
        dt=torch.roll(dt2,[i,j],dims=[1,2]).reshape(batch_size,1600)

        #Training
        poutputs=net(dt)
        targets=torch.tensor(labels2,dtype=torch.float32,requires_grad=False)

        with torch.no_grad():
            w1=0.5
            wghts=(w1*targets+(1-w1)*(1-targets))
            wghts=wghts/torch.sum(wghts)
        loss_tmp=loss_fn(poutputs,torch.unsqueeze(targets,1))
        loss=torch.sum(loss_tmp.squeeze(1)*wghts)
        loss.backward()
        if k%1000==0:
            losses.append(loss.detach().cpu())
            with torch.no_grad():
                d=torch.tensor(data_validate.reshape(61*2000,1600))
                output_v=net(d)
                labels_v=torch.tensor(labels_validate)
                loss_v=loss_fn(output_v,labels_v.unsqueeze(-1))
                loss_v=torch.mean(loss_v)
            print(count,k,loss.detach().cpu(),loss_v.detach().cpu(),end='\n')
        optimizer.step()
        #------averaging loss-------
        Loss_batch += loss.detach().cpu().item()
    
    Loss_batch /= batch_no     
    scheduler.step(Loss_batch)
    Loss_epoch.append(Loss_batch)
    
    if count%1==0 and count>0: #Saving last five models 
        sfname="./trained_%s_%d_D_%d_%.0f"%(model_type,count,depth,100*factor)
        if is_theta:
            sfname=sfname+"_theta"
        else:
            sfname=sfname+"full_curve"
        if is_ab:
            sfname=sfname+"_ab"
        if is_shuffling:
            sfname=sfname+"_shuffling"
        sfname=sfname+".dat"
        
        if len(osfnames)>5:
            osfname=osfnames.popleft()
            if os.path.exists(osfname):
                print("Removing:%s"%osfname)
                os.remove(osfname)
            
        with open(sfname,"wb") as fl:
            print(sfname)
            pickle.dump(net.state_dict(),fl)
            pickle.dump({'T0':T0,'T1':T1,'Targs':Targs,'epochs':count,'losses':losses,'batch_size': batch_size, 'epoch_size': NN_test},fl)
            osfnames.append(sfname)
            fl.close()
    count=count+1
# Out:
# 0 0 tensor(0.6948) tensor(0.6944)
# 0 1000 tensor(0.5028) tensor(0.6163)
# 0 2000 tensor(0.5140) tensor(0.6051)
# 0 3000 tensor(0.4679) tensor(0.5993)
# 1 0 tensor(0.4947) tensor(0.5981)
# 1 1000 tensor(0.4682) tensor(0.5916)
# 1 2000 tensor(0.4503) tensor(0.5834)
# 1 3000 tensor(0.4039) tensor(0.5743)
# ./trained_VDNN_1_D_4_30_theta_shuffling.dat
# 2 0 tensor(0.4433) tensor(0.5720)
# 2 1000 tensor(0.4486) tensor(0.5550)
# 2 2000 tensor(0.4712) tensor(0.5375)
# 2 3000 tensor(0.3758) tensor(0.5083)
# ./trained_VDNN_2_D_4_30_theta_shuffling.dat
# 3 0 tensor(0.4643) tensor(0.4991)
# 3 1000 tensor(0.3055) tensor(0.4620)
# 3 2000 tensor(0.2746) tensor(0.4239)
# 3 3000 tensor(0.2825) tensor(0.3921)
# ./trained_VDNN_3_D_4_30_theta_shuffling.dat
# 4 0 tensor(0.2858) tensor(0.3833)
# 4 1000 tensor(0.2993) tensor(0.3647)
# 4 2000 tensor(0.2605) tensor(0.3555)
# 4 3000 tensor(0.2545) tensor(0.3426)
# ./trained_VDNN_4_D_4_30_theta_shuffling.dat
# 5 0 tensor(0.2635) tensor(0.3434)
# 5 1000 tensor(0.2037) tensor(0.3365)
# 5 2000 tensor(0.2095) tensor(0.3275)
# 5 3000 tensor(0.1763) tensor(0.3207)
# ./trained_VDNN_5_D_4_30_theta_shuffling.dat
# 6 0 tensor(0.2296) tensor(0.3215)
# 6 1000 tensor(0.2453) tensor(0.3162)
# 6 2000 tensor(0.2449) tensor(0.3131)
# 6 3000 tensor(0.1867) tensor(0.3091)
# ./trained_VDNN_6_D_4_30_theta_shuffling.dat
# 7 0 tensor(0.1909) tensor(0.3061)
# 7 1000 tensor(0.1733) tensor(0.3053)
# 7 2000 tensor(0.2467) tensor(0.3009)
# 7 3000 tensor(0.2101) tensor(0.2965)
# Removing:./trained_VDNN_1_D_4_30_theta_shuffling.dat
# ./trained_VDNN_7_D_4_30_theta_shuffling.dat
# 8 0 tensor(0.2120) tensor(0.3021)
# 8 1000 tensor(0.1984) tensor(0.2955)
# 8 2000 tensor(0.1673) tensor(0.2945)
# 8 3000 tensor(0.2617) tensor(0.2906)
# Removing:./trained_VDNN_2_D_4_30_theta_shuffling.dat
# ./trained_VDNN_8_D_4_30_theta_shuffling.dat
# 9 0 tensor(0.2034) tensor(0.2925)
# 9 1000 tensor(0.1869) tensor(0.2924)
# 9 2000 tensor(0.2035) tensor(0.2882)
# 9 3000 tensor(0.1440) tensor(0.2905)
# Removing:./trained_VDNN_3_D_4_30_theta_shuffling.dat
# ./trained_VDNN_9_D_4_30_theta_shuffling.dat
# 10 0 tensor(0.1780) tensor(0.2866)
# 10 1000 tensor(0.1829) tensor(0.2883)
# 10 2000 tensor(0.1777) tensor(0.2873)
# 10 3000 tensor(0.2608) tensor(0.2859)
# Removing:./trained_VDNN_4_D_4_30_theta_shuffling.dat
# ./trained_VDNN_10_D_4_30_theta_shuffling.dat
# 11 0 tensor(0.2264) tensor(0.2834)
# 11 1000 tensor(0.2064) tensor(0.2842)
# 11 2000 tensor(0.2033) tensor(0.2814)
# 11 3000 tensor(0.2600) tensor(0.2819)
# Removing:./trained_VDNN_5_D_4_30_theta_shuffling.dat
# ./trained_VDNN_11_D_4_30_theta_shuffling.dat
# 12 0 tensor(0.2303) tensor(0.2799)
# 12 1000 tensor(0.2396) tensor(0.2835)
# 12 2000 tensor(0.1854) tensor(0.2835)
# 12 3000 tensor(0.1496) tensor(0.2795)
# Removing:./trained_VDNN_6_D_4_30_theta_shuffling.dat
# ./trained_VDNN_12_D_4_30_theta_shuffling.dat
# 13 0 tensor(0.1676) tensor(0.2823)
# 13 1000 tensor(0.1598) tensor(0.2777)
# 13 2000 tensor(0.1941) tensor(0.2785)
# 13 3000 tensor(0.1336) tensor(0.2794)
# Removing:./trained_VDNN_7_D_4_30_theta_shuffling.dat
# ./trained_VDNN_13_D_4_30_theta_shuffling.dat
# 14 0 tensor(0.2457) tensor(0.2775)
# 14 1000 tensor(0.2612) tensor(0.2794)
# 14 2000 tensor(0.1798) tensor(0.2757)
# 14 3000 tensor(0.1770) tensor(0.2797)
# Removing:./trained_VDNN_8_D_4_30_theta_shuffling.dat
# ./trained_VDNN_14_D_4_30_theta_shuffling.dat
# 15 0 tensor(0.2117) tensor(0.2788)
# 15 1000 tensor(0.1145) tensor(0.2756)
# 15 2000 tensor(0.2182) tensor(0.2724)
# 15 3000 tensor(0.1296) tensor(0.2731)
# Removing:./trained_VDNN_9_D_4_30_theta_shuffling.dat
# ./trained_VDNN_15_D_4_30_theta_shuffling.dat
# 16 0 tensor(0.1853) tensor(0.2744)
# 16 1000 tensor(0.2242) tensor(0.2743)
# 16 2000 tensor(0.1962) tensor(0.2759)
# 16 3000 tensor(0.2131) tensor(0.2710)
# Removing:./trained_VDNN_10_D_4_30_theta_shuffling.dat
# ./trained_VDNN_16_D_4_30_theta_shuffling.dat
# 17 0 tensor(0.2147) tensor(0.2740)
# 17 1000 tensor(0.2121) tensor(0.2716)
# 17 2000 tensor(0.1585) tensor(0.2696)
# 17 3000 tensor(0.1497) tensor(0.2716)
# Removing:./trained_VDNN_11_D_4_30_theta_shuffling.dat
# ./trained_VDNN_17_D_4_30_theta_shuffling.dat
# 18 0 tensor(0.1949) tensor(0.2717)
# 18 1000 tensor(0.1998) tensor(0.2742)
# 18 2000 tensor(0.2198) tensor(0.2675)
# 18 3000 tensor(0.1079) tensor(0.2694)
# Removing:./trained_VDNN_12_D_4_30_theta_shuffling.dat
# ./trained_VDNN_18_D_4_30_theta_shuffling.dat
# 19 0 tensor(0.1763) tensor(0.2715)
# 19 1000 tensor(0.2326) tensor(0.2681)
# 19 2000 tensor(0.1533) tensor(0.2680)
# 19 3000 tensor(0.2516) tensor(0.2668)
# Removing:./trained_VDNN_13_D_4_30_theta_shuffling.dat
# ./trained_VDNN_19_D_4_30_theta_shuffling.dat
# 20 0 tensor(0.1492) tensor(0.2698)
# 20 1000 tensor(0.1650) tensor(0.2694)
# 20 2000 tensor(0.1899) tensor(0.2683)
# 20 3000 tensor(0.1323) tensor(0.2678)
# Removing:./trained_VDNN_14_D_4_30_theta_shuffling.dat
# ./trained_VDNN_20_D_4_30_theta_shuffling.dat
# 21 0 tensor(0.1444) tensor(0.2673)
# 21 1000 tensor(0.1605) tensor(0.2685)
# 21 2000 tensor(0.2240) tensor(0.2637)
# 21 3000 tensor(0.2216) tensor(0.2667)
# Removing:./trained_VDNN_15_D_4_30_theta_shuffling.dat
# ./trained_VDNN_21_D_4_30_theta_shuffling.dat
# 22 0 tensor(0.0928) tensor(0.2664)
# 22 1000 tensor(0.1771) tensor(0.2653)
# 22 2000 tensor(0.2253) tensor(0.2625)
# 22 3000 tensor(0.2153) tensor(0.2637)
# Removing:./trained_VDNN_16_D_4_30_theta_shuffling.dat
# ./trained_VDNN_22_D_4_30_theta_shuffling.dat
# 23 0 tensor(0.1629) tensor(0.2674)
# 23 1000 tensor(0.1614) tensor(0.2671)
# 23 2000 tensor(0.2324) tensor(0.2638)
# 23 3000 tensor(0.2037) tensor(0.2622)
# Removing:./trained_VDNN_17_D_4_30_theta_shuffling.dat
# ./trained_VDNN_23_D_4_30_theta_shuffling.dat
# 24 0 tensor(0.1442) tensor(0.2628)
# 24 1000 tensor(0.1963) tensor(0.2616)
# 24 2000 tensor(0.1528) tensor(0.2649)
# 24 3000 tensor(0.2165) tensor(0.2631)
# Removing:./trained_VDNN_18_D_4_30_theta_shuffling.dat
# ./trained_VDNN_24_D_4_30_theta_shuffling.dat
# 25 0 tensor(0.1773) tensor(0.2654)
# 25 1000 tensor(0.1511) tensor(0.2617)
# 25 2000 tensor(0.1628) tensor(0.2607)
# 25 3000 tensor(0.1684) tensor(0.2619)
# Removing:./trained_VDNN_19_D_4_30_theta_shuffling.dat
# ./trained_VDNN_25_D_4_30_theta_shuffling.dat
# 26 0 tensor(0.1640) tensor(0.2615)
# 26 1000 tensor(0.1846) tensor(0.2619)
# 26 2000 tensor(0.2604) tensor(0.2613)
# 26 3000 tensor(0.1450) tensor(0.2632)
# Removing:./trained_VDNN_20_D_4_30_theta_shuffling.dat
# ./trained_VDNN_26_D_4_30_theta_shuffling.dat
# 27 0 tensor(0.2184) tensor(0.2622)
# 27 1000 tensor(0.2254) tensor(0.2596)
# 27 2000 tensor(0.1451) tensor(0.2629)
# 27 3000 tensor(0.1527) tensor(0.2577)
# Removing:./trained_VDNN_21_D_4_30_theta_shuffling.dat
# ./trained_VDNN_27_D_4_30_theta_shuffling.dat
# 28 0 tensor(0.1702) tensor(0.2625)
# 28 1000 tensor(0.2279) tensor(0.2594)
# 28 2000 tensor(0.1462) tensor(0.2603)
# 28 3000 tensor(0.2370) tensor(0.2614)
# Removing:./trained_VDNN_22_D_4_30_theta_shuffling.dat
# ./trained_VDNN_28_D_4_30_theta_shuffling.dat
# 29 0 tensor(0.1426) tensor(0.2600)
# 29 1000 tensor(0.2417) tensor(0.2572)
# 29 2000 tensor(0.1789) tensor(0.2569)
# 29 3000 tensor(0.2114) tensor(0.2584)
# Removing:./trained_VDNN_23_D_4_30_theta_shuffling.dat
# ./trained_VDNN_29_D_4_30_theta_shuffling.dat
# 30 0 tensor(0.1616) tensor(0.2560)
# 30 1000 tensor(0.1011) tensor(0.2556)
# 30 2000 tensor(0.2060) tensor(0.2601)
# 30 3000 tensor(0.1804) tensor(0.2597)
# Removing:./trained_VDNN_24_D_4_30_theta_shuffling.dat
# ./trained_VDNN_30_D_4_30_theta_shuffling.dat
# 31 0 tensor(0.1622) tensor(0.2572)
# 31 1000 tensor(0.1835) tensor(0.2586)
# 31 2000 tensor(0.1528) tensor(0.2582)
# 31 3000 tensor(0.2210) tensor(0.2586)
# Removing:./trained_VDNN_25_D_4_30_theta_shuffling.dat
# ./trained_VDNN_31_D_4_30_theta_shuffling.dat
# 32 0 tensor(0.0832) tensor(0.2583)
# 32 1000 tensor(0.2121) tensor(0.2579)
# 32 2000 tensor(0.1794) tensor(0.2568)
# 32 3000 tensor(0.1492) tensor(0.2594)
# Removing:./trained_VDNN_26_D_4_30_theta_shuffling.dat
# ./trained_VDNN_32_D_4_30_theta_shuffling.dat
# 33 0 tensor(0.2401) tensor(0.2574)
# 33 1000 tensor(0.1619) tensor(0.2554)
# 33 2000 tensor(0.2038) tensor(0.2568)
# 33 3000 tensor(0.1295) tensor(0.2551)
# Removing:./trained_VDNN_27_D_4_30_theta_shuffling.dat
# ./trained_VDNN_33_D_4_30_theta_shuffling.dat
# 34 0 tensor(0.1912) tensor(0.2548)
# 34 1000 tensor(0.1676) tensor(0.2549)
# 34 2000 tensor(0.2800) tensor(0.2549)
# 34 3000 tensor(0.1065) tensor(0.2546)
# Removing:./trained_VDNN_28_D_4_30_theta_shuffling.dat
# ./trained_VDNN_34_D_4_30_theta_shuffling.dat
# 35 0 tensor(0.1709) tensor(0.2525)
# 35 1000 tensor(0.1836) tensor(0.2534)
# 35 2000 tensor(0.1796) tensor(0.2548)
# 35 3000 tensor(0.1946) tensor(0.2556)
# Removing:./trained_VDNN_29_D_4_30_theta_shuffling.dat
# ./trained_VDNN_35_D_4_30_theta_shuffling.dat
# 36 0 tensor(0.1651) tensor(0.2541)
# 36 1000 tensor(0.1535) tensor(0.2562)
# 36 2000 tensor(0.1400) tensor(0.2522)
# 36 3000 tensor(0.2681) tensor(0.2538)
# Removing:./trained_VDNN_30_D_4_30_theta_shuffling.dat
# ./trained_VDNN_36_D_4_30_theta_shuffling.dat
# 37 0 tensor(0.1774) tensor(0.2520)
# 37 1000 tensor(0.1332) tensor(0.2517)
# 37 2000 tensor(0.1979) tensor(0.2531)
# 37 3000 tensor(0.0987) tensor(0.2559)
# Removing:./trained_VDNN_31_D_4_30_theta_shuffling.dat
# ./trained_VDNN_37_D_4_30_theta_shuffling.dat
# 38 0 tensor(0.1488) tensor(0.2506)
# 38 1000 tensor(0.2220) tensor(0.2515)
# 38 2000 tensor(0.2294) tensor(0.2518)
# 38 3000 tensor(0.1177) tensor(0.2533)
# Removing:./trained_VDNN_32_D_4_30_theta_shuffling.dat
# ./trained_VDNN_38_D_4_30_theta_shuffling.dat
# 39 0 tensor(0.1880) tensor(0.2522)
# 39 1000 tensor(0.2304) tensor(0.2525)
# 39 2000 tensor(0.1437) tensor(0.2525)
# 39 3000 tensor(0.2072) tensor(0.2526)
# Removing:./trained_VDNN_33_D_4_30_theta_shuffling.dat
# ./trained_VDNN_39_D_4_30_theta_shuffling.dat
# 40 0 tensor(0.1312) tensor(0.2493)
# 40 1000 tensor(0.1970) tensor(0.2504)
# 40 2000 tensor(0.1427) tensor(0.2501)
# 40 3000 tensor(0.1612) tensor(0.2504)
# Removing:./trained_VDNN_34_D_4_30_theta_shuffling.dat
# ./trained_VDNN_40_D_4_30_theta_shuffling.dat
# 41 0 tensor(0.1817) tensor(0.2494)
# 41 1000 tensor(0.1917) tensor(0.2492)
# 41 2000 tensor(0.1990) tensor(0.2485)
# 41 3000 tensor(0.1799) tensor(0.2493)
# Removing:./trained_VDNN_35_D_4_30_theta_shuffling.dat
# ./trained_VDNN_41_D_4_30_theta_shuffling.dat
# 42 0 tensor(0.1466) tensor(0.2476)
# 42 1000 tensor(0.1605) tensor(0.2499)
# 42 2000 tensor(0.1910) tensor(0.2516)
# 42 3000 tensor(0.1525) tensor(0.2461)
# Removing:./trained_VDNN_36_D_4_30_theta_shuffling.dat
# ./trained_VDNN_42_D_4_30_theta_shuffling.dat
# 43 0 tensor(0.1169) tensor(0.2493)
# 43 1000 tensor(0.1682) tensor(0.2487)
# 43 2000 tensor(0.1764) tensor(0.2461)
# 43 3000 tensor(0.1795) tensor(0.2467)
# Removing:./trained_VDNN_37_D_4_30_theta_shuffling.dat
# ./trained_VDNN_43_D_4_30_theta_shuffling.dat
# 44 0 tensor(0.1874) tensor(0.2464)
# 44 1000 tensor(0.2052) tensor(0.2475)
# 44 2000 tensor(0.1127) tensor(0.2480)
# 44 3000 tensor(0.1618) tensor(0.2462)
# Removing:./trained_VDNN_38_D_4_30_theta_shuffling.dat
# ./trained_VDNN_44_D_4_30_theta_shuffling.dat
# 45 0 tensor(0.1808) tensor(0.2445)
# 45 1000 tensor(0.1716) tensor(0.2456)
# 45 2000 tensor(0.2170) tensor(0.2450)
# 45 3000 tensor(0.1542) tensor(0.2442)
# Removing:./trained_VDNN_39_D_4_30_theta_shuffling.dat
# ./trained_VDNN_45_D_4_30_theta_shuffling.dat
# 46 0 tensor(0.0880) tensor(0.2452)
# 46 1000 tensor(0.1738) tensor(0.2453)
# 46 2000 tensor(0.1409) tensor(0.2449)
# 46 3000 tensor(0.1490) tensor(0.2443)
# Removing:./trained_VDNN_40_D_4_30_theta_shuffling.dat
# ./trained_VDNN_46_D_4_30_theta_shuffling.dat
# 47 0 tensor(0.1748) tensor(0.2447)
# 47 1000 tensor(0.2057) tensor(0.2450)
# 47 2000 tensor(0.1787) tensor(0.2487)
# 47 3000 tensor(0.2269) tensor(0.2432)
# Removing:./trained_VDNN_41_D_4_30_theta_shuffling.dat
# ./trained_VDNN_47_D_4_30_theta_shuffling.dat
# 48 0 tensor(0.1244) tensor(0.2430)
# 48 1000 tensor(0.1421) tensor(0.2430)
# 48 2000 tensor(0.1545) tensor(0.2446)
# 48 3000 tensor(0.1735) tensor(0.2419)
# Removing:./trained_VDNN_42_D_4_30_theta_shuffling.dat
# ./trained_VDNN_48_D_4_30_theta_shuffling.dat
# 49 0 tensor(0.1481) tensor(0.2440)
# 49 1000 tensor(0.2314) tensor(0.2412)
# 49 2000 tensor(0.1544) tensor(0.2428)
# 49 3000 tensor(0.1538) tensor(0.2442)
# Removing:./trained_VDNN_43_D_4_30_theta_shuffling.dat
# ./trained_VDNN_49_D_4_30_theta_shuffling.dat
# 50 0 tensor(0.1885) tensor(0.2418)
# 50 1000 tensor(0.1210) tensor(0.2405)
# 50 2000 tensor(0.1700) tensor(0.2416)
# 50 3000 tensor(0.1717) tensor(0.2402)
# Removing:./trained_VDNN_44_D_4_30_theta_shuffling.dat
# ./trained_VDNN_50_D_4_30_theta_shuffling.dat
# 51 0 tensor(0.1439) tensor(0.2401)
# 51 1000 tensor(0.1669) tensor(0.2427)
# 51 2000 tensor(0.1985) tensor(0.2425)
# 51 3000 tensor(0.2092) tensor(0.2405)
# Removing:./trained_VDNN_45_D_4_30_theta_shuffling.dat
# ./trained_VDNN_51_D_4_30_theta_shuffling.dat
# 52 0 tensor(0.1919) tensor(0.2381)
# 52 1000 tensor(0.1385) tensor(0.2390)
# 52 2000 tensor(0.1656) tensor(0.2388)
# 52 3000 tensor(0.1352) tensor(0.2398)
# Removing:./trained_VDNN_46_D_4_30_theta_shuffling.dat
# ./trained_VDNN_52_D_4_30_theta_shuffling.dat
# 53 0 tensor(0.1741) tensor(0.2384)
# 53 1000 tensor(0.1585) tensor(0.2394)
# 53 2000 tensor(0.1536) tensor(0.2377)
# 53 3000 tensor(0.0982) tensor(0.2389)
# Removing:./trained_VDNN_47_D_4_30_theta_shuffling.dat
# ./trained_VDNN_53_D_4_30_theta_shuffling.dat
# 54 0 tensor(0.1562) tensor(0.2381)
# 54 1000 tensor(0.1237) tensor(0.2360)
# 54 2000 tensor(0.1739) tensor(0.2369)
# 54 3000 tensor(0.1547) tensor(0.2378)
# Removing:./trained_VDNN_48_D_4_30_theta_shuffling.dat
# ./trained_VDNN_54_D_4_30_theta_shuffling.dat
# 55 0 tensor(0.1124) tensor(0.2354)
# 55 1000 tensor(0.1691) tensor(0.2354)
# 55 2000 tensor(0.2064) tensor(0.2352)
# 55 3000 tensor(0.1421) tensor(0.2347)
# Removing:./trained_VDNN_49_D_4_30_theta_shuffling.dat
# ./trained_VDNN_55_D_4_30_theta_shuffling.dat
# 56 0 tensor(0.1164) tensor(0.2353)
# 56 1000 tensor(0.1309) tensor(0.2360)
# 56 2000 tensor(0.1514) tensor(0.2347)
# 56 3000 tensor(0.1555) tensor(0.2338)
# Removing:./trained_VDNN_50_D_4_30_theta_shuffling.dat
# ./trained_VDNN_56_D_4_30_theta_shuffling.dat
# 57 0 tensor(0.2182) tensor(0.2334)
# 57 1000 tensor(0.1649) tensor(0.2352)
# 57 2000 tensor(0.1474) tensor(0.2339)
# 57 3000 tensor(0.1858) tensor(0.2341)
# Removing:./trained_VDNN_51_D_4_30_theta_shuffling.dat
# ./trained_VDNN_57_D_4_30_theta_shuffling.dat
# 58 0 tensor(0.1399) tensor(0.2335)
# 58 1000 tensor(0.1072) tensor(0.2321)
# 58 2000 tensor(0.2252) tensor(0.2335)
# 58 3000 tensor(0.2092) tensor(0.2317)
# Removing:./trained_VDNN_52_D_4_30_theta_shuffling.dat
# ./trained_VDNN_58_D_4_30_theta_shuffling.dat
# 59 0 tensor(0.1651) tensor(0.2331)
# 59 1000 tensor(0.1934) tensor(0.2309)
# 59 2000 tensor(0.1305) tensor(0.2303)
# 59 3000 tensor(0.1329) tensor(0.2323)
# Removing:./trained_VDNN_53_D_4_30_theta_shuffling.dat
# ./trained_VDNN_59_D_4_30_theta_shuffling.dat
# 60 0 tensor(0.1300) tensor(0.2315)
# 60 1000 tensor(0.1449) tensor(0.2295)
# 60 2000 tensor(0.1374) tensor(0.2301)
# 60 3000 tensor(0.1594) tensor(0.2299)
# Removing:./trained_VDNN_54_D_4_30_theta_shuffling.dat
# ./trained_VDNN_60_D_4_30_theta_shuffling.dat
# 61 0 tensor(0.1451) tensor(0.2337)
# 61 1000 tensor(0.1494) tensor(0.2283)
# 61 2000 tensor(0.1247) tensor(0.2301)
# 61 3000 tensor(0.1038) tensor(0.2295)
# Removing:./trained_VDNN_55_D_4_30_theta_shuffling.dat
# ./trained_VDNN_61_D_4_30_theta_shuffling.dat
# 62 0 tensor(0.1520) tensor(0.2273)
# 62 1000 tensor(0.2002) tensor(0.2292)
# 62 2000 tensor(0.1420) tensor(0.2279)
# 62 3000 tensor(0.1254) tensor(0.2293)
# Removing:./trained_VDNN_56_D_4_30_theta_shuffling.dat
# ./trained_VDNN_62_D_4_30_theta_shuffling.dat
# 63 0 tensor(0.1818) tensor(0.2280)
# 63 1000 tensor(0.1718) tensor(0.2280)
# 63 2000 tensor(0.1398) tensor(0.2290)
# 63 3000 tensor(0.1608) tensor(0.2273)
# Removing:./trained_VDNN_57_D_4_30_theta_shuffling.dat
# ./trained_VDNN_63_D_4_30_theta_shuffling.dat
# 64 0 tensor(0.1658) tensor(0.2277)
# 64 1000 tensor(0.1815) tensor(0.2282)
# 64 2000 tensor(0.2233) tensor(0.2283)
# 64 3000 tensor(0.1216) tensor(0.2260)
# Removing:./trained_VDNN_58_D_4_30_theta_shuffling.dat
# ./trained_VDNN_64_D_4_30_theta_shuffling.dat
# 65 0 tensor(0.2204) tensor(0.2275)
# 65 1000 tensor(0.1284) tensor(0.2263)
# 65 2000 tensor(0.1804) tensor(0.2263)
# 65 3000 tensor(0.1537) tensor(0.2279)
# Removing:./trained_VDNN_59_D_4_30_theta_shuffling.dat
# ./trained_VDNN_65_D_4_30_theta_shuffling.dat
# 66 0 tensor(0.2720) tensor(0.2245)
# 66 1000 tensor(0.1302) tensor(0.2269)
# 66 2000 tensor(0.1256) tensor(0.2248)
# 66 3000 tensor(0.1581) tensor(0.2252)
# Removing:./trained_VDNN_60_D_4_30_theta_shuffling.dat
# ./trained_VDNN_66_D_4_30_theta_shuffling.dat
# 67 0 tensor(0.2202) tensor(0.2247)
# 67 1000 tensor(0.1852) tensor(0.2233)
# 67 2000 tensor(0.1416) tensor(0.2249)
# 67 3000 tensor(0.1091) tensor(0.2258)
# Removing:./trained_VDNN_61_D_4_30_theta_shuffling.dat
# ./trained_VDNN_67_D_4_30_theta_shuffling.dat
# 68 0 tensor(0.1177) tensor(0.2237)
# 68 1000 tensor(0.1454) tensor(0.2252)
# 68 2000 tensor(0.1354) tensor(0.2225)
# 68 3000 tensor(0.1191) tensor(0.2258)
# Removing:./trained_VDNN_62_D_4_30_theta_shuffling.dat
# ./trained_VDNN_68_D_4_30_theta_shuffling.dat
# 69 0 tensor(0.1295) tensor(0.2248)
# 69 1000 tensor(0.1979) tensor(0.2253)
# 69 2000 tensor(0.1595) tensor(0.2222)
# 69 3000 tensor(0.1696) tensor(0.2215)
# Removing:./trained_VDNN_63_D_4_30_theta_shuffling.dat
# ./trained_VDNN_69_D_4_30_theta_shuffling.dat
# 70 0 tensor(0.1636) tensor(0.2227)
# 70 1000 tensor(0.1308) tensor(0.2236)
# 70 2000 tensor(0.1312) tensor(0.2235)
# 70 3000 tensor(0.1710) tensor(0.2224)
# Removing:./trained_VDNN_64_D_4_30_theta_shuffling.dat
# ./trained_VDNN_70_D_4_30_theta_shuffling.dat
# 71 0 tensor(0.1136) tensor(0.2215)
# 71 1000 tensor(0.1446) tensor(0.2233)
# 71 2000 tensor(0.1984) tensor(0.2246)
# 71 3000 tensor(0.1371) tensor(0.2216)
# Removing:./trained_VDNN_65_D_4_30_theta_shuffling.dat
# ./trained_VDNN_71_D_4_30_theta_shuffling.dat
# 72 0 tensor(0.1171) tensor(0.2208)
# 72 1000 tensor(0.1231) tensor(0.2228)
# 72 2000 tensor(0.1722) tensor(0.2209)
# 72 3000 tensor(0.1214) tensor(0.2221)
# Removing:./trained_VDNN_66_D_4_30_theta_shuffling.dat
# ./trained_VDNN_72_D_4_30_theta_shuffling.dat
# 73 0 tensor(0.1381) tensor(0.2224)
# 73 1000 tensor(0.1230) tensor(0.2232)
# 73 2000 tensor(0.1045) tensor(0.2203)
# 73 3000 tensor(0.2120) tensor(0.2194)
# Removing:./trained_VDNN_67_D_4_30_theta_shuffling.dat
# ./trained_VDNN_73_D_4_30_theta_shuffling.dat
# 74 0 tensor(0.1372) tensor(0.2204)
# 74 1000 tensor(0.2197) tensor(0.2204)
# 74 2000 tensor(0.1677) tensor(0.2215)
# 74 3000 tensor(0.1210) tensor(0.2212)
# Removing:./trained_VDNN_68_D_4_30_theta_shuffling.dat
# ./trained_VDNN_74_D_4_30_theta_shuffling.dat
# 75 0 tensor(0.1295) tensor(0.2206)
# 75 1000 tensor(0.1328) tensor(0.2221)
# 75 2000 tensor(0.1329) tensor(0.2208)
# 75 3000 tensor(0.1533) tensor(0.2218)
# Removing:./trained_VDNN_69_D_4_30_theta_shuffling.dat
# ./trained_VDNN_75_D_4_30_theta_shuffling.dat
# 76 0 tensor(0.1406) tensor(0.2202)
# 76 1000 tensor(0.1286) tensor(0.2195)
# 76 2000 tensor(0.0893) tensor(0.2208)
# 76 3000 tensor(0.1517) tensor(0.2231)
# Removing:./trained_VDNN_70_D_4_30_theta_shuffling.dat
# ./trained_VDNN_76_D_4_30_theta_shuffling.dat
# 77 0 tensor(0.1265) tensor(0.2186)
# 77 1000 tensor(0.1299) tensor(0.2223)
# 77 2000 tensor(0.2602) tensor(0.2202)
# 77 3000 tensor(0.1532) tensor(0.2225)
# Removing:./trained_VDNN_71_D_4_30_theta_shuffling.dat
# ./trained_VDNN_77_D_4_30_theta_shuffling.dat
# 78 0 tensor(0.1806) tensor(0.2210)
# 78 1000 tensor(0.1445) tensor(0.2198)
# 78 2000 tensor(0.1144) tensor(0.2181)
# 78 3000 tensor(0.1439) tensor(0.2214)
# Removing:./trained_VDNN_72_D_4_30_theta_shuffling.dat
# ./trained_VDNN_78_D_4_30_theta_shuffling.dat
# 79 0 tensor(0.0997) tensor(0.2189)
# 79 1000 tensor(0.2735) tensor(0.2186)
# 79 2000 tensor(0.2001) tensor(0.2205)
# 79 3000 tensor(0.1371) tensor(0.2181)
# Removing:./trained_VDNN_73_D_4_30_theta_shuffling.dat
# ./trained_VDNN_79_D_4_30_theta_shuffling.dat
# 80 0 tensor(0.1287) tensor(0.2187)
# 80 1000 tensor(0.1101) tensor(0.2190)
# 80 2000 tensor(0.2002) tensor(0.2187)
# 80 3000 tensor(0.1163) tensor(0.2196)
# Removing:./trained_VDNN_74_D_4_30_theta_shuffling.dat
# ./trained_VDNN_80_D_4_30_theta_shuffling.dat
# 81 0 tensor(0.0956) tensor(0.2188)
# 81 1000 tensor(0.1757) tensor(0.2186)
# 81 2000 tensor(0.1639) tensor(0.2176)
# 81 3000 tensor(0.0949) tensor(0.2177)
# Removing:./trained_VDNN_75_D_4_30_theta_shuffling.dat
# ./trained_VDNN_81_D_4_30_theta_shuffling.dat
# 82 0 tensor(0.1141) tensor(0.2200)
# 82 1000 tensor(0.1324) tensor(0.2192)
# 82 2000 tensor(0.1294) tensor(0.2172)
# 82 3000 tensor(0.1225) tensor(0.2198)
# Removing:./trained_VDNN_76_D_4_30_theta_shuffling.dat
# ./trained_VDNN_82_D_4_30_theta_shuffling.dat
# 83 0 tensor(0.1575) tensor(0.2223)
# 83 1000 tensor(0.1292) tensor(0.2176)
# 83 2000 tensor(0.1228) tensor(0.2195)
# 83 3000 tensor(0.1572) tensor(0.2183)
# Removing:./trained_VDNN_77_D_4_30_theta_shuffling.dat
# ./trained_VDNN_83_D_4_30_theta_shuffling.dat
# 84 0 tensor(0.1144) tensor(0.2198)
# 84 1000 tensor(0.1144) tensor(0.2173)
# 84 2000 tensor(0.0821) tensor(0.2170)
# 84 3000 tensor(0.2105) tensor(0.2167)
# Removing:./trained_VDNN_78_D_4_30_theta_shuffling.dat
# ./trained_VDNN_84_D_4_30_theta_shuffling.dat
# 85 0 tensor(0.1142) tensor(0.2174)
# 85 1000 tensor(0.1197) tensor(0.2163)
# 85 2000 tensor(0.1702) tensor(0.2169)
# 85 3000 tensor(0.1053) tensor(0.2166)
# Removing:./trained_VDNN_79_D_4_30_theta_shuffling.dat
# ./trained_VDNN_85_D_4_30_theta_shuffling.dat
# 86 0 tensor(0.0951) tensor(0.2162)
# 86 1000 tensor(0.1453) tensor(0.2194)
# 86 2000 tensor(0.1543) tensor(0.2167)
# 86 3000 tensor(0.1351) tensor(0.2179)
# Removing:./trained_VDNN_80_D_4_30_theta_shuffling.dat
# ./trained_VDNN_86_D_4_30_theta_shuffling.dat
# 87 0 tensor(0.1423) tensor(0.2164)
# 87 1000 tensor(0.1395) tensor(0.2160)
# 87 2000 tensor(0.1018) tensor(0.2176)
# 87 3000 tensor(0.1328) tensor(0.2210)
# Removing:./trained_VDNN_81_D_4_30_theta_shuffling.dat
# ./trained_VDNN_87_D_4_30_theta_shuffling.dat
# 88 0 tensor(0.1357) tensor(0.2178)
# 88 1000 tensor(0.0927) tensor(0.2206)
# 88 2000 tensor(0.1442) tensor(0.2194)
# 88 3000 tensor(0.2057) tensor(0.2179)
# Removing:./trained_VDNN_82_D_4_30_theta_shuffling.dat
# ./trained_VDNN_88_D_4_30_theta_shuffling.dat
# 89 0 tensor(0.1519) tensor(0.2182)
# 89 1000 tensor(0.0842) tensor(0.2172)
# 89 2000 tensor(0.1097) tensor(0.2166)
# 89 3000 tensor(0.1386) tensor(0.2181)
# Removing:./trained_VDNN_83_D_4_30_theta_shuffling.dat
# ./trained_VDNN_89_D_4_30_theta_shuffling.dat
# 90 0 tensor(0.1390) tensor(0.2157)
# 90 1000 tensor(0.1663) tensor(0.2160)
# 90 2000 tensor(0.1760) tensor(0.2181)
# 90 3000 tensor(0.1013) tensor(0.2158)
# Removing:./trained_VDNN_84_D_4_30_theta_shuffling.dat
# ./trained_VDNN_90_D_4_30_theta_shuffling.dat
# 91 0 tensor(0.1341) tensor(0.2175)
# 91 1000 tensor(0.1654) tensor(0.2167)
# 91 2000 tensor(0.1086) tensor(0.2154)
# 91 3000 tensor(0.1354) tensor(0.2158)
# Removing:./trained_VDNN_85_D_4_30_theta_shuffling.dat
# ./trained_VDNN_91_D_4_30_theta_shuffling.dat
# 92 0 tensor(0.1233) tensor(0.2142)
# 92 1000 tensor(0.1661) tensor(0.2151)
# 92 2000 tensor(0.1287) tensor(0.2154)
# 92 3000 tensor(0.1276) tensor(0.2151)
# Removing:./trained_VDNN_86_D_4_30_theta_shuffling.dat
# ./trained_VDNN_92_D_4_30_theta_shuffling.dat
# 93 0 tensor(0.1405) tensor(0.2146)
# 93 1000 tensor(0.2045) tensor(0.2151)
# 93 2000 tensor(0.1938) tensor(0.2148)
# 93 3000 tensor(0.1297) tensor(0.2148)
# Removing:./trained_VDNN_87_D_4_30_theta_shuffling.dat
# ./trained_VDNN_93_D_4_30_theta_shuffling.dat
# 94 0 tensor(0.1301) tensor(0.2149)
# 94 1000 tensor(0.0975) tensor(0.2156)
# 94 2000 tensor(0.1583) tensor(0.2211)
# 94 3000 tensor(0.1756) tensor(0.2140)
# Removing:./trained_VDNN_88_D_4_30_theta_shuffling.dat
# ./trained_VDNN_94_D_4_30_theta_shuffling.dat
# 95 0 tensor(0.1332) tensor(0.2139)
# 95 1000 tensor(0.1378) tensor(0.2142)
# 95 2000 tensor(0.1643) tensor(0.2149)
# 95 3000 tensor(0.1674) tensor(0.2143)
# Removing:./trained_VDNN_89_D_4_30_theta_shuffling.dat
# ./trained_VDNN_95_D_4_30_theta_shuffling.dat
# 96 0 tensor(0.1386) tensor(0.2139)
# 96 1000 tensor(0.1524) tensor(0.2146)
# 96 2000 tensor(0.1387) tensor(0.2149)
# 96 3000 tensor(0.1509) tensor(0.2164)
# Removing:./trained_VDNN_90_D_4_30_theta_shuffling.dat
# ./trained_VDNN_96_D_4_30_theta_shuffling.dat
# 97 0 tensor(0.1440) tensor(0.2147)
# 97 1000 tensor(0.1378) tensor(0.2134)
# 97 2000 tensor(0.1366) tensor(0.2149)
# 97 3000 tensor(0.1105) tensor(0.2185)
# Removing:./trained_VDNN_91_D_4_30_theta_shuffling.dat
# ./trained_VDNN_97_D_4_30_theta_shuffling.dat
# 98 0 tensor(0.1219) tensor(0.2156)
# 98 1000 tensor(0.2155) tensor(0.2176)
# 98 2000 tensor(0.0704) tensor(0.2162)
# 98 3000 tensor(0.1649) tensor(0.2165)
# Removing:./trained_VDNN_92_D_4_30_theta_shuffling.dat
# ./trained_VDNN_98_D_4_30_theta_shuffling.dat
# 99 0 tensor(0.0957) tensor(0.2142)
# 99 1000 tensor(0.1411) tensor(0.2165)
# 99 2000 tensor(0.2014) tensor(0.2131)
# 99 3000 tensor(0.1627) tensor(0.2149)
# Removing:./trained_VDNN_93_D_4_30_theta_shuffling.dat
# ./trained_VDNN_99_D_4_30_theta_shuffling.dat
# 100 0 tensor(0.1666) tensor(0.2159)
# 100 1000 tensor(0.1730) tensor(0.2151)
# 100 2000 tensor(0.1551) tensor(0.2126)
# 100 3000 tensor(0.1535) tensor(0.2132)
# Removing:./trained_VDNN_94_D_4_30_theta_shuffling.dat
# ./trained_VDNN_100_D_4_30_theta_shuffling.dat
# 101 0 tensor(0.1891) tensor(0.2150)
# 101 1000 tensor(0.1360) tensor(0.2138)
# 101 2000 tensor(0.1915) tensor(0.2138)
# 101 3000 tensor(0.1323) tensor(0.2132)
# Removing:./trained_VDNN_95_D_4_30_theta_shuffling.dat
# ./trained_VDNN_101_D_4_30_theta_shuffling.dat
# 102 0 tensor(0.1655) tensor(0.2148)
# 102 1000 tensor(0.1557) tensor(0.2139)
# 102 2000 tensor(0.1643) tensor(0.2128)
# 102 3000 tensor(0.1351) tensor(0.2123)
# Removing:./trained_VDNN_96_D_4_30_theta_shuffling.dat
# ./trained_VDNN_102_D_4_30_theta_shuffling.dat
# 103 0 tensor(0.1313) tensor(0.2146)
# 103 1000 tensor(0.1619) tensor(0.2140)
# 103 2000 tensor(0.1423) tensor(0.2131)
# 103 3000 tensor(0.1887) tensor(0.2138)
# Removing:./trained_VDNN_97_D_4_30_theta_shuffling.dat
# ./trained_VDNN_103_D_4_30_theta_shuffling.dat
# 104 0 tensor(0.0982) tensor(0.2133)
# 104 1000 tensor(0.1391) tensor(0.2122)
# 104 2000 tensor(0.0965) tensor(0.2141)
# 104 3000 tensor(0.1198) tensor(0.2155)
# Removing:./trained_VDNN_98_D_4_30_theta_shuffling.dat
# ./trained_VDNN_104_D_4_30_theta_shuffling.dat
# 105 0 tensor(0.0991) tensor(0.2147)
# 105 1000 tensor(0.1412) tensor(0.2154)
# 105 2000 tensor(0.1243) tensor(0.2120)
# 105 3000 tensor(0.1235) tensor(0.2127)
# Removing:./trained_VDNN_99_D_4_30_theta_shuffling.dat
# ./trained_VDNN_105_D_4_30_theta_shuffling.dat
# 106 0 tensor(0.1086) tensor(0.2143)
# 106 1000 tensor(0.1345) tensor(0.2126)
# 106 2000 tensor(0.1298) tensor(0.2120)
# 106 3000 tensor(0.1433) tensor(0.2128)
# Removing:./trained_VDNN_100_D_4_30_theta_shuffling.dat
# ./trained_VDNN_106_D_4_30_theta_shuffling.dat
# 107 0 tensor(0.1551) tensor(0.2132)
# 107 1000 tensor(0.1242) tensor(0.2124)
# 107 2000 tensor(0.1857) tensor(0.2121)
# 107 3000 tensor(0.1035) tensor(0.2126)
# Removing:./trained_VDNN_101_D_4_30_theta_shuffling.dat
# ./trained_VDNN_107_D_4_30_theta_shuffling.dat
# 108 0 tensor(0.1851) tensor(0.2124)
# 108 1000 tensor(0.0894) tensor(0.2133)
# 108 2000 tensor(0.1427) tensor(0.2135)
# 108 3000 tensor(0.2067) tensor(0.2143)
# Removing:./trained_VDNN_102_D_4_30_theta_shuffling.dat
# ./trained_VDNN_108_D_4_30_theta_shuffling.dat
# 109 0 tensor(0.1221) tensor(0.2147)
# 109 1000 tensor(0.1612) tensor(0.2120)
# 109 2000 tensor(0.1470) tensor(0.2136)
# 109 3000 tensor(0.0970) tensor(0.2177)
# Removing:./trained_VDNN_103_D_4_30_theta_shuffling.dat
# ./trained_VDNN_109_D_4_30_theta_shuffling.dat
# 110 0 tensor(0.0903) tensor(0.2126)
# 110 1000 tensor(0.0797) tensor(0.2123)
# 110 2000 tensor(0.0808) tensor(0.2119)
# 110 3000 tensor(0.1665) tensor(0.2138)
# Removing:./trained_VDNN_104_D_4_30_theta_shuffling.dat
# ./trained_VDNN_110_D_4_30_theta_shuffling.dat
# 111 0 tensor(0.2267) tensor(0.2116)
# 111 1000 tensor(0.1739) tensor(0.2117)
# 111 2000 tensor(0.1700) tensor(0.2142)
# 111 3000 tensor(0.1640) tensor(0.2118)
# Removing:./trained_VDNN_105_D_4_30_theta_shuffling.dat
# ./trained_VDNN_111_D_4_30_theta_shuffling.dat
# 112 0 tensor(0.1285) tensor(0.2105)
# 112 1000 tensor(0.1277) tensor(0.2131)
# 112 2000 tensor(0.1423) tensor(0.2134)
# 112 3000 tensor(0.0931) tensor(0.2144)
# Removing:./trained_VDNN_106_D_4_30_theta_shuffling.dat
# ./trained_VDNN_112_D_4_30_theta_shuffling.dat
# 113 0 tensor(0.1406) tensor(0.2118)
# 113 1000 tensor(0.1297) tensor(0.2112)
# 113 2000 tensor(0.1107) tensor(0.2109)
# 113 3000 tensor(0.1376) tensor(0.2123)
# Removing:./trained_VDNN_107_D_4_30_theta_shuffling.dat
# ./trained_VDNN_113_D_4_30_theta_shuffling.dat
# 114 0 tensor(0.1229) tensor(0.2141)
# 114 1000 tensor(0.1787) tensor(0.2119)
# 114 2000 tensor(0.1269) tensor(0.2117)
# 114 3000 tensor(0.1287) tensor(0.2106)
# Removing:./trained_VDNN_108_D_4_30_theta_shuffling.dat
# ./trained_VDNN_114_D_4_30_theta_shuffling.dat
# 115 0 tensor(0.1151) tensor(0.2117)
# 115 1000 tensor(0.1697) tensor(0.2108)
# 115 2000 tensor(0.1045) tensor(0.2110)
# 115 3000 tensor(0.1321) tensor(0.2114)
# Removing:./trained_VDNN_109_D_4_30_theta_shuffling.dat
# ./trained_VDNN_115_D_4_30_theta_shuffling.dat
# 116 0 tensor(0.1900) tensor(0.2099)
# 116 1000 tensor(0.1239) tensor(0.2101)
# 116 2000 tensor(0.1507) tensor(0.2124)
# 116 3000 tensor(0.1209) tensor(0.2112)
# Removing:./trained_VDNN_110_D_4_30_theta_shuffling.dat
# ./trained_VDNN_116_D_4_30_theta_shuffling.dat
# 117 0 tensor(0.1333) tensor(0.2122)
# 117 1000 tensor(0.1333) tensor(0.2104)
# 117 2000 tensor(0.1135) tensor(0.2112)
# 117 3000 tensor(0.2481) tensor(0.2163)
# Removing:./trained_VDNN_111_D_4_30_theta_shuffling.dat
# ./trained_VDNN_117_D_4_30_theta_shuffling.dat
# 118 0 tensor(0.1519) tensor(0.2118)
# 118 1000 tensor(0.1739) tensor(0.2112)
# 118 2000 tensor(0.1529) tensor(0.2123)
# 118 3000 tensor(0.1439) tensor(0.2113)
# Removing:./trained_VDNN_112_D_4_30_theta_shuffling.dat
# ./trained_VDNN_118_D_4_30_theta_shuffling.dat
# 119 0 tensor(0.1932) tensor(0.2115)
# 119 1000 tensor(0.1570) tensor(0.2104)
# 119 2000 tensor(0.1506) tensor(0.2104)
# 119 3000 tensor(0.1662) tensor(0.2117)
# Removing:./trained_VDNN_113_D_4_30_theta_shuffling.dat
# ./trained_VDNN_119_D_4_30_theta_shuffling.dat
# 120 0 tensor(0.0894) tensor(0.2133)
# 120 1000 tensor(0.1672) tensor(0.2096)
# 120 2000 tensor(0.1843) tensor(0.2106)
# 120 3000 tensor(0.2611) tensor(0.2118)
# Removing:./trained_VDNN_114_D_4_30_theta_shuffling.dat
# ./trained_VDNN_120_D_4_30_theta_shuffling.dat
# 121 0 tensor(0.1625) tensor(0.2109)
# 121 1000 tensor(0.1524) tensor(0.2106)
# 121 2000 tensor(0.1204) tensor(0.2133)
# 121 3000 tensor(0.2004) tensor(0.2098)
# Removing:./trained_VDNN_115_D_4_30_theta_shuffling.dat
# ./trained_VDNN_121_D_4_30_theta_shuffling.dat
# 122 0 tensor(0.0811) tensor(0.2136)
# 122 1000 tensor(0.1633) tensor(0.2095)
# 122 2000 tensor(0.1265) tensor(0.2097)
# 122 3000 tensor(0.1235) tensor(0.2118)
# Removing:./trained_VDNN_116_D_4_30_theta_shuffling.dat
# ./trained_VDNN_122_D_4_30_theta_shuffling.dat
# 123 0 tensor(0.1190) tensor(0.2094)
# 123 1000 tensor(0.1557) tensor(0.2112)
# 123 2000 tensor(0.1562) tensor(0.2113)
# 123 3000 tensor(0.1364) tensor(0.2111)
# Removing:./trained_VDNN_117_D_4_30_theta_shuffling.dat
# ./trained_VDNN_123_D_4_30_theta_shuffling.dat
# 124 0 tensor(0.1766) tensor(0.2136)
# 124 1000 tensor(0.1477) tensor(0.2102)
# 124 2000 tensor(0.0904) tensor(0.2107)
# 124 3000 tensor(0.1273) tensor(0.2143)
# Removing:./trained_VDNN_118_D_4_30_theta_shuffling.dat
# ./trained_VDNN_124_D_4_30_theta_shuffling.dat
# 125 0 tensor(0.1283) tensor(0.2112)
# 125 1000 tensor(0.1512) tensor(0.2092)
# 125 2000 tensor(0.1578) tensor(0.2112)
# 125 3000 tensor(0.1672) tensor(0.2094)
# Removing:./trained_VDNN_119_D_4_30_theta_shuffling.dat
# ./trained_VDNN_125_D_4_30_theta_shuffling.dat
# 126 0 tensor(0.1510) tensor(0.2095)
# 126 1000 tensor(0.1211) tensor(0.2108)
# 126 2000 tensor(0.1124) tensor(0.2097)
# 126 3000 tensor(0.2089) tensor(0.2096)
# Removing:./trained_VDNN_120_D_4_30_theta_shuffling.dat
# ./trained_VDNN_126_D_4_30_theta_shuffling.dat
# 127 0 tensor(0.1593) tensor(0.2096)
# 127 1000 tensor(0.1491) tensor(0.2098)
# 127 2000 tensor(0.1243) tensor(0.2110)
# 127 3000 tensor(0.0959) tensor(0.2149)
# Removing:./trained_VDNN_121_D_4_30_theta_shuffling.dat
# ./trained_VDNN_127_D_4_30_theta_shuffling.dat
# 128 0 tensor(0.1306) tensor(0.2107)
# 128 1000 tensor(0.1363) tensor(0.2111)
# 128 2000 tensor(0.1079) tensor(0.2109)
# 128 3000 tensor(0.1725) tensor(0.2088)
# Removing:./trained_VDNN_122_D_4_30_theta_shuffling.dat
# ./trained_VDNN_128_D_4_30_theta_shuffling.dat
# 129 0 tensor(0.1248) tensor(0.2106)
# 129 1000 tensor(0.1455) tensor(0.2089)
# 129 2000 tensor(0.1851) tensor(0.2097)
# 129 3000 tensor(0.1591) tensor(0.2094)
# Removing:./trained_VDNN_123_D_4_30_theta_shuffling.dat
# ./trained_VDNN_129_D_4_30_theta_shuffling.dat
# 130 0 tensor(0.1601) tensor(0.2134)
# 130 1000 tensor(0.1532) tensor(0.2097)
# 130 2000 tensor(0.1992) tensor(0.2124)
# 130 3000 tensor(0.2432) tensor(0.2081)
# Removing:./trained_VDNN_124_D_4_30_theta_shuffling.dat
# ./trained_VDNN_130_D_4_30_theta_shuffling.dat
# 131 0 tensor(0.1054) tensor(0.2107)
# 131 1000 tensor(0.1270) tensor(0.2090)
# 131 2000 tensor(0.1279) tensor(0.2091)
# 131 3000 tensor(0.2052) tensor(0.2127)
# Removing:./trained_VDNN_125_D_4_30_theta_shuffling.dat
# ./trained_VDNN_131_D_4_30_theta_shuffling.dat
# 132 0 tensor(0.1320) tensor(0.2099)
# 132 1000 tensor(0.1304) tensor(0.2090)
# 132 2000 tensor(0.1606) tensor(0.2104)
# 132 3000 tensor(0.1279) tensor(0.2131)
# Removing:./trained_VDNN_126_D_4_30_theta_shuffling.dat
# ./trained_VDNN_132_D_4_30_theta_shuffling.dat
# 133 0 tensor(0.1994) tensor(0.2079)
# 133 1000 tensor(0.1191) tensor(0.2090)
# 133 2000 tensor(0.1703) tensor(0.2081)
# 133 3000 tensor(0.1621) tensor(0.2144)
# Removing:./trained_VDNN_127_D_4_30_theta_shuffling.dat
# ./trained_VDNN_133_D_4_30_theta_shuffling.dat
# 134 0 tensor(0.2334) tensor(0.2085)
# 134 1000 tensor(0.1454) tensor(0.2084)
# 134 2000 tensor(0.2382) tensor(0.2097)
# 134 3000 tensor(0.0868) tensor(0.2081)
# Removing:./trained_VDNN_128_D_4_30_theta_shuffling.dat
# ./trained_VDNN_134_D_4_30_theta_shuffling.dat
# 135 0 tensor(0.1949) tensor(0.2087)
# 135 1000 tensor(0.1544) tensor(0.2085)
# 135 2000 tensor(0.1334) tensor(0.2083)
# 135 3000 tensor(0.0697) tensor(0.2091)
# Removing:./trained_VDNN_129_D_4_30_theta_shuffling.dat
# ./trained_VDNN_135_D_4_30_theta_shuffling.dat
# 136 0 tensor(0.1455) tensor(0.2080)
# 136 1000 tensor(0.2067) tensor(0.2096)
# 136 2000 tensor(0.0828) tensor(0.2077)
# 136 3000 tensor(0.1150) tensor(0.2109)
# Removing:./trained_VDNN_130_D_4_30_theta_shuffling.dat
# ./trained_VDNN_136_D_4_30_theta_shuffling.dat
# 137 0 tensor(0.1612) tensor(0.2074)
# 137 1000 tensor(0.1061) tensor(0.2121)
# 137 2000 tensor(0.1137) tensor(0.2084)
# 137 3000 tensor(0.1664) tensor(0.2089)
# Removing:./trained_VDNN_131_D_4_30_theta_shuffling.dat
# ./trained_VDNN_137_D_4_30_theta_shuffling.dat
# 138 0 tensor(0.1293) tensor(0.2081)
# 138 1000 tensor(0.1202) tensor(0.2077)
# 138 2000 tensor(0.1639) tensor(0.2080)
# 138 3000 tensor(0.1892) tensor(0.2092)
# Removing:./trained_VDNN_132_D_4_30_theta_shuffling.dat
# ./trained_VDNN_138_D_4_30_theta_shuffling.dat
# 139 0 tensor(0.1165) tensor(0.2112)
# 139 1000 tensor(0.1523) tensor(0.2083)
# 139 2000 tensor(0.0704) tensor(0.2098)
# 139 3000 tensor(0.1078) tensor(0.2086)
# Removing:./trained_VDNN_133_D_4_30_theta_shuffling.dat
# ./trained_VDNN_139_D_4_30_theta_shuffling.dat
# 140 0 tensor(0.1496) tensor(0.2102)
# 140 1000 tensor(0.1698) tensor(0.2070)
# 140 2000 tensor(0.1387) tensor(0.2069)
# 140 3000 tensor(0.1187) tensor(0.2086)
# Removing:./trained_VDNN_134_D_4_30_theta_shuffling.dat
# ./trained_VDNN_140_D_4_30_theta_shuffling.dat
# 141 0 tensor(0.1581) tensor(0.2106)
# 141 1000 tensor(0.1654) tensor(0.2075)
# 141 2000 tensor(0.1315) tensor(0.2100)
# 141 3000 tensor(0.1182) tensor(0.2078)
# Removing:./trained_VDNN_135_D_4_30_theta_shuffling.dat
# ./trained_VDNN_141_D_4_30_theta_shuffling.dat
# 142 0 tensor(0.2236) tensor(0.2085)
# 142 1000 tensor(0.1237) tensor(0.2082)
# 142 2000 tensor(0.1512) tensor(0.2094)
# 142 3000 tensor(0.1469) tensor(0.2087)
# Removing:./trained_VDNN_136_D_4_30_theta_shuffling.dat
# ./trained_VDNN_142_D_4_30_theta_shuffling.dat
# 143 0 tensor(0.0965) tensor(0.2079)
# 143 1000 tensor(0.1468) tensor(0.2073)
# 143 2000 tensor(0.1699) tensor(0.2075)
# 143 3000 tensor(0.1055) tensor(0.2091)
# Removing:./trained_VDNN_137_D_4_30_theta_shuffling.dat
# ./trained_VDNN_143_D_4_30_theta_shuffling.dat
# 144 0 tensor(0.1316) tensor(0.2131)
# 144 1000 tensor(0.1800) tensor(0.2086)
# 144 2000 tensor(0.1104) tensor(0.2078)
# 144 3000 tensor(0.0862) tensor(0.2078)
# Removing:./trained_VDNN_138_D_4_30_theta_shuffling.dat
# ./trained_VDNN_144_D_4_30_theta_shuffling.dat
# 145 0 tensor(0.1280) tensor(0.2095)
# 145 1000 tensor(0.0828) tensor(0.2073)
# 145 2000 tensor(0.1523) tensor(0.2075)
# 145 3000 tensor(0.2034) tensor(0.2095)
# Removing:./trained_VDNN_139_D_4_30_theta_shuffling.dat
# ./trained_VDNN_145_D_4_30_theta_shuffling.dat
# 146 0 tensor(0.1511) tensor(0.2100)
# 146 1000 tensor(0.1660) tensor(0.2098)
# 146 2000 tensor(0.1424) tensor(0.2066)
# 146 3000 tensor(0.1460) tensor(0.2073)
# Removing:./trained_VDNN_140_D_4_30_theta_shuffling.dat
# ./trained_VDNN_146_D_4_30_theta_shuffling.dat
# 147 0 tensor(0.1153) tensor(0.2082)
# 147 1000 tensor(0.0985) tensor(0.2066)
# 147 2000 tensor(0.1130) tensor(0.2067)
# 147 3000 tensor(0.1877) tensor(0.2106)
# Removing:./trained_VDNN_141_D_4_30_theta_shuffling.dat
# ./trained_VDNN_147_D_4_30_theta_shuffling.dat
# 148 0 tensor(0.1212) tensor(0.2080)
# 148 1000 tensor(0.1279) tensor(0.2094)
# 148 2000 tensor(0.1017) tensor(0.2090)
# 148 3000 tensor(0.1801) tensor(0.2072)
# Removing:./trained_VDNN_142_D_4_30_theta_shuffling.dat
# ./trained_VDNN_148_D_4_30_theta_shuffling.dat
# 149 0 tensor(0.1375) tensor(0.2079)
# 149 1000 tensor(0.1668) tensor(0.2082)
# 149 2000 tensor(0.1755) tensor(0.2083)
# 149 3000 tensor(0.1840) tensor(0.2066)
# Removing:./trained_VDNN_143_D_4_30_theta_shuffling.dat
# ./trained_VDNN_149_D_4_30_theta_shuffling.dat
# 150 0 tensor(0.1004) tensor(0.2086)
# 150 1000 tensor(0.1075) tensor(0.2114)
# 150 2000 tensor(0.1638) tensor(0.2076)
# 150 3000 tensor(0.0973) tensor(0.2094)
# Removing:./trained_VDNN_144_D_4_30_theta_shuffling.dat
# ./trained_VDNN_150_D_4_30_theta_shuffling.dat
# 151 0 tensor(0.1005) tensor(0.2082)
# 151 1000 tensor(0.1751) tensor(0.2144)
# 151 2000 tensor(0.1536) tensor(0.2073)
# 151 3000 tensor(0.0934) tensor(0.2082)
# Removing:./trained_VDNN_145_D_4_30_theta_shuffling.dat
# ./trained_VDNN_151_D_4_30_theta_shuffling.dat
# 152 0 tensor(0.1325) tensor(0.2074)
# 152 1000 tensor(0.1345) tensor(0.2077)
# 152 2000 tensor(0.1657) tensor(0.2064)
# 152 3000 tensor(0.1352) tensor(0.2064)
# Removing:./trained_VDNN_146_D_4_30_theta_shuffling.dat
# ./trained_VDNN_152_D_4_30_theta_shuffling.dat
# 153 0 tensor(0.1359) tensor(0.2072)
# 153 1000 tensor(0.1177) tensor(0.2071)
# 153 2000 tensor(0.1175) tensor(0.2070)
# 153 3000 tensor(0.1518) tensor(0.2071)
# Removing:./trained_VDNN_147_D_4_30_theta_shuffling.dat
# ./trained_VDNN_153_D_4_30_theta_shuffling.dat
# 154 0 tensor(0.1738) tensor(0.2061)
# 154 1000 tensor(0.1659) tensor(0.2075)
# 154 2000 tensor(0.1050) tensor(0.2066)
# 154 3000 tensor(0.1275) tensor(0.2069)
# Removing:./trained_VDNN_148_D_4_30_theta_shuffling.dat
# ./trained_VDNN_154_D_4_30_theta_shuffling.dat
# 155 0 tensor(0.1452) tensor(0.2079)
# 155 1000 tensor(0.1629) tensor(0.2071)
# 155 2000 tensor(0.1351) tensor(0.2060)
# 155 3000 tensor(0.1052) tensor(0.2079)
# Removing:./trained_VDNN_149_D_4_30_theta_shuffling.dat
# ./trained_VDNN_155_D_4_30_theta_shuffling.dat
# 156 0 tensor(0.1611) tensor(0.2071)
# 156 1000 tensor(0.1488) tensor(0.2097)
# 156 2000 tensor(0.1211) tensor(0.2077)
# 156 3000 tensor(0.1611) tensor(0.2080)
# Removing:./trained_VDNN_150_D_4_30_theta_shuffling.dat
# ./trained_VDNN_156_D_4_30_theta_shuffling.dat
# 157 0 tensor(0.1305) tensor(0.2072)
# 157 1000 tensor(0.1390) tensor(0.2072)
# 157 2000 tensor(0.1198) tensor(0.2073)
# 157 3000 tensor(0.1300) tensor(0.2080)
# Removing:./trained_VDNN_151_D_4_30_theta_shuffling.dat
# ./trained_VDNN_157_D_4_30_theta_shuffling.dat
# 158 0 tensor(0.1799) tensor(0.2089)
# 158 1000 tensor(0.1260) tensor(0.2069)
# 158 2000 tensor(0.1316) tensor(0.2094)
# 158 3000 tensor(0.2212) tensor(0.2077)
# Removing:./trained_VDNN_152_D_4_30_theta_shuffling.dat
# ./trained_VDNN_158_D_4_30_theta_shuffling.dat
# 159 0 tensor(0.1211) tensor(0.2067)
# 159 1000 tensor(0.1167) tensor(0.2098)
# 159 2000 tensor(0.1386) tensor(0.2083)
# 159 3000 tensor(0.1491) tensor(0.2101)
# Removing:./trained_VDNN_153_D_4_30_theta_shuffling.dat
# ./trained_VDNN_159_D_4_30_theta_shuffling.dat
# 160 0 tensor(0.1385) tensor(0.2062)
# 160 1000 tensor(0.1358) tensor(0.2082)
# 160 2000 tensor(0.1136) tensor(0.2094)
# 160 3000 tensor(0.0816) tensor(0.2080)
# Removing:./trained_VDNN_154_D_4_30_theta_shuffling.dat
# ./trained_VDNN_160_D_4_30_theta_shuffling.dat
# 161 0 tensor(0.1224) tensor(0.2080)
# 161 1000 tensor(0.1062) tensor(0.2062)
# 161 2000 tensor(0.1028) tensor(0.2065)
# 161 3000 tensor(0.0925) tensor(0.2090)
# Removing:./trained_VDNN_155_D_4_30_theta_shuffling.dat
# ./trained_VDNN_161_D_4_30_theta_shuffling.dat
# 162 0 tensor(0.1119) tensor(0.2061)
# 162 1000 tensor(0.1475) tensor(0.2068)
# 162 2000 tensor(0.1163) tensor(0.2077)
# 162 3000 tensor(0.1415) tensor(0.2061)
# Removing:./trained_VDNN_156_D_4_30_theta_shuffling.dat
# ./trained_VDNN_162_D_4_30_theta_shuffling.dat
# 163 0 tensor(0.1039) tensor(0.2071)
# 163 1000 tensor(0.1433) tensor(0.2080)
# 163 2000 tensor(0.1671) tensor(0.2073)
# 163 3000 tensor(0.0728) tensor(0.2058)
# Removing:./trained_VDNN_157_D_4_30_theta_shuffling.dat
# ./trained_VDNN_163_D_4_30_theta_shuffling.dat
# 164 0 tensor(0.1302) tensor(0.2074)
# 164 1000 tensor(0.2085) tensor(0.2064)
# 164 2000 tensor(0.1340) tensor(0.2092)
# 164 3000 tensor(0.1745) tensor(0.2065)
# Removing:./trained_VDNN_158_D_4_30_theta_shuffling.dat
# ./trained_VDNN_164_D_4_30_theta_shuffling.dat
# 165 0 tensor(0.1571) tensor(0.2063)
# 165 1000 tensor(0.1319) tensor(0.2057)
# 165 2000 tensor(0.1433) tensor(0.2086)
# 165 3000 tensor(0.1089) tensor(0.2077)
# Removing:./trained_VDNN_159_D_4_30_theta_shuffling.dat
# ./trained_VDNN_165_D_4_30_theta_shuffling.dat
# 166 0 tensor(0.1517) tensor(0.2056)
# 166 1000 tensor(0.1248) tensor(0.2088)
# 166 2000 tensor(0.2039) tensor(0.2049)
# 166 3000 tensor(0.1455) tensor(0.2063)
# Removing:./trained_VDNN_160_D_4_30_theta_shuffling.dat
# ./trained_VDNN_166_D_4_30_theta_shuffling.dat
# 167 0 tensor(0.1092) tensor(0.2079)
# 167 1000 tensor(0.1748) tensor(0.2088)
# 167 2000 tensor(0.1575) tensor(0.2057)
# 167 3000 tensor(0.0927) tensor(0.2067)
# Removing:./trained_VDNN_161_D_4_30_theta_shuffling.dat
# ./trained_VDNN_167_D_4_30_theta_shuffling.dat
# 168 0 tensor(0.1461) tensor(0.2068)
# 168 1000 tensor(0.1151) tensor(0.2062)
# 168 2000 tensor(0.1182) tensor(0.2068)
# 168 3000 tensor(0.1834) tensor(0.2070)
# Removing:./trained_VDNN_162_D_4_30_theta_shuffling.dat
# ./trained_VDNN_168_D_4_30_theta_shuffling.dat
# 169 0 tensor(0.1340) tensor(0.2055)
# 169 1000 tensor(0.1741) tensor(0.2071)
# 169 2000 tensor(0.1034) tensor(0.2127)
# 169 3000 tensor(0.1517) tensor(0.2064)
# Removing:./trained_VDNN_163_D_4_30_theta_shuffling.dat
# ./trained_VDNN_169_D_4_30_theta_shuffling.dat
# 170 0 tensor(0.1838) tensor(0.2054)
# 170 1000 tensor(0.1611) tensor(0.2097)
# 170 2000 tensor(0.1488) tensor(0.2096)
# 170 3000 tensor(0.1375) tensor(0.2087)
# Removing:./trained_VDNN_164_D_4_30_theta_shuffling.dat
# ./trained_VDNN_170_D_4_30_theta_shuffling.dat
# 171 0 tensor(0.1980) tensor(0.2074)
# 171 1000 tensor(0.0844) tensor(0.2059)
# 171 2000 tensor(0.1159) tensor(0.2077)
# 171 3000 tensor(0.1194) tensor(0.2126)
# Removing:./trained_VDNN_165_D_4_30_theta_shuffling.dat
# ./trained_VDNN_171_D_4_30_theta_shuffling.dat
# 172 0 tensor(0.1956) tensor(0.2067)
# 172 1000 tensor(0.1586) tensor(0.2068)
# 172 2000 tensor(0.1403) tensor(0.2067)
# 172 3000 tensor(0.1335) tensor(0.2064)
# Removing:./trained_VDNN_166_D_4_30_theta_shuffling.dat
# ./trained_VDNN_172_D_4_30_theta_shuffling.dat
# 173 0 tensor(0.1281) tensor(0.2085)
# 173 1000 tensor(0.1279) tensor(0.2057)
# 173 2000 tensor(0.2299) tensor(0.2057)
# 173 3000 tensor(0.1364) tensor(0.2057)
# Removing:./trained_VDNN_167_D_4_30_theta_shuffling.dat
# ./trained_VDNN_173_D_4_30_theta_shuffling.dat
# 174 0 tensor(0.1465) tensor(0.2077)
# 174 1000 tensor(0.1917) tensor(0.2051)
# 174 2000 tensor(0.0860) tensor(0.2051)
# 174 3000 tensor(0.1810) tensor(0.2062)
# Removing:./trained_VDNN_168_D_4_30_theta_shuffling.dat
# ./trained_VDNN_174_D_4_30_theta_shuffling.dat
# 175 0 tensor(0.0899) tensor(0.2168)
# 175 1000 tensor(0.0946) tensor(0.2049)
# 175 2000 tensor(0.1099) tensor(0.2054)
# 175 3000 tensor(0.1339) tensor(0.2056)
# Removing:./trained_VDNN_169_D_4_30_theta_shuffling.dat
# ./trained_VDNN_175_D_4_30_theta_shuffling.dat
# 176 0 tensor(0.1655) tensor(0.2082)
# 176 1000 tensor(0.1073) tensor(0.2088)
# 176 2000 tensor(0.1818) tensor(0.2051)
# 176 3000 tensor(0.1341) tensor(0.2070)
# Removing:./trained_VDNN_170_D_4_30_theta_shuffling.dat
# ./trained_VDNN_176_D_4_30_theta_shuffling.dat
# 177 0 tensor(0.0886) tensor(0.2056)
# 177 1000 tensor(0.1106) tensor(0.2091)
# 177 2000 tensor(0.1209) tensor(0.2052)
# 177 3000 tensor(0.1472) tensor(0.2092)
# Removing:./trained_VDNN_171_D_4_30_theta_shuffling.dat
# ./trained_VDNN_177_D_4_30_theta_shuffling.dat
# 178 0 tensor(0.2630) tensor(0.2086)
# 178 1000 tensor(0.0595) tensor(0.2058)
# 178 2000 tensor(0.1138) tensor(0.2054)
# 178 3000 tensor(0.1432) tensor(0.2053)
# Removing:./trained_VDNN_172_D_4_30_theta_shuffling.dat
# ./trained_VDNN_178_D_4_30_theta_shuffling.dat
# 179 0 tensor(0.1270) tensor(0.2052)
# 179 1000 tensor(0.2025) tensor(0.2055)
# 179 2000 tensor(0.1137) tensor(0.2066)
# 179 3000 tensor(0.0787) tensor(0.2060)
# Removing:./trained_VDNN_173_D_4_30_theta_shuffling.dat
# ./trained_VDNN_179_D_4_30_theta_shuffling.dat
# 180 0 tensor(0.1613) tensor(0.2054)
# 180 1000 tensor(0.1822) tensor(0.2056)
# 180 2000 tensor(0.1661) tensor(0.2048)
# 180 3000 tensor(0.0962) tensor(0.2056)
# Removing:./trained_VDNN_174_D_4_30_theta_shuffling.dat
# ./trained_VDNN_180_D_4_30_theta_shuffling.dat
# 181 0 tensor(0.1315) tensor(0.2047)
# 181 1000 tensor(0.1229) tensor(0.2054)
# 181 2000 tensor(0.1589) tensor(0.2049)
# 181 3000 tensor(0.0790) tensor(0.2049)
# Removing:./trained_VDNN_175_D_4_30_theta_shuffling.dat
# ./trained_VDNN_181_D_4_30_theta_shuffling.dat
# 182 0 tensor(0.1217) tensor(0.2054)
# 182 1000 tensor(0.1285) tensor(0.2055)
# 182 2000 tensor(0.1865) tensor(0.2051)
# 182 3000 tensor(0.1482) tensor(0.2046)
# Removing:./trained_VDNN_176_D_4_30_theta_shuffling.dat
# ./trained_VDNN_182_D_4_30_theta_shuffling.dat
# 183 0 tensor(0.2119) tensor(0.2051)
# 183 1000 tensor(0.1350) tensor(0.2053)
# 183 2000 tensor(0.1413) tensor(0.2050)
# 183 3000 tensor(0.1019) tensor(0.2044)
# Removing:./trained_VDNN_177_D_4_30_theta_shuffling.dat
# ./trained_VDNN_183_D_4_30_theta_shuffling.dat
# 184 0 tensor(0.1499) tensor(0.2045)
# 184 1000 tensor(0.1357) tensor(0.2052)
# 184 2000 tensor(0.0981) tensor(0.2050)
# 184 3000 tensor(0.1618) tensor(0.2052)
# Removing:./trained_VDNN_178_D_4_30_theta_shuffling.dat
# ./trained_VDNN_184_D_4_30_theta_shuffling.dat
# 185 0 tensor(0.1375) tensor(0.2049)
# 185 1000 tensor(0.0842) tensor(0.2048)
# 185 2000 tensor(0.1449) tensor(0.2043)
# 185 3000 tensor(0.1268) tensor(0.2047)
# Removing:./trained_VDNN_179_D_4_30_theta_shuffling.dat
# ./trained_VDNN_185_D_4_30_theta_shuffling.dat
# 186 0 tensor(0.1304) tensor(0.2055)
# 186 1000 tensor(0.1297) tensor(0.2049)
# 186 2000 tensor(0.1410) tensor(0.2044)
# 186 3000 tensor(0.1317) tensor(0.2044)
# Removing:./trained_VDNN_180_D_4_30_theta_shuffling.dat
# ./trained_VDNN_186_D_4_30_theta_shuffling.dat
# 187 0 tensor(0.1186) tensor(0.2049)
# 187 1000 tensor(0.1233) tensor(0.2048)
# 187 2000 tensor(0.1472) tensor(0.2051)
# 187 3000 tensor(0.1804) tensor(0.2052)
# Removing:./trained_VDNN_181_D_4_30_theta_shuffling.dat
# ./trained_VDNN_187_D_4_30_theta_shuffling.dat
# 188 0 tensor(0.2039) tensor(0.2052)
# 188 1000 tensor(0.1756) tensor(0.2046)
# 188 2000 tensor(0.1358) tensor(0.2054)
# 188 3000 tensor(0.1481) tensor(0.2052)
# Removing:./trained_VDNN_182_D_4_30_theta_shuffling.dat
# ./trained_VDNN_188_D_4_30_theta_shuffling.dat
# 189 0 tensor(0.1294) tensor(0.2044)
# 189 1000 tensor(0.1069) tensor(0.2048)
# 189 2000 tensor(0.0606) tensor(0.2041)
# 189 3000 tensor(0.1280) tensor(0.2046)
# Removing:./trained_VDNN_183_D_4_30_theta_shuffling.dat
# ./trained_VDNN_189_D_4_30_theta_shuffling.dat
# 190 0 tensor(0.1844) tensor(0.2051)
# 190 1000 tensor(0.1640) tensor(0.2043)
# 190 2000 tensor(0.1761) tensor(0.2051)
# 190 3000 tensor(0.1282) tensor(0.2046)
# Removing:./trained_VDNN_184_D_4_30_theta_shuffling.dat
# ./trained_VDNN_190_D_4_30_theta_shuffling.dat
# 191 0 tensor(0.1885) tensor(0.2046)
# 191 1000 tensor(0.1249) tensor(0.2049)
# 191 2000 tensor(0.1682) tensor(0.2058)
# 191 3000 tensor(0.1307) tensor(0.2051)
# Removing:./trained_VDNN_185_D_4_30_theta_shuffling.dat
# ./trained_VDNN_191_D_4_30_theta_shuffling.dat
# 192 0 tensor(0.0964) tensor(0.2047)
# 192 1000 tensor(0.1194) tensor(0.2039)
# 192 2000 tensor(0.1653) tensor(0.2043)
# 192 3000 tensor(0.1068) tensor(0.2048)
# Removing:./trained_VDNN_186_D_4_30_theta_shuffling.dat
# ./trained_VDNN_192_D_4_30_theta_shuffling.dat
# 193 0 tensor(0.1164) tensor(0.2045)
# ...
# 437 3000 tensor(0.1480) tensor(0.2043)
# Removing:./trained_VDNN_431_D_4_30_theta_shuffling.dat
# ./trained_VDNN_437_D_4_30_theta_shuffling.dat
# 438 0 tensor(0.0995) tensor(0.2043)
# 438 1000 tensor(0.2158) tensor(0.2044)
# 438 2000 tensor(0.1068) tensor(0.2043)
# 438 3000 tensor(0.1149) tensor(0.2043)
# Removing:./trained_VDNN_432_D_4_30_theta_shuffling.dat
# ./trained_VDNN_438_D_4_30_theta_shuffling.dat
# 439 0 tensor(0.1388) tensor(0.2043)
# 439 1000 tensor(0.1660) tensor(0.2043)
# 439 2000 tensor(0.1149) tensor(0.2042)
# 439 3000 tensor(0.1733) tensor(0.2043)
# Removing:./trained_VDNN_433_D_4_30_theta_shuffling.dat
# ./trained_VDNN_439_D_4_30_theta_shuffling.dat
# 440 0 tensor(0.1292) tensor(0.2043)
# 440 1000 tensor(0.1629) tensor(0.2043)
# 440 2000 tensor(0.1241) tensor(0.2043)
# 440 3000 tensor(0.1151) tensor(0.2043)
# Removing:./trained_VDNN_434_D_4_30_theta_shuffling.dat
# ./trained_VDNN_440_D_4_30_theta_shuffling.dat
# 441 0 tensor(0.1395) tensor(0.2043)
# 441 1000 tensor(0.0954) tensor(0.2043)
# 441 2000 tensor(0.1860) tensor(0.2043)
# 441 3000 tensor(0.1561) tensor(0.2044)
# Removing:./trained_VDNN_435_D_4_30_theta_shuffling.dat
# ./trained_VDNN_441_D_4_30_theta_shuffling.dat
# 442 0 tensor(0.1581) tensor(0.2044)
# 442 1000 tensor(0.1035) tensor(0.2043)
# 442 2000 tensor(0.1120) tensor(0.2043)
# 442 3000 tensor(0.0999) tensor(0.2043)
# Removing:./trained_VDNN_436_D_4_30_theta_shuffling.dat
# ./trained_VDNN_442_D_4_30_theta_shuffling.dat
# 443 0 tensor(0.1660) tensor(0.2043)
# 443 1000 tensor(0.1653) tensor(0.2043)
# 443 2000 tensor(0.0990) tensor(0.2043)
# 443 3000 tensor(0.1108) tensor(0.2043)
# Removing:./trained_VDNN_437_D_4_30_theta_shuffling.dat
# ./trained_VDNN_443_D_4_30_theta_shuffling.dat
# 444 0 tensor(0.0853) tensor(0.2043)
# 444 1000 tensor(0.1571) tensor(0.2043)
# 444 2000 tensor(0.1322) tensor(0.2043)
# 444 3000 tensor(0.1360) tensor(0.2043)
# Removing:./trained_VDNN_438_D_4_30_theta_shuffling.dat
# ./trained_VDNN_444_D_4_30_theta_shuffling.dat
# 445 0 tensor(0.1315) tensor(0.2043)
# 445 1000 tensor(0.0977) tensor(0.2043)
# 445 2000 tensor(0.1304) tensor(0.2043)
# 445 3000 tensor(0.1179) tensor(0.2044)
# Removing:./trained_VDNN_439_D_4_30_theta_shuffling.dat
# ./trained_VDNN_445_D_4_30_theta_shuffling.dat
# 446 0 tensor(0.1706) tensor(0.2043)
# 446 1000 tensor(0.1805) tensor(0.2043)
# 446 2000 tensor(0.1416) tensor(0.2043)
# 446 3000 tensor(0.1519) tensor(0.2043)
# Removing:./trained_VDNN_440_D_4_30_theta_shuffling.dat
# ./trained_VDNN_446_D_4_30_theta_shuffling.dat
# 447 0 tensor(0.1164) tensor(0.2043)
# 447 1000 tensor(0.1579) tensor(0.2043)
# 447 2000 tensor(0.1317) tensor(0.2043)
# 447 3000 tensor(0.1779) tensor(0.2042)
# Removing:./trained_VDNN_441_D_4_30_theta_shuffling.dat
# ./trained_VDNN_447_D_4_30_theta_shuffling.dat
# 448 0 tensor(0.1505) tensor(0.2043)
# 448 1000 tensor(0.1395) tensor(0.2042)
# 448 2000 tensor(0.1140) tensor(0.2042)
# 448 3000 tensor(0.1907) tensor(0.2043)
# Removing:./trained_VDNN_442_D_4_30_theta_shuffling.dat
# ./trained_VDNN_448_D_4_30_theta_shuffling.dat
# 449 0 tensor(0.1318) tensor(0.2043)
# 449 1000 tensor(0.1265) tensor(0.2043)
# 449 2000 tensor(0.1353) tensor(0.2043)
# 449 3000 tensor(0.1286) tensor(0.2043)
# Removing:./trained_VDNN_443_D_4_30_theta_shuffling.dat
# ./trained_VDNN_449_D_4_30_theta_shuffling.dat
# 450 0 tensor(0.1574) tensor(0.2043)
# 450 1000 tensor(0.1458) tensor(0.2043)
# 450 2000 tensor(0.1546) tensor(0.2043)
# 450 3000 tensor(0.1509) tensor(0.2043)
# Removing:./trained_VDNN_444_D_4_30_theta_shuffling.dat
# ./trained_VDNN_450_D_4_30_theta_shuffling.dat
# 451 0 tensor(0.1435) tensor(0.2043)
# 451 1000 tensor(0.1469) tensor(0.2043)
# 451 2000 tensor(0.1245) tensor(0.2043)
# 451 3000 tensor(0.1330) tensor(0.2043)
# Removing:./trained_VDNN_445_D_4_30_theta_shuffling.dat
# ./trained_VDNN_451_D_4_30_theta_shuffling.dat
# 452 0 tensor(0.1319) tensor(0.2043)
# 452 1000 tensor(0.1807) tensor(0.2043)
# 452 2000 tensor(0.1317) tensor(0.2043)
# 452 3000 tensor(0.1031) tensor(0.2043)
# Removing:./trained_VDNN_446_D_4_30_theta_shuffling.dat
# ./trained_VDNN_452_D_4_30_theta_shuffling.dat
# 453 0 tensor(0.1593) tensor(0.2043)
# 453 1000 tensor(0.1004) tensor(0.2043)
# 453 2000 tensor(0.1874) tensor(0.2043)
# 453 3000 tensor(0.0928) tensor(0.2043)
# Removing:./trained_VDNN_447_D_4_30_theta_shuffling.dat
# ./trained_VDNN_453_D_4_30_theta_shuffling.dat
# 454 0 tensor(0.2002) tensor(0.2043)
# 454 1000 tensor(0.1520) tensor(0.2043)
# 454 2000 tensor(0.2112) tensor(0.2043)
# 454 3000 tensor(0.1963) tensor(0.2043)
# Removing:./trained_VDNN_448_D_4_30_theta_shuffling.dat
# ./trained_VDNN_454_D_4_30_theta_shuffling.dat
# 455 0 tensor(0.1205) tensor(0.2043)
# 455 1000 tensor(0.0972) tensor(0.2043)
# 455 2000 tensor(0.0868) tensor(0.2043)
# 455 3000 tensor(0.1605) tensor(0.2043)
# Removing:./trained_VDNN_449_D_4_30_theta_shuffling.dat
# ./trained_VDNN_455_D_4_30_theta_shuffling.dat
# 456 0 tensor(0.1151) tensor(0.2043)
# 456 1000 tensor(0.1437) tensor(0.2043)
# 456 2000 tensor(0.1614) tensor(0.2043)
# 456 3000 tensor(0.1617) tensor(0.2043)
# Removing:./trained_VDNN_450_D_4_30_theta_shuffling.dat
# ./trained_VDNN_456_D_4_30_theta_shuffling.dat
# 457 0 tensor(0.0943) tensor(0.2043)
# 457 1000 tensor(0.1494) tensor(0.2043)
# 457 2000 tensor(0.1490) tensor(0.2043)
# 457 3000 tensor(0.1616) tensor(0.2043)
# Removing:./trained_VDNN_451_D_4_30_theta_shuffling.dat
# ./trained_VDNN_457_D_4_30_theta_shuffling.dat
# 458 0 tensor(0.1621) tensor(0.2043)
# 458 1000 tensor(0.1736) tensor(0.2043)
# 458 2000 tensor(0.1421) tensor(0.2043)
# 458 3000 tensor(0.2243) tensor(0.2043)
# Removing:./trained_VDNN_452_D_4_30_theta_shuffling.dat
# ./trained_VDNN_458_D_4_30_theta_shuffling.dat
# 459 0 tensor(0.1620) tensor(0.2043)
# 459 1000 tensor(0.1120) tensor(0.2043)
# 459 2000 tensor(0.1256) tensor(0.2043)
# 459 3000 tensor(0.1248) tensor(0.2043)
# Removing:./trained_VDNN_453_D_4_30_theta_shuffling.dat
# ./trained_VDNN_459_D_4_30_theta_shuffling.dat
# 460 0 tensor(0.1629) tensor(0.2043)
# 460 1000 tensor(0.1343) tensor(0.2043)
# 460 2000 tensor(0.1348) tensor(0.2043)
# 460 3000 tensor(0.1263) tensor(0.2043)
# Removing:./trained_VDNN_454_D_4_30_theta_shuffling.dat
# ./trained_VDNN_460_D_4_30_theta_shuffling.dat
# 461 0 tensor(0.1054) tensor(0.2043)
# 461 1000 tensor(0.1082) tensor(0.2043)
# 461 2000 tensor(0.0882) tensor(0.2043)
# 461 3000 tensor(0.0951) tensor(0.2043)
# Removing:./trained_VDNN_455_D_4_30_theta_shuffling.dat
# ./trained_VDNN_461_D_4_30_theta_shuffling.dat
# 462 0 tensor(0.1317) tensor(0.2043)
# 462 1000 tensor(0.1134) tensor(0.2043)
# 462 2000 tensor(0.1321) tensor(0.2043)
# 462 3000 tensor(0.1257) tensor(0.2043)
# Removing:./trained_VDNN_456_D_4_30_theta_shuffling.dat
# ./trained_VDNN_462_D_4_30_theta_shuffling.dat
# 463 0 tensor(0.1346) tensor(0.2043)
# 463 1000 tensor(0.1491) tensor(0.2043)
# 463 2000 tensor(0.1242) tensor(0.2043)
# 463 3000 tensor(0.1583) tensor(0.2043)
# Removing:./trained_VDNN_457_D_4_30_theta_shuffling.dat
# ./trained_VDNN_463_D_4_30_theta_shuffling.dat
# 464 0 tensor(0.1810) tensor(0.2043)
# 464 1000 tensor(0.2392) tensor(0.2044)
# 464 2000 tensor(0.1137) tensor(0.2043)
# 464 3000 tensor(0.1520) tensor(0.2043)
# Removing:./trained_VDNN_458_D_4_30_theta_shuffling.dat
# ./trained_VDNN_464_D_4_30_theta_shuffling.dat
# 465 0 tensor(0.1744) tensor(0.2043)
# 465 1000 tensor(0.1878) tensor(0.2043)
# 465 2000 tensor(0.1832) tensor(0.2043)
# 465 3000 tensor(0.1357) tensor(0.2043)
# Removing:./trained_VDNN_459_D_4_30_theta_shuffling.dat
# ./trained_VDNN_465_D_4_30_theta_shuffling.dat
# 466 0 tensor(0.1335) tensor(0.2043)
# 466 1000 tensor(0.1858) tensor(0.2043)
# 466 2000 tensor(0.1586) tensor(0.2043)
# 466 3000 tensor(0.1170) tensor(0.2043)
# Removing:./trained_VDNN_460_D_4_30_theta_shuffling.dat
# ./trained_VDNN_466_D_4_30_theta_shuffling.dat
# 467 0 tensor(0.1439) tensor(0.2043)
# 467 1000 tensor(0.1562) tensor(0.2043)
# 467 2000 tensor(0.1654) tensor(0.2043)
# 467 3000 tensor(0.1351) tensor(0.2043)
# Removing:./trained_VDNN_461_D_4_30_theta_shuffling.dat
# ./trained_VDNN_467_D_4_30_theta_shuffling.dat
# 468 0 tensor(0.1345) tensor(0.2043)
# 468 1000 tensor(0.1613) tensor(0.2043)
# 468 2000 tensor(0.0820) tensor(0.2043)
# 468 3000 tensor(0.1164) tensor(0.2043)
# Removing:./trained_VDNN_462_D_4_30_theta_shuffling.dat
# ./trained_VDNN_468_D_4_30_theta_shuffling.dat
# 469 0 tensor(0.1076) tensor(0.2043)
# 469 1000 tensor(0.0711) tensor(0.2043)
# 469 2000 tensor(0.0901) tensor(0.2043)
# 469 3000 tensor(0.1822) tensor(0.2043)
# Removing:./trained_VDNN_463_D_4_30_theta_shuffling.dat
# ./trained_VDNN_469_D_4_30_theta_shuffling.dat
# 470 0 tensor(0.1082) tensor(0.2043)
# 470 1000 tensor(0.1318) tensor(0.2043)
# 470 2000 tensor(0.1228) tensor(0.2043)
# 470 3000 tensor(0.1325) tensor(0.2043)
# Removing:./trained_VDNN_464_D_4_30_theta_shuffling.dat
# ./trained_VDNN_470_D_4_30_theta_shuffling.dat
# 471 0 tensor(0.0915) tensor(0.2043)
# 471 1000 tensor(0.1252) tensor(0.2043)
# 471 2000 tensor(0.1883) tensor(0.2042)
# 471 3000 tensor(0.1154) tensor(0.2042)
# Removing:./trained_VDNN_465_D_4_30_theta_shuffling.dat
# ./trained_VDNN_471_D_4_30_theta_shuffling.dat
# 472 0 tensor(0.1542) tensor(0.2042)
# 472 1000 tensor(0.0883) tensor(0.2043)
# 472 2000 tensor(0.0938) tensor(0.2043)
# 472 3000 tensor(0.1619) tensor(0.2042)
# Removing:./trained_VDNN_466_D_4_30_theta_shuffling.dat
# ./trained_VDNN_472_D_4_30_theta_shuffling.dat
# 473 0 tensor(0.1556) tensor(0.2042)
# 473 1000 tensor(0.1292) tensor(0.2042)
# 473 2000 tensor(0.1443) tensor(0.2042)
# 473 3000 tensor(0.1094) tensor(0.2043)
# Removing:./trained_VDNN_467_D_4_30_theta_shuffling.dat
# ./trained_VDNN_473_D_4_30_theta_shuffling.dat
# 474 0 tensor(0.0936) tensor(0.2042)
# 474 1000 tensor(0.1102) tensor(0.2042)
# 474 2000 tensor(0.1403) tensor(0.2042)
# 474 3000 tensor(0.1310) tensor(0.2042)
# Removing:./trained_VDNN_468_D_4_30_theta_shuffling.dat
# ./trained_VDNN_474_D_4_30_theta_shuffling.dat
# 475 0 tensor(0.1043) tensor(0.2042)
# 475 1000 tensor(0.0663) tensor(0.2042)
# 475 2000 tensor(0.1442) tensor(0.2042)
# 475 3000 tensor(0.1087) tensor(0.2042)
# Removing:./trained_VDNN_469_D_4_30_theta_shuffling.dat
# ./trained_VDNN_475_D_4_30_theta_shuffling.dat
# 476 0 tensor(0.1185) tensor(0.2042)
# 476 1000 tensor(0.0742) tensor(0.2042)
# 476 2000 tensor(0.0697) tensor(0.2042)
# 476 3000 tensor(0.0726) tensor(0.2042)
# Removing:./trained_VDNN_470_D_4_30_theta_shuffling.dat
# ./trained_VDNN_476_D_4_30_theta_shuffling.dat
# 477 0 tensor(0.1601) tensor(0.2042)
# 477 1000 tensor(0.2229) tensor(0.2042)
# 477 2000 tensor(0.1363) tensor(0.2043)
# 477 3000 tensor(0.1405) tensor(0.2043)
# Removing:./trained_VDNN_471_D_4_30_theta_shuffling.dat
# ./trained_VDNN_477_D_4_30_theta_shuffling.dat
# 478 0 tensor(0.2413) tensor(0.2043)
# 478 1000 tensor(0.1885) tensor(0.2043)
# 478 2000 tensor(0.1075) tensor(0.2043)
# 478 3000 tensor(0.1474) tensor(0.2044)
# Removing:./trained_VDNN_472_D_4_30_theta_shuffling.dat
# ./trained_VDNN_478_D_4_30_theta_shuffling.dat
# 479 0 tensor(0.1408) tensor(0.2044)
# 479 1000 tensor(0.0910) tensor(0.2044)
# 479 2000 tensor(0.1823) tensor(0.2043)
# 479 3000 tensor(0.0945) tensor(0.2043)
# Removing:./trained_VDNN_473_D_4_30_theta_shuffling.dat
# ./trained_VDNN_479_D_4_30_theta_shuffling.dat
# 480 0 tensor(0.1734) tensor(0.2043)
# 480 1000 tensor(0.1556) tensor(0.2043)
# 480 2000 tensor(0.1134) tensor(0.2043)
# 480 3000 tensor(0.1072) tensor(0.2043)
# Removing:./trained_VDNN_474_D_4_30_theta_shuffling.dat
# ./trained_VDNN_480_D_4_30_theta_shuffling.dat
# 481 0 tensor(0.1920) tensor(0.2043)
# 481 1000 tensor(0.1252) tensor(0.2043)
# 481 2000 tensor(0.1531) tensor(0.2043)
# 481 3000 tensor(0.1364) tensor(0.2043)
# Removing:./trained_VDNN_475_D_4_30_theta_shuffling.dat
# ./trained_VDNN_481_D_4_30_theta_shuffling.dat
# 482 0 tensor(0.1728) tensor(0.2043)
# 482 1000 tensor(0.1401) tensor(0.2042)
# 482 2000 tensor(0.0911) tensor(0.2042)
# 482 3000 tensor(0.1707) tensor(0.2042)
# Removing:./trained_VDNN_476_D_4_30_theta_shuffling.dat
# ./trained_VDNN_482_D_4_30_theta_shuffling.dat
# 483 0 tensor(0.1755) tensor(0.2042)
# 483 1000 tensor(0.1559) tensor(0.2043)
# 483 2000 tensor(0.1663) tensor(0.2043)
# 483 3000 tensor(0.0951) tensor(0.2043)
# Removing:./trained_VDNN_477_D_4_30_theta_shuffling.dat
# ./trained_VDNN_483_D_4_30_theta_shuffling.dat
# 484 0 tensor(0.1265) tensor(0.2043)
# 484 1000 tensor(0.1126) tensor(0.2043)
# 484 2000 tensor(0.0836) tensor(0.2043)
# 484 3000 tensor(0.1311) tensor(0.2043)
# Removing:./trained_VDNN_478_D_4_30_theta_shuffling.dat
# ./trained_VDNN_484_D_4_30_theta_shuffling.dat
# 485 0 tensor(0.1943) tensor(0.2043)
# 485 1000 tensor(0.1101) tensor(0.2042)
# 485 2000 tensor(0.1316) tensor(0.2042)
# 485 3000 tensor(0.1450) tensor(0.2043)
# Removing:./trained_VDNN_479_D_4_30_theta_shuffling.dat
# ./trained_VDNN_485_D_4_30_theta_shuffling.dat
# 486 0 tensor(0.2038) tensor(0.2043)
# 486 1000 tensor(0.1278) tensor(0.2043)
# 486 2000 tensor(0.1421) tensor(0.2043)
# 486 3000 tensor(0.1107) tensor(0.2043)
# Removing:./trained_VDNN_480_D_4_30_theta_shuffling.dat
# ./trained_VDNN_486_D_4_30_theta_shuffling.dat
# 487 0 tensor(0.0925) tensor(0.2043)
# 487 1000 tensor(0.1842) tensor(0.2043)
# 487 2000 tensor(0.1737) tensor(0.2043)
# 487 3000 tensor(0.1024) tensor(0.2043)
# Removing:./trained_VDNN_481_D_4_30_theta_shuffling.dat
# ./trained_VDNN_487_D_4_30_theta_shuffling.dat
# 488 0 tensor(0.1269) tensor(0.2043)
# 488 1000 tensor(0.1752) tensor(0.2042)
# 488 2000 tensor(0.0837) tensor(0.2042)
# 488 3000 tensor(0.1269) tensor(0.2042)
# Removing:./trained_VDNN_482_D_4_30_theta_shuffling.dat
# ./trained_VDNN_488_D_4_30_theta_shuffling.dat
# 489 0 tensor(0.1375) tensor(0.2042)
# 489 1000 tensor(0.0981) tensor(0.2042)
# 489 2000 tensor(0.1305) tensor(0.2042)
# 489 3000 tensor(0.1354) tensor(0.2042)
# Removing:./trained_VDNN_483_D_4_30_theta_shuffling.dat
# ./trained_VDNN_489_D_4_30_theta_shuffling.dat
# 490 0 tensor(0.1640) tensor(0.2042)
# 490 1000 tensor(0.1019) tensor(0.2043)
# 490 2000 tensor(0.1564) tensor(0.2043)
# 490 3000 tensor(0.1023) tensor(0.2043)
# Removing:./trained_VDNN_484_D_4_30_theta_shuffling.dat
# ./trained_VDNN_490_D_4_30_theta_shuffling.dat
# 491 0 tensor(0.1502) tensor(0.2043)
# 491 1000 tensor(0.1286) tensor(0.2043)
# 491 2000 tensor(0.1155) tensor(0.2042)
# 491 3000 tensor(0.1198) tensor(0.2042)
# Removing:./trained_VDNN_485_D_4_30_theta_shuffling.dat
# ./trained_VDNN_491_D_4_30_theta_shuffling.dat
# 492 0 tensor(0.2276) tensor(0.2042)
# 492 1000 tensor(0.1458) tensor(0.2042)
# 492 2000 tensor(0.1343) tensor(0.2042)
# 492 3000 tensor(0.1676) tensor(0.2042)
# Removing:./trained_VDNN_486_D_4_30_theta_shuffling.dat
# ./trained_VDNN_492_D_4_30_theta_shuffling.dat
# 493 0 tensor(0.1618) tensor(0.2042)
# 493 1000 tensor(0.1406) tensor(0.2043)
# 493 2000 tensor(0.1065) tensor(0.2043)
# 493 3000 tensor(0.1709) tensor(0.2043)
# Removing:./trained_VDNN_487_D_4_30_theta_shuffling.dat
# ./trained_VDNN_493_D_4_30_theta_shuffling.dat
# 494 0 tensor(0.1286) tensor(0.2043)
# 494 1000 tensor(0.1122) tensor(0.2043)
# 494 2000 tensor(0.1155) tensor(0.2042)
# 494 3000 tensor(0.2090) tensor(0.2042)
# Removing:./trained_VDNN_488_D_4_30_theta_shuffling.dat
# ./trained_VDNN_494_D_4_30_theta_shuffling.dat
# 495 0 tensor(0.1696) tensor(0.2042)
# 495 1000 tensor(0.1020) tensor(0.2042)
# 495 2000 tensor(0.1509) tensor(0.2042)
# 495 3000 tensor(0.1832) tensor(0.2042)
# Removing:./trained_VDNN_489_D_4_30_theta_shuffling.dat
# ./trained_VDNN_495_D_4_30_theta_shuffling.dat
# 496 0 tensor(0.1124) tensor(0.2042)
# 496 1000 tensor(0.1405) tensor(0.2043)
# 496 2000 tensor(0.1105) tensor(0.2043)
# 496 3000 tensor(0.1598) tensor(0.2043)
# Removing:./trained_VDNN_490_D_4_30_theta_shuffling.dat
# ./trained_VDNN_496_D_4_30_theta_shuffling.dat
# 497 0 tensor(0.1568) tensor(0.2043)
# 497 1000 tensor(0.1528) tensor(0.2043)
# 497 2000 tensor(0.1733) tensor(0.2043)
# 497 3000 tensor(0.1441) tensor(0.2043)
# Removing:./trained_VDNN_491_D_4_30_theta_shuffling.dat
# ./trained_VDNN_497_D_4_30_theta_shuffling.dat
# 498 0 tensor(0.1491) tensor(0.2043)
# 498 1000 tensor(0.1452) tensor(0.2042)
# 498 2000 tensor(0.1243) tensor(0.2043)
# 498 3000 tensor(0.1025) tensor(0.2042)
# Removing:./trained_VDNN_492_D_4_30_theta_shuffling.dat
# ./trained_VDNN_498_D_4_30_theta_shuffling.dat
# 499 0 tensor(0.2157) tensor(0.2042)
# 499 1000 tensor(0.1384) tensor(0.2042)
# 499 2000 tensor(0.1382) tensor(0.2042)
# 499 3000 tensor(0.1030) tensor(0.2042)
# Removing:./trained_VDNN_493_D_4_30_theta_shuffling.dat
# ./trained_VDNN_499_D_4_30_theta_shuffling.dat
# CPU times: user 6h 16min 48s, sys: 25min, total: 6h 41min 48s
# Wall time: 3h 21min 46s

# %%
import scipy
sns.set_style("whitegrid")
plt.figure
plt.plot(Loss_epoch,".")
plt.ylabel("Training Loss")
plt.xlabel("epoch")
x_val=np.linspace(0,np.size(Loss_epoch)-1,np.size(Loss_epoch))
y_val=Loss_epoch
int_fnc = scipy.interpolate.make_interp_spline(x_val,y_val)
x_new = np.linspace(0,np.size(Loss_epoch)-1, np.size(Loss_epoch)*10)
y_new = int_fnc(x_new)
plt.plot(x_new,y_new,"--")
plt.show()

# %% [markdown]
# ## G=0 Testing

# %%
#Plot the output
outputs=[]
outputs_01=[]
outputs2=[]
net.eval()
with torch.no_grad():
    for i in torch.arange(Targs.shape[0]):
        d=data_validate[i,:,:]
        output=net(torch.tensor(d,dtype=torch.float32))
        output_01=(output>0.5)
        outputs_01.append(output_01.squeeze().detach().numpy())
        shfl=np.random.permutation(np.arange(1600))
        output2=net(torch.tensor(d[:,shfl],dtype=torch.float32))
        outputs.append(output.squeeze().detach().numpy())
        outputs2.append(output2.squeeze().detach().numpy())
    
#plt.plot(outputs.squeeze(),"o",alpha=0.02,color='red')
#plt.plot(labels_validate)
#depth=6
sns.set_style("whitegrid")
mu=np.average(np.fabs(np.average(data_validate[:,:2000,:],axis=2)),axis=1)
outputs=np.array(outputs)
outputs2=np.array(outputs2)
Tsn=Ts_G_0[Targs]
ax=plt.axes()

ax.scatter(np.repeat(Tsn,2000),np.concatenate(outputs),alpha=0.002,s=8.0,color='springgreen')

#plt.plot(Tsn,labels_tmp,"g.--")
ax.plot(Tsn,mu,"r--",alpha=0.4,label="\mu")
#plt.plot(Tsn,np.average(outputs,axis=1),"o-",markersize=4,color='darkgreen')
ax.plot(Tsn,np.average(outputs_01,axis=1),"o-",markersize=4,color='darkgreen',label='Model output')
T0,T1=Tsn[np.where(labels_tmp==1.0)[0][[0,-1]]]
ax.vlines(T0,0,1,color='magenta',linestyle='dashed')
ax.vlines(T1,0,1,color='magenta',linestyle='dashed')
ax.plot(Tsn,np.average(outputs2,axis=1),"*-",color='purple',label='Model output shuffled')
#plt.plot(Ts,probs)
# ax.plot(Tc,mu_avc,"r",alpha=0.4) # Ask Pallab - what is mu_avc

#plt.legend(loc="upper right")/
handles, labels = ax.get_legend_handles_labels()
plt.savefig("%s_testdata_g0.pdf"%(sfname[:-4]),dpi=300)

# %%
# -----------------Dileep's modification ---------------------
# Just to save the data for plotting later figures
df_adversarial_G_0 = pd.DataFrame()
df_adversarial_G_0["Ts"] = Ts_G_0
df_adversarial_G_0["mu"] = mu
df_adversarial_G_0["ordinary_data_avg_pred"] = np.average(outputs_01,axis=1)
df_adversarial_G_0["shuffled_data_avg_pred"] = np.average(outputs2,axis=1)


G_0_adversarial_scatter_plot_info_dict = {"T0":T0,"T1":T1,"Ts":np.repeat(Tsn,2000),"outputs":np.concatenate(outputs)}
# --------------------------------------------------------------

# %% [markdown]
# ## G = 0.1 Testing

# %%
#---------------------------Critical region for G=0.1 ------------------
#xiBs,labels
xiBs=f5_new['xiBs'][:]
factor=0.30
cut=np.amax(xiBs)*factor

labels_tmp=np.heaviside(xiBs[Targs]-cut,1.0)
labels_train=np.repeat(labels_tmp,8000)
labels_validate=np.repeat(labels_tmp,2000)

T0,T1=Ts_G_0_1[np.where(labels_tmp==1.0)[0][[0,-1]]]
#---------------------

#Plot the output
outputs=[]
outputs_01=[]
outputs2=[]
net.eval()
with torch.no_grad():
    for i in torch.arange(Targs.shape[0]):
        d=data_validate_new[i,:,:]
        output=net(torch.tensor(d,dtype=torch.float32))
        output_01=(output>0.5)
        outputs_01.append(output_01.squeeze().detach().numpy())
        shfl=np.random.permutation(np.arange(1600))
        output2=net(torch.tensor(d[:,shfl],dtype=torch.float32))
        outputs.append(output.squeeze().detach().numpy())
        outputs2.append(output2.squeeze().detach().numpy())
    
#plt.plot(outputs.squeeze(),"o",alpha=0.02,color='red')
#plt.plot(labels_validate)
#depth=6
sns.set_style("whitegrid")
mu=np.average(np.fabs(np.average(data_validate_new[:,:2000,:],axis=2)),axis=1)
outputs=np.array(outputs)
outputs2=np.array(outputs2)
Tsn=Ts_G_0_1[Targs]
ax=plt.axes()

ax.scatter(np.repeat(Tsn,2000),np.concatenate(outputs),alpha=0.002,s=8.0,color='springgreen')

#plt.plot(Tsn,labels_tmp,"g.--")
ax.plot(Tsn,mu,"r--",alpha=0.4,label="\mu")
#plt.plot(Tsn,np.average(outputs,axis=1),"o-",markersize=4,color='darkgreen')
ax.plot(Tsn,np.average(outputs_01,axis=1),"o-",markersize=4,color='darkgreen',label='Model output')
T0,T1=Tsn[np.where(labels_tmp==1.0)[0][[0,-1]]]
# ax.vlines(T0,0,1,color='magenta',linestyle='dashed')
# ax.vlines(T1,0,1,color='magenta',linestyle='dashed')
ax.plot(Tsn,np.average(outputs2,axis=1),"*-",color='purple',label='Model output shuffled')
#plt.plot(Ts,probs)
# ax.plot(Tc,mu_avc,"r",alpha=0.4) # Ask Pallab - what is mu_avc

#plt.legend(loc="upper right")/
handles, labels = ax.get_legend_handles_labels()
plt.savefig("%s_testdata_g0.pdf"%(sfname[:-4]),dpi=300)

# %%
# -----------------Dileep's modification ---------------------
# Just to save the data for plotting later figures
df_adversarial_G_0_1 = pd.DataFrame()
df_adversarial_G_0_1["Ts"] = Ts_G_0_1
df_adversarial_G_0_1["mu"] = mu
df_adversarial_G_0_1["ordinary_data_avg_pred"] = np.average(outputs_01,axis=1)
df_adversarial_G_0_1["shuffled_data_avg_pred"] = np.average(outputs2,axis=1)


G_0_1_adversarial_scatter_plot_info_dict = {"T0":T0,"T1":T1,"Ts":np.repeat(Tsn,2000),"outputs":np.concatenate(outputs)}
# --------------------------------------------------------------

# %% [markdown]
# # G = 0.5 Testing

# %%
#---------------------------Critical region for G=0.5 ------------------
#xiBs,labels
xiBs=f5_new_2['xiBs'][:]
factor=0.30
cut=np.amax(xiBs)*factor

labels_tmp=np.heaviside(xiBs[Targs]-cut,1.0)
labels_train=np.repeat(labels_tmp,8000)
labels_validate=np.repeat(labels_tmp,2000)

T0,T1=Ts_G_0_5[np.where(labels_tmp==1.0)[0][[0,-1]]]
#---------------------


#Plot the output
outputs=[]
outputs_01=[]
outputs2=[]
net.eval()
with torch.no_grad():
    for i in torch.arange(Targs.shape[0]):
        d=data_validate_new2[i,:,:]
        output=net(torch.tensor(d,dtype=torch.float32))
        output_01=(output>0.5)
        outputs_01.append(output_01.squeeze().detach().numpy())
        shfl=np.random.permutation(np.arange(1600))
        output2=net(torch.tensor(d[:,shfl],dtype=torch.float32))
        outputs.append(output.squeeze().detach().numpy())
        outputs2.append(output2.squeeze().detach().numpy())
    
#plt.plot(outputs.squeeze(),"o",alpha=0.02,color='red')
#plt.plot(labels_validate)
#depth=6
sns.set_style("whitegrid")
mu=np.average(np.fabs(np.average(data_validate_new2[:,:2000,:],axis=2)),axis=1)
outputs=np.array(outputs)
outputs2=np.array(outputs2)
Tsn=Ts_G_0_5[Targs]
ax=plt.axes()

ax.scatter(np.repeat(Tsn,2000),np.concatenate(outputs),alpha=0.002,s=8.0,color='springgreen')

#plt.plot(Tsn,labels_tmp,"g.--")
ax.plot(Tsn,mu,"r--",alpha=0.4,label="\mu")
#plt.plot(Tsn,np.average(outputs,axis=1),"o-",markersize=4,color='darkgreen')
ax.plot(Tsn,np.average(outputs_01,axis=1),"o-",markersize=4,color='darkgreen',label='Model output')
T0,T1=Tsn[np.where(labels_tmp==1.0)[0][[0,-1]]]
# ax.vlines(T0,0,1,color='magenta',linestyle='dashed')
# ax.vlines(T1,0,1,color='magenta',linestyle='dashed')
ax.plot(Tsn,np.average(outputs2,axis=1),"*-",color='purple',label='Model output shuffled')
#plt.plot(Ts,probs)
# ax.plot(Tc,mu_avc,"r",alpha=0.4) # Ask Pallab - what is mu_avc

#plt.legend(loc="upper right")/
handles, labels = ax.get_legend_handles_labels()
plt.savefig("%s_testdata_g0.pdf"%(sfname[:-4]),dpi=300)

# %%
# -----------------Dileep's modification ---------------------
# Just to save the data for plotting later figures
df_adversarial_G_0_5 = pd.DataFrame()
df_adversarial_G_0_5["Ts"] = Ts_G_0_5
df_adversarial_G_0_5["mu"] = mu
df_adversarial_G_0_5["ordinary_data_avg_pred"] = np.average(outputs_01,axis=1)
df_adversarial_G_0_5["shuffled_data_avg_pred"] = np.average(outputs2,axis=1)


G_0_5_adversarial_scatter_plot_info_dict = {"T0":T0,"T1":T1,"Ts":np.repeat(Tsn,2000),"outputs":np.concatenate(outputs)}
# ------------------------------------------------------------

# %% [markdown]
# ## G=1, J=1 testing

# %%
#---------------------------Critical region for G=0.5 ------------------
#xiBs,labels
xiBs=f5_new_3['xiBs'][:]
factor=0.30
cut=np.amax(xiBs)*factor

labels_tmp=np.heaviside(xiBs[Targs_new]-cut,1.0)
labels_train=np.repeat(labels_tmp,8000)
labels_validate=np.repeat(labels_tmp,2000)

T0,T1=Ts_G_1[np.where(labels_tmp==1.0)[0][[0,-1]]]
#---------------------


#Plot the output
outputs=[]
outputs_01=[]
outputs2=[]
net.eval()
with torch.no_grad():
    for i in torch.arange(Targs_new.shape[0]):
        d=data_validate_new3[i,:,:]
        output=net(torch.tensor(d,dtype=torch.float32))
        output_01=(output>0.5)
        outputs_01.append(output_01.squeeze().detach().numpy())
        shfl=np.random.permutation(np.arange(1600))
        output2=net(torch.tensor(d[:,shfl],dtype=torch.float32))
        outputs.append(output.squeeze().detach().numpy())
        outputs2.append(output2.squeeze().detach().numpy())
    
#plt.plot(outputs.squeeze(),"o",alpha=0.02,color='red')
#plt.plot(labels_validate)
#depth=6
sns.set_style("whitegrid")
mu=np.average(np.fabs(np.average(data_validate_new3[:,:2000,:],axis=2)),axis=1)
outputs=np.array(outputs)
outputs2=np.array(outputs2)
Tsn=Ts_G_1[Targs_new]
ax=plt.axes()

ax.scatter(np.repeat(Tsn,2000),np.concatenate(outputs),alpha=0.002,s=8.0,color='springgreen')

#plt.plot(Tsn,labels_tmp,"g.--")
ax.plot(Tsn,mu,"r--",alpha=0.4,label="\mu")
#plt.plot(Tsn,np.average(outputs,axis=1),"o-",markersize=4,color='darkgreen')
ax.plot(Tsn,np.average(outputs_01,axis=1),"o-",markersize=4,color='darkgreen',label='Model output')
T0,T1=Tsn[np.where(labels_tmp==1.0)[0][[0,-1]]]
# ax.vlines(T0,0,1,color='magenta',linestyle='dashed')
# ax.vlines(T1,0,1,color='magenta',linestyle='dashed')
ax.plot(Tsn,np.average(outputs2,axis=1),"*-",color='purple',label='Model output shuffled')
#plt.plot(Ts,probs)
# ax.plot(Tc,mu_avc,"r",alpha=0.4) # Ask Pallab - what is mu_avc

#plt.legend(loc="upper right")/
handles, labels = ax.get_legend_handles_labels()
plt.savefig("%s_testdata_g0.pdf"%(sfname[:-4]),dpi=300)

# %% [markdown]
# ## J=0.01, G=1 testing

# %%
#---------------------------Critical region for G=0.5 ------------------
#xiBs,labels
xiBs=f5_new_4['xiBs'][:]
factor=0.30
cut=np.amax(xiBs)*factor

labels_tmp=np.heaviside(xiBs[Targs]-cut,1.0)
labels_train=np.repeat(labels_tmp,8000)
labels_validate=np.repeat(labels_tmp,2000)

T0,T1=Ts_G_1_J_0[np.where(labels_tmp==1.0)[0][[0,-1]]]
#---------------------


#Plot the output
outputs=[]
outputs_01=[]
outputs2=[]
net.eval()
with torch.no_grad():
    for i in torch.arange(Targs.shape[0]):
        d=data_validate_new4[i,:,:]
        output=net(torch.tensor(d,dtype=torch.float32))
        output_01=(output>0.5)
        outputs_01.append(output_01.squeeze().detach().numpy())
        shfl=np.random.permutation(np.arange(1600))
        output2=net(torch.tensor(d[:,shfl],dtype=torch.float32))
        outputs.append(output.squeeze().detach().numpy())
        outputs2.append(output2.squeeze().detach().numpy())
    
#plt.plot(outputs.squeeze(),"o",alpha=0.02,color='red')
#plt.plot(labels_validate)
#depth=6
sns.set_style("whitegrid")
mu=np.average(np.fabs(np.average(data_validate_new4[:,:2000,:],axis=2)),axis=1)
outputs=np.array(outputs)
outputs2=np.array(outputs2)
Tsn=Ts_G_1_J_0[Targs]
ax=plt.axes()

ax.scatter(np.repeat(Tsn,2000),np.concatenate(outputs),alpha=0.002,s=8.0,color='springgreen')

#plt.plot(Tsn,labels_tmp,"g.--")
ax.plot(Tsn,mu,"r--",alpha=0.4,label="\mu")
#plt.plot(Tsn,np.average(outputs,axis=1),"o-",markersize=4,color='darkgreen')
ax.plot(Tsn,np.average(outputs_01,axis=1),"o-",markersize=4,color='darkgreen',label='Model output')
T0,T1=Tsn[np.where(labels_tmp==1.0)[0][[0,-1]]]
# ax.vlines(T0,0,1,color='magenta',linestyle='dashed')
# ax.vlines(T1,0,1,color='magenta',linestyle='dashed')
ax.plot(Tsn,np.average(outputs2,axis=1),"*-",color='purple',label='Model output shuffled')
#plt.plot(Ts,probs)
# ax.plot(Tc,mu_avc,"r",alpha=0.4) # Ask Pallab - what is mu_avc

#plt.legend(loc="upper right")/
handles, labels = ax.get_legend_handles_labels()
plt.savefig("%s_testdata_g0.pdf"%(sfname[:-4]),dpi=300)

# %% [markdown]
# # <span style="color:green"> Dileep's modifications</span>

# %% [markdown]
# ## Training With out shuffling

# %%
#Define NN and training parameters
depth=4
net_ordinary=VDNN(depth)
loss_fn = nn.BCELoss(reduction='none')
count=0

# #-------------------------------------------
# #No of epochs during training
# optim_step=15
# #--------------------------------------------------------------------------------
# Commented out because this parameter is defined during the previous training 
#----------------------------------------------------------------------------------


losses=[]

NN_test=Targs.shape[0]*8000

model_type=type(net).__name__

# %%
#scheduler
lr=5e-6


optimizer = optim.Adam(net_ordinary.parameters(),lr=lr,weight_decay=0)
scheduler = ReduceLROnPlateau(optimizer, "min", patience=5)
from collections import deque
osfnames=deque()

# %%
# %%time

#------------Loss variable for each iteration-----------
Loss_epoch = []
#Loss_batch = 0
#------------

#training
net_ordinary.train()
batch_size=150
is_theta=True
is_ab=False
is_shuffling=False
batch_no=np.int32(NN_test/batch_size)

shuffle_injection_frequency=50
while (count<optim_step):
    Loss_batch = 0 #for loss plot
    optimizer.zero_grad()
    NNs=torch.randperm(NN_test)
    for k in np.arange(batch_no):
        optimizer.zero_grad()
        inds = NNs[k*batch_size:(k+1)*batch_size]
        inds = inds[:batch_size]
        datas2 = data_train[inds]
        labels2 = labels_train[inds]
        
        sgn=(2*torch.bernoulli(torch.ones(batch_size)*0.5)-1).unsqueeze(-1)
        dt=torch.tensor(datas2,dtype=torch.float32)
        dt=dt*sgn
    # Adversarial 
        if is_ab:
            a,b=torch.rand(2,batch_size)
            a=0.25+2*torch.unsqueeze(a,-1)
            b=1*(torch.unsqueeze(b,-1)-0.5)
            #a,b=1,0 #no a,b
            dt=(dt*a)
            sgn=(2*torch.bernoulli(torch.ones(batch_size)*0.5)-1).unsqueeze(-1)
            dt=(dt*sgn)+b
   
    #shuffling
        if is_shuffling:
            s_inds=torch.randperm(1600)
            dt[:shuffle_injection_frequency,:]=dt[:shuffle_injection_frequency,s_inds]
            labels2[:shuffle_injection_frequency]=0
    
        #A random shift x and y
        i,j=torch.randint(40,[2])
        dt2=dt.reshape(batch_size,40,40)
        dt=torch.roll(dt2,[i,j],dims=[1,2]).reshape(batch_size,1600)

        #Training
        poutputs=net_ordinary(dt)
        targets=torch.tensor(labels2,dtype=torch.float32,requires_grad=False)

        with torch.no_grad():
            w1=0.5
            wghts=(w1*targets+(1-w1)*(1-targets))
            wghts=wghts/torch.sum(wghts)
        loss_tmp=loss_fn(poutputs,torch.unsqueeze(targets,1))
        loss=torch.sum(loss_tmp.squeeze(1)*wghts)
        loss.backward()
        if k%1000==0:
            losses.append(loss.detach().cpu())
            with torch.no_grad():
                d=torch.tensor(data_validate.reshape(61*2000,1600))
                output_v=net_ordinary(d)
                labels_v=torch.tensor(labels_validate)
                loss_v=loss_fn(output_v,labels_v.unsqueeze(-1))
                loss_v=torch.mean(loss_v)
            print(count,k,loss.detach().cpu(),loss_v.detach().cpu(),end='\n')
        optimizer.step()
        #------averaging loss-------
        Loss_batch += loss.detach().cpu().item()
    
    Loss_batch /= batch_no     
    scheduler.step(Loss_batch)
    Loss_epoch.append(Loss_batch)
        
        
    if count%1==0 and count>0: #Saving last five models 
        sfname="./trained_%s_%d_D_%d_%.0f"%(model_type,count,depth,100*factor)
        if is_theta:
            sfname=sfname+"_theta"
        else:
            sfname=sfname+"full_curve"
        if is_ab:
            sfname=sfname+"_ab"
        if is_shuffling:
            sfname=sfname+"_shuffling"
        sfname=sfname+".dat"
        
        if len(osfnames)>5:
            osfname=osfnames.popleft()
            if os.path.exists(osfname):
                print("Removing:%s"%osfname)
                os.remove(osfname)
            
        with open(sfname,"wb") as fl:
            print(sfname)
            pickle.dump(net_ordinary.state_dict(),fl)
            pickle.dump({'T0':T0,'T1':T1,'Targs':Targs,'epochs':count,'losses':losses,'batch_size': batch_size, 'epoch_size': NN_test},fl)
            osfnames.append(sfname)
            fl.close()
    count=count+1
# Out:
# 0 0 tensor(0.6933) tensor(0.6922)
# 0 1000 tensor(0.5008) tensor(0.5104)
# 0 2000 tensor(0.5184) tensor(0.4989)
# 0 3000 tensor(0.4602) tensor(0.4817)
# 1 0 tensor(0.5205) tensor(0.4770)
# 1 1000 tensor(0.4523) tensor(0.4608)
# 1 2000 tensor(0.4597) tensor(0.4476)
# 1 3000 tensor(0.4883) tensor(0.4339)
# ./trained_VDNN_1_D_4_30_theta.dat
# 2 0 tensor(0.4300) tensor(0.4299)
# 2 1000 tensor(0.4481) tensor(0.4134)
# 2 2000 tensor(0.3580) tensor(0.3972)
# 2 3000 tensor(0.3919) tensor(0.3840)
# ./trained_VDNN_2_D_4_30_theta.dat
# 3 0 tensor(0.3774) tensor(0.3813)
# 3 1000 tensor(0.3579) tensor(0.3724)
# 3 2000 tensor(0.3944) tensor(0.3653)
# 3 3000 tensor(0.3625) tensor(0.3592)
# ./trained_VDNN_3_D_4_30_theta.dat
# 4 0 tensor(0.3899) tensor(0.3578)
# 4 1000 tensor(0.4145) tensor(0.3528)
# 4 2000 tensor(0.3530) tensor(0.3478)
# 4 3000 tensor(0.3853) tensor(0.3438)
# ./trained_VDNN_4_D_4_30_theta.dat
# 5 0 tensor(0.2869) tensor(0.3428)
# 5 1000 tensor(0.3315) tensor(0.3392)
# 5 2000 tensor(0.3357) tensor(0.3364)
# 5 3000 tensor(0.3234) tensor(0.3326)
# ./trained_VDNN_5_D_4_30_theta.dat
# 6 0 tensor(0.2822) tensor(0.3318)
# 6 1000 tensor(0.4012) tensor(0.3293)
# 6 2000 tensor(0.4092) tensor(0.3267)
# 6 3000 tensor(0.3632) tensor(0.3244)
# ./trained_VDNN_6_D_4_30_theta.dat
# 7 0 tensor(0.3940) tensor(0.3236)
# 7 1000 tensor(0.3908) tensor(0.3217)
# 7 2000 tensor(0.3126) tensor(0.3196)
# 7 3000 tensor(0.3374) tensor(0.3177)
# Removing:./trained_VDNN_1_D_4_30_theta.dat
# ./trained_VDNN_7_D_4_30_theta.dat
# 8 0 tensor(0.3146) tensor(0.3172)
# 8 1000 tensor(0.4216) tensor(0.3159)
# 8 2000 tensor(0.2703) tensor(0.3141)
# 8 3000 tensor(0.3089) tensor(0.3126)
# Removing:./trained_VDNN_2_D_4_30_theta.dat
# ./trained_VDNN_8_D_4_30_theta.dat
# 9 0 tensor(0.3333) tensor(0.3122)
# 9 1000 tensor(0.3218) tensor(0.3108)
# 9 2000 tensor(0.3232) tensor(0.3094)
# 9 3000 tensor(0.3157) tensor(0.3078)
# Removing:./trained_VDNN_3_D_4_30_theta.dat
# ./trained_VDNN_9_D_4_30_theta.dat
# 10 0 tensor(0.2644) tensor(0.3076)
# 10 1000 tensor(0.2272) tensor(0.3064)
# 10 2000 tensor(0.3570) tensor(0.3051)
# 10 3000 tensor(0.2583) tensor(0.3038)
# Removing:./trained_VDNN_4_D_4_30_theta.dat
# ./trained_VDNN_10_D_4_30_theta.dat
# 11 0 tensor(0.2584) tensor(0.3036)
# 11 1000 tensor(0.2465) tensor(0.3022)
# 11 2000 tensor(0.2949) tensor(0.3013)
# 11 3000 tensor(0.2456) tensor(0.3002)
# Removing:./trained_VDNN_5_D_4_30_theta.dat
# ./trained_VDNN_11_D_4_30_theta.dat
# 12 0 tensor(0.3561) tensor(0.2998)
# 12 1000 tensor(0.3212) tensor(0.2987)
# 12 2000 tensor(0.2690) tensor(0.2978)
# 12 3000 tensor(0.3441) tensor(0.2966)
# Removing:./trained_VDNN_6_D_4_30_theta.dat
# ./trained_VDNN_12_D_4_30_theta.dat
# 13 0 tensor(0.3019) tensor(0.2963)
# 13 1000 tensor(0.2989) tensor(0.2952)
# 13 2000 tensor(0.2626) tensor(0.2940)
# 13 3000 tensor(0.2531) tensor(0.2932)
# Removing:./trained_VDNN_7_D_4_30_theta.dat
# ./trained_VDNN_13_D_4_30_theta.dat
# 14 0 tensor(0.2686) tensor(0.2929)
# 14 1000 tensor(0.2464) tensor(0.2920)
# 14 2000 tensor(0.2555) tensor(0.2911)
# 14 3000 tensor(0.2641) tensor(0.2902)
# Removing:./trained_VDNN_8_D_4_30_theta.dat
# ./trained_VDNN_14_D_4_30_theta.dat
# 15 0 tensor(0.3073) tensor(0.2898)
# 15 1000 tensor(0.2709) tensor(0.2891)
# 15 2000 tensor(0.2355) tensor(0.2879)
# 15 3000 tensor(0.3758) tensor(0.2870)
# Removing:./trained_VDNN_9_D_4_30_theta.dat
# ./trained_VDNN_15_D_4_30_theta.dat
# 16 0 tensor(0.2685) tensor(0.2867)
# 16 1000 tensor(0.2935) tensor(0.2857)
# 16 2000 tensor(0.2609) tensor(0.2849)
# 16 3000 tensor(0.3228) tensor(0.2840)
# Removing:./trained_VDNN_10_D_4_30_theta.dat
# ./trained_VDNN_16_D_4_30_theta.dat
# 17 0 tensor(0.2928) tensor(0.2837)
# 17 1000 tensor(0.2428) tensor(0.2827)
# 17 2000 tensor(0.2983) tensor(0.2819)
# 17 3000 tensor(0.2548) tensor(0.2811)
# Removing:./trained_VDNN_11_D_4_30_theta.dat
# ./trained_VDNN_17_D_4_30_theta.dat
# 18 0 tensor(0.2916) tensor(0.2807)
# 18 1000 tensor(0.2873) tensor(0.2797)
# 18 2000 tensor(0.2668) tensor(0.2788)
# 18 3000 tensor(0.2587) tensor(0.2780)
# Removing:./trained_VDNN_12_D_4_30_theta.dat
# ./trained_VDNN_18_D_4_30_theta.dat
# 19 0 tensor(0.3188) tensor(0.2776)
# 19 1000 tensor(0.2345) tensor(0.2766)
# 19 2000 tensor(0.2832) tensor(0.2755)
# 19 3000 tensor(0.2990) tensor(0.2744)
# Removing:./trained_VDNN_13_D_4_30_theta.dat
# ./trained_VDNN_19_D_4_30_theta.dat
# 20 0 tensor(0.3281) tensor(0.2744)
# 20 1000 tensor(0.2504) tensor(0.2736)
# 20 2000 tensor(0.2186) tensor(0.2724)
# 20 3000 tensor(0.2966) tensor(0.2714)
# Removing:./trained_VDNN_14_D_4_30_theta.dat
# ./trained_VDNN_20_D_4_30_theta.dat
# 21 0 tensor(0.2290) tensor(0.2711)
# 21 1000 tensor(0.2100) tensor(0.2699)
# 21 2000 tensor(0.2136) tensor(0.2689)
# 21 3000 tensor(0.3333) tensor(0.2680)
# Removing:./trained_VDNN_15_D_4_30_theta.dat
# ./trained_VDNN_21_D_4_30_theta.dat
# 22 0 tensor(0.3152) tensor(0.2681)
# 22 1000 tensor(0.2218) tensor(0.2670)
# 22 2000 tensor(0.2741) tensor(0.2659)
# 22 3000 tensor(0.2434) tensor(0.2650)
# Removing:./trained_VDNN_16_D_4_30_theta.dat
# ./trained_VDNN_22_D_4_30_theta.dat
# 23 0 tensor(0.3136) tensor(0.2647)
# 23 1000 tensor(0.3111) tensor(0.2637)
# 23 2000 tensor(0.2317) tensor(0.2628)
# 23 3000 tensor(0.2519) tensor(0.2618)
# Removing:./trained_VDNN_17_D_4_30_theta.dat
# ./trained_VDNN_23_D_4_30_theta.dat
# 24 0 tensor(0.2436) tensor(0.2615)
# 24 1000 tensor(0.2308) tensor(0.2608)
# 24 2000 tensor(0.2621) tensor(0.2597)
# 24 3000 tensor(0.2353) tensor(0.2589)
# Removing:./trained_VDNN_18_D_4_30_theta.dat
# ./trained_VDNN_24_D_4_30_theta.dat
# 25 0 tensor(0.2390) tensor(0.2585)
# 25 1000 tensor(0.2635) tensor(0.2578)
# 25 2000 tensor(0.2241) tensor(0.2571)
# 25 3000 tensor(0.2873) tensor(0.2564)
# Removing:./trained_VDNN_19_D_4_30_theta.dat
# ./trained_VDNN_25_D_4_30_theta.dat
# 26 0 tensor(0.3279) tensor(0.2560)
# 26 1000 tensor(0.3133) tensor(0.2552)
# 26 2000 tensor(0.2164) tensor(0.2545)
# 26 3000 tensor(0.2750) tensor(0.2536)
# Removing:./trained_VDNN_20_D_4_30_theta.dat
# ./trained_VDNN_26_D_4_30_theta.dat
# 27 0 tensor(0.2765) tensor(0.2535)
# 27 1000 tensor(0.2273) tensor(0.2527)
# 27 2000 tensor(0.2785) tensor(0.2524)
# 27 3000 tensor(0.2189) tensor(0.2516)
# Removing:./trained_VDNN_21_D_4_30_theta.dat
# ./trained_VDNN_27_D_4_30_theta.dat
# 28 0 tensor(0.2493) tensor(0.2514)
# 28 1000 tensor(0.2236) tensor(0.2509)
# 28 2000 tensor(0.3287) tensor(0.2503)
# 28 3000 tensor(0.2092) tensor(0.2497)
# Removing:./trained_VDNN_22_D_4_30_theta.dat
# ./trained_VDNN_28_D_4_30_theta.dat
# 29 0 tensor(0.2623) tensor(0.2497)
# 29 1000 tensor(0.3277) tensor(0.2490)
# 29 2000 tensor(0.2562) tensor(0.2486)
# 29 3000 tensor(0.2841) tensor(0.2482)
# Removing:./trained_VDNN_23_D_4_30_theta.dat
# ./trained_VDNN_29_D_4_30_theta.dat
# 30 0 tensor(0.2292) tensor(0.2479)
# 30 1000 tensor(0.2417) tensor(0.2475)
# 30 2000 tensor(0.2452) tensor(0.2475)
# 30 3000 tensor(0.2679) tensor(0.2466)
# Removing:./trained_VDNN_24_D_4_30_theta.dat
# ./trained_VDNN_30_D_4_30_theta.dat
# 31 0 tensor(0.2659) tensor(0.2465)
# 31 1000 tensor(0.3085) tensor(0.2464)
# 31 2000 tensor(0.2017) tensor(0.2461)
# 31 3000 tensor(0.1750) tensor(0.2455)
# Removing:./trained_VDNN_25_D_4_30_theta.dat
# ./trained_VDNN_31_D_4_30_theta.dat
# 32 0 tensor(0.2826) tensor(0.2455)
# 32 1000 tensor(0.1726) tensor(0.2452)
# 32 2000 tensor(0.2656) tensor(0.2447)
# 32 3000 tensor(0.2177) tensor(0.2444)
# Removing:./trained_VDNN_26_D_4_30_theta.dat
# ./trained_VDNN_32_D_4_30_theta.dat
# 33 0 tensor(0.2180) tensor(0.2449)
# 33 1000 tensor(0.2450) tensor(0.2442)
# 33 2000 tensor(0.2494) tensor(0.2438)
# 33 3000 tensor(0.2998) tensor(0.2433)
# Removing:./trained_VDNN_27_D_4_30_theta.dat
# ./trained_VDNN_33_D_4_30_theta.dat
# 34 0 tensor(0.2383) tensor(0.2433)
# 34 1000 tensor(0.2528) tensor(0.2429)
# 34 2000 tensor(0.1848) tensor(0.2429)
# 34 3000 tensor(0.2240) tensor(0.2427)
# Removing:./trained_VDNN_28_D_4_30_theta.dat
# ./trained_VDNN_34_D_4_30_theta.dat
# 35 0 tensor(0.2286) tensor(0.2427)
# 35 1000 tensor(0.2453) tensor(0.2423)
# 35 2000 tensor(0.2167) tensor(0.2418)
# 35 3000 tensor(0.2364) tensor(0.2417)
# Removing:./trained_VDNN_29_D_4_30_theta.dat
# ./trained_VDNN_35_D_4_30_theta.dat
# 36 0 tensor(0.1953) tensor(0.2419)
# 36 1000 tensor(0.2429) tensor(0.2414)
# 36 2000 tensor(0.2140) tensor(0.2412)
# 36 3000 tensor(0.2474) tensor(0.2408)
# Removing:./trained_VDNN_30_D_4_30_theta.dat
# ./trained_VDNN_36_D_4_30_theta.dat
# 37 0 tensor(0.3207) tensor(0.2409)
# 37 1000 tensor(0.1995) tensor(0.2408)
# 37 2000 tensor(0.2400) tensor(0.2405)
# 37 3000 tensor(0.2379) tensor(0.2404)
# Removing:./trained_VDNN_31_D_4_30_theta.dat
# ./trained_VDNN_37_D_4_30_theta.dat
# 38 0 tensor(0.2198) tensor(0.2402)
# 38 1000 tensor(0.2201) tensor(0.2399)
# 38 2000 tensor(0.2364) tensor(0.2398)
# 38 3000 tensor(0.2364) tensor(0.2396)
# Removing:./trained_VDNN_32_D_4_30_theta.dat
# ./trained_VDNN_38_D_4_30_theta.dat
# 39 0 tensor(0.2583) tensor(0.2398)
# 39 1000 tensor(0.2006) tensor(0.2393)
# 39 2000 tensor(0.2194) tensor(0.2390)
# 39 3000 tensor(0.3108) tensor(0.2389)
# Removing:./trained_VDNN_33_D_4_30_theta.dat
# ./trained_VDNN_39_D_4_30_theta.dat
# 40 0 tensor(0.2599) tensor(0.2388)
# 40 1000 tensor(0.2004) tensor(0.2386)
# 40 2000 tensor(0.2272) tensor(0.2386)
# 40 3000 tensor(0.2784) tensor(0.2382)
# Removing:./trained_VDNN_34_D_4_30_theta.dat
# ./trained_VDNN_40_D_4_30_theta.dat
# 41 0 tensor(0.2337) tensor(0.2385)
# 41 1000 tensor(0.2294) tensor(0.2379)
# 41 2000 tensor(0.2707) tensor(0.2379)
# 41 3000 tensor(0.3092) tensor(0.2378)
# Removing:./trained_VDNN_35_D_4_30_theta.dat
# ./trained_VDNN_41_D_4_30_theta.dat
# 42 0 tensor(0.2821) tensor(0.2377)
# 42 1000 tensor(0.2949) tensor(0.2380)
# 42 2000 tensor(0.2100) tensor(0.2374)
# 42 3000 tensor(0.3071) tensor(0.2374)
# Removing:./trained_VDNN_36_D_4_30_theta.dat
# ./trained_VDNN_42_D_4_30_theta.dat
# 43 0 tensor(0.2762) tensor(0.2374)
# 43 1000 tensor(0.1509) tensor(0.2371)
# 43 2000 tensor(0.2138) tensor(0.2367)
# 43 3000 tensor(0.2527) tensor(0.2366)
# Removing:./trained_VDNN_37_D_4_30_theta.dat
# ./trained_VDNN_43_D_4_30_theta.dat
# 44 0 tensor(0.2964) tensor(0.2367)
# 44 1000 tensor(0.2247) tensor(0.2364)
# 44 2000 tensor(0.2411) tensor(0.2363)
# 44 3000 tensor(0.2182) tensor(0.2362)
# Removing:./trained_VDNN_38_D_4_30_theta.dat
# ./trained_VDNN_44_D_4_30_theta.dat
# 45 0 tensor(0.2957) tensor(0.2361)
# 45 1000 tensor(0.2683) tensor(0.2360)
# 45 2000 tensor(0.2301) tensor(0.2357)
# 45 3000 tensor(0.1783) tensor(0.2355)
# Removing:./trained_VDNN_39_D_4_30_theta.dat
# ./trained_VDNN_45_D_4_30_theta.dat
# 46 0 tensor(0.2488) tensor(0.2357)
# 46 1000 tensor(0.2141) tensor(0.2354)
# 46 2000 tensor(0.2210) tensor(0.2353)
# 46 3000 tensor(0.2460) tensor(0.2350)
# Removing:./trained_VDNN_40_D_4_30_theta.dat
# ./trained_VDNN_46_D_4_30_theta.dat
# 47 0 tensor(0.2214) tensor(0.2357)
# 47 1000 tensor(0.1855) tensor(0.2350)
# 47 2000 tensor(0.2670) tensor(0.2349)
# 47 3000 tensor(0.2456) tensor(0.2349)
# Removing:./trained_VDNN_41_D_4_30_theta.dat
# ./trained_VDNN_47_D_4_30_theta.dat
# 48 0 tensor(0.2527) tensor(0.2349)
# 48 1000 tensor(0.2740) tensor(0.2347)
# 48 2000 tensor(0.2516) tensor(0.2346)
# 48 3000 tensor(0.2487) tensor(0.2347)
# Removing:./trained_VDNN_42_D_4_30_theta.dat
# ./trained_VDNN_48_D_4_30_theta.dat
# 49 0 tensor(0.2754) tensor(0.2344)
# 49 1000 tensor(0.2411) tensor(0.2343)
# 49 2000 tensor(0.1996) tensor(0.2344)
# 49 3000 tensor(0.1745) tensor(0.2341)
# Removing:./trained_VDNN_43_D_4_30_theta.dat
# ./trained_VDNN_49_D_4_30_theta.dat
# 50 0 tensor(0.2016) tensor(0.2339)
# 50 1000 tensor(0.2351) tensor(0.2338)
# 50 2000 tensor(0.2243) tensor(0.2340)
# 50 3000 tensor(0.2609) tensor(0.2338)
# Removing:./trained_VDNN_44_D_4_30_theta.dat
# ./trained_VDNN_50_D_4_30_theta.dat
# 51 0 tensor(0.1762) tensor(0.2337)
# 51 1000 tensor(0.1935) tensor(0.2335)
# 51 2000 tensor(0.2477) tensor(0.2332)
# 51 3000 tensor(0.2205) tensor(0.2333)
# Removing:./trained_VDNN_45_D_4_30_theta.dat
# ./trained_VDNN_51_D_4_30_theta.dat
# 52 0 tensor(0.1892) tensor(0.2330)
# 52 1000 tensor(0.1886) tensor(0.2329)
# 52 2000 tensor(0.1843) tensor(0.2328)
# 52 3000 tensor(0.2004) tensor(0.2327)
# Removing:./trained_VDNN_46_D_4_30_theta.dat
# ./trained_VDNN_52_D_4_30_theta.dat
# 53 0 tensor(0.2406) tensor(0.2327)
# 53 1000 tensor(0.1827) tensor(0.2325)
# 53 2000 tensor(0.1993) tensor(0.2325)
# 53 3000 tensor(0.2502) tensor(0.2323)
# Removing:./trained_VDNN_47_D_4_30_theta.dat
# ./trained_VDNN_53_D_4_30_theta.dat
# 54 0 tensor(0.2827) tensor(0.2323)
# 54 1000 tensor(0.2248) tensor(0.2326)
# 54 2000 tensor(0.1769) tensor(0.2322)
# 54 3000 tensor(0.2308) tensor(0.2320)
# Removing:./trained_VDNN_48_D_4_30_theta.dat
# ./trained_VDNN_54_D_4_30_theta.dat
# 55 0 tensor(0.2685) tensor(0.2319)
# 55 1000 tensor(0.2138) tensor(0.2318)
# 55 2000 tensor(0.2330) tensor(0.2317)
# 55 3000 tensor(0.2311) tensor(0.2316)
# Removing:./trained_VDNN_49_D_4_30_theta.dat
# ./trained_VDNN_55_D_4_30_theta.dat
# 56 0 tensor(0.2864) tensor(0.2317)
# 56 1000 tensor(0.2678) tensor(0.2320)
# 56 2000 tensor(0.2558) tensor(0.2318)
# 56 3000 tensor(0.1809) tensor(0.2317)
# Removing:./trained_VDNN_50_D_4_30_theta.dat
# ./trained_VDNN_56_D_4_30_theta.dat
# 57 0 tensor(0.2456) tensor(0.2316)
# 57 1000 tensor(0.2087) tensor(0.2319)
# 57 2000 tensor(0.1760) tensor(0.2313)
# 57 3000 tensor(0.2090) tensor(0.2313)
# Removing:./trained_VDNN_51_D_4_30_theta.dat
# ./trained_VDNN_57_D_4_30_theta.dat
# 58 0 tensor(0.1528) tensor(0.2311)
# 58 1000 tensor(0.2588) tensor(0.2309)
# 58 2000 tensor(0.1460) tensor(0.2308)
# 58 3000 tensor(0.1984) tensor(0.2308)
# Removing:./trained_VDNN_52_D_4_30_theta.dat
# ./trained_VDNN_58_D_4_30_theta.dat
# 59 0 tensor(0.2159) tensor(0.2309)
# 59 1000 tensor(0.2569) tensor(0.2312)
# 59 2000 tensor(0.2073) tensor(0.2308)
# 59 3000 tensor(0.1784) tensor(0.2309)
# Removing:./trained_VDNN_53_D_4_30_theta.dat
# ./trained_VDNN_59_D_4_30_theta.dat
# 60 0 tensor(0.2471) tensor(0.2306)
# 60 1000 tensor(0.1885) tensor(0.2304)
# 60 2000 tensor(0.2236) tensor(0.2302)
# 60 3000 tensor(0.1738) tensor(0.2302)
# Removing:./trained_VDNN_54_D_4_30_theta.dat
# ./trained_VDNN_60_D_4_30_theta.dat
# 61 0 tensor(0.2979) tensor(0.2304)
# 61 1000 tensor(0.1365) tensor(0.2301)
# 61 2000 tensor(0.2340) tensor(0.2299)
# 61 3000 tensor(0.2456) tensor(0.2300)
# Removing:./trained_VDNN_55_D_4_30_theta.dat
# ./trained_VDNN_61_D_4_30_theta.dat
# 62 0 tensor(0.2097) tensor(0.2303)
# 62 1000 tensor(0.1467) tensor(0.2300)
# 62 2000 tensor(0.2073) tensor(0.2295)
# 62 3000 tensor(0.2265) tensor(0.2295)
# Removing:./trained_VDNN_56_D_4_30_theta.dat
# ./trained_VDNN_62_D_4_30_theta.dat
# 63 0 tensor(0.2649) tensor(0.2294)
# 63 1000 tensor(0.3232) tensor(0.2292)
# 63 2000 tensor(0.2369) tensor(0.2296)
# 63 3000 tensor(0.2171) tensor(0.2292)
# Removing:./trained_VDNN_57_D_4_30_theta.dat
# ./trained_VDNN_63_D_4_30_theta.dat
# 64 0 tensor(0.2907) tensor(0.2297)
# 64 1000 tensor(0.1837) tensor(0.2292)
# 64 2000 tensor(0.2310) tensor(0.2290)
# 64 3000 tensor(0.2087) tensor(0.2290)
# Removing:./trained_VDNN_58_D_4_30_theta.dat
# ./trained_VDNN_64_D_4_30_theta.dat
# 65 0 tensor(0.2745) tensor(0.2293)
# 65 1000 tensor(0.2052) tensor(0.2290)
# 65 2000 tensor(0.2107) tensor(0.2289)
# 65 3000 tensor(0.1820) tensor(0.2291)
# Removing:./trained_VDNN_59_D_4_30_theta.dat
# ./trained_VDNN_65_D_4_30_theta.dat
# 66 0 tensor(0.1924) tensor(0.2289)
# 66 1000 tensor(0.2533) tensor(0.2291)
# 66 2000 tensor(0.2052) tensor(0.2288)
# 66 3000 tensor(0.2165) tensor(0.2285)
# Removing:./trained_VDNN_60_D_4_30_theta.dat
# ./trained_VDNN_66_D_4_30_theta.dat
# 67 0 tensor(0.2718) tensor(0.2289)
# 67 1000 tensor(0.2553) tensor(0.2288)
# 67 2000 tensor(0.2406) tensor(0.2288)
# 67 3000 tensor(0.2053) tensor(0.2287)
# Removing:./trained_VDNN_61_D_4_30_theta.dat
# ./trained_VDNN_67_D_4_30_theta.dat
# 68 0 tensor(0.1474) tensor(0.2284)
# 68 1000 tensor(0.2894) tensor(0.2284)
# 68 2000 tensor(0.1844) tensor(0.2286)
# 68 3000 tensor(0.2191) tensor(0.2281)
# Removing:./trained_VDNN_62_D_4_30_theta.dat
# ./trained_VDNN_68_D_4_30_theta.dat
# 69 0 tensor(0.1860) tensor(0.2283)
# 69 1000 tensor(0.1823) tensor(0.2284)
# 69 2000 tensor(0.1582) tensor(0.2280)
# 69 3000 tensor(0.2324) tensor(0.2275)
# Removing:./trained_VDNN_63_D_4_30_theta.dat
# ./trained_VDNN_69_D_4_30_theta.dat
# 70 0 tensor(0.2340) tensor(0.2276)
# 70 1000 tensor(0.3516) tensor(0.2276)
# 70 2000 tensor(0.2387) tensor(0.2276)
# 70 3000 tensor(0.2387) tensor(0.2273)
# Removing:./trained_VDNN_64_D_4_30_theta.dat
# ./trained_VDNN_70_D_4_30_theta.dat
# 71 0 tensor(0.2094) tensor(0.2274)
# 71 1000 tensor(0.2614) tensor(0.2275)
# 71 2000 tensor(0.2289) tensor(0.2272)
# 71 3000 tensor(0.2385) tensor(0.2270)
# Removing:./trained_VDNN_65_D_4_30_theta.dat
# ./trained_VDNN_71_D_4_30_theta.dat
# 72 0 tensor(0.2367) tensor(0.2271)
# 72 1000 tensor(0.2389) tensor(0.2269)
# 72 2000 tensor(0.1717) tensor(0.2269)
# 72 3000 tensor(0.2460) tensor(0.2266)
# Removing:./trained_VDNN_66_D_4_30_theta.dat
# ./trained_VDNN_72_D_4_30_theta.dat
# 73 0 tensor(0.1824) tensor(0.2268)
# 73 1000 tensor(0.2127) tensor(0.2269)
# 73 2000 tensor(0.2203) tensor(0.2266)
# 73 3000 tensor(0.1715) tensor(0.2268)
# Removing:./trained_VDNN_67_D_4_30_theta.dat
# ./trained_VDNN_73_D_4_30_theta.dat
# 74 0 tensor(0.1816) tensor(0.2266)
# 74 1000 tensor(0.1896) tensor(0.2262)
# 74 2000 tensor(0.2432) tensor(0.2262)
# 74 3000 tensor(0.2014) tensor(0.2262)
# Removing:./trained_VDNN_68_D_4_30_theta.dat
# ./trained_VDNN_74_D_4_30_theta.dat
# 75 0 tensor(0.2161) tensor(0.2262)
# 75 1000 tensor(0.2221) tensor(0.2260)
# 75 2000 tensor(0.2283) tensor(0.2263)
# 75 3000 tensor(0.2821) tensor(0.2261)
# Removing:./trained_VDNN_69_D_4_30_theta.dat
# ./trained_VDNN_75_D_4_30_theta.dat
# 76 0 tensor(0.1950) tensor(0.2261)
# 76 1000 tensor(0.2744) tensor(0.2258)
# 76 2000 tensor(0.2430) tensor(0.2262)
# 76 3000 tensor(0.1915) tensor(0.2258)
# Removing:./trained_VDNN_70_D_4_30_theta.dat
# ./trained_VDNN_76_D_4_30_theta.dat
# 77 0 tensor(0.2108) tensor(0.2258)
# 77 1000 tensor(0.1883) tensor(0.2257)
# 77 2000 tensor(0.2575) tensor(0.2256)
# 77 3000 tensor(0.2338) tensor(0.2257)
# Removing:./trained_VDNN_71_D_4_30_theta.dat
# ./trained_VDNN_77_D_4_30_theta.dat
# 78 0 tensor(0.2624) tensor(0.2255)
# 78 1000 tensor(0.2311) tensor(0.2253)
# 78 2000 tensor(0.1820) tensor(0.2258)
# 78 3000 tensor(0.2731) tensor(0.2254)
# Removing:./trained_VDNN_72_D_4_30_theta.dat
# ./trained_VDNN_78_D_4_30_theta.dat
# 79 0 tensor(0.2231) tensor(0.2258)
# 79 1000 tensor(0.2377) tensor(0.2257)
# 79 2000 tensor(0.2647) tensor(0.2253)
# 79 3000 tensor(0.1884) tensor(0.2252)
# Removing:./trained_VDNN_73_D_4_30_theta.dat
# ./trained_VDNN_79_D_4_30_theta.dat
# 80 0 tensor(0.1776) tensor(0.2255)
# 80 1000 tensor(0.1708) tensor(0.2253)
# 80 2000 tensor(0.2085) tensor(0.2253)
# 80 3000 tensor(0.1992) tensor(0.2251)
# Removing:./trained_VDNN_74_D_4_30_theta.dat
# ./trained_VDNN_80_D_4_30_theta.dat
# 81 0 tensor(0.2533) tensor(0.2249)
# 81 1000 tensor(0.2322) tensor(0.2250)
# 81 2000 tensor(0.2869) tensor(0.2249)
# 81 3000 tensor(0.1766) tensor(0.2247)
# Removing:./trained_VDNN_75_D_4_30_theta.dat
# ./trained_VDNN_81_D_4_30_theta.dat
# 82 0 tensor(0.1667) tensor(0.2247)
# 82 1000 tensor(0.1978) tensor(0.2246)
# 82 2000 tensor(0.2556) tensor(0.2252)
# 82 3000 tensor(0.2284) tensor(0.2255)
# Removing:./trained_VDNN_76_D_4_30_theta.dat
# ./trained_VDNN_82_D_4_30_theta.dat
# 83 0 tensor(0.2415) tensor(0.2251)
# 83 1000 tensor(0.2759) tensor(0.2246)
# 83 2000 tensor(0.1989) tensor(0.2248)
# 83 3000 tensor(0.2706) tensor(0.2246)
# Removing:./trained_VDNN_77_D_4_30_theta.dat
# ./trained_VDNN_83_D_4_30_theta.dat
# 84 0 tensor(0.2102) tensor(0.2247)
# 84 1000 tensor(0.1909) tensor(0.2243)
# 84 2000 tensor(0.1966) tensor(0.2246)
# 84 3000 tensor(0.2207) tensor(0.2243)
# Removing:./trained_VDNN_78_D_4_30_theta.dat
# ./trained_VDNN_84_D_4_30_theta.dat
# 85 0 tensor(0.1918) tensor(0.2242)
# 85 1000 tensor(0.1402) tensor(0.2241)
# 85 2000 tensor(0.1986) tensor(0.2244)
# 85 3000 tensor(0.2187) tensor(0.2240)
# Removing:./trained_VDNN_79_D_4_30_theta.dat
# ./trained_VDNN_85_D_4_30_theta.dat
# 86 0 tensor(0.2342) tensor(0.2240)
# 86 1000 tensor(0.2220) tensor(0.2239)
# 86 2000 tensor(0.2703) tensor(0.2237)
# 86 3000 tensor(0.1775) tensor(0.2234)
# Removing:./trained_VDNN_80_D_4_30_theta.dat
# ./trained_VDNN_86_D_4_30_theta.dat
# 87 0 tensor(0.2162) tensor(0.2237)
# 87 1000 tensor(0.2213) tensor(0.2235)
# 87 2000 tensor(0.2631) tensor(0.2236)
# 87 3000 tensor(0.2786) tensor(0.2233)
# Removing:./trained_VDNN_81_D_4_30_theta.dat
# ./trained_VDNN_87_D_4_30_theta.dat
# 88 0 tensor(0.2487) tensor(0.2234)
# 88 1000 tensor(0.2600) tensor(0.2231)
# 88 2000 tensor(0.2343) tensor(0.2231)
# 88 3000 tensor(0.2668) tensor(0.2238)
# Removing:./trained_VDNN_82_D_4_30_theta.dat
# ./trained_VDNN_88_D_4_30_theta.dat
# 89 0 tensor(0.1909) tensor(0.2232)
# 89 1000 tensor(0.1986) tensor(0.2233)
# 89 2000 tensor(0.2319) tensor(0.2232)
# 89 3000 tensor(0.2169) tensor(0.2233)
# Removing:./trained_VDNN_83_D_4_30_theta.dat
# ./trained_VDNN_89_D_4_30_theta.dat
# 90 0 tensor(0.2724) tensor(0.2231)
# 90 1000 tensor(0.2665) tensor(0.2232)
# 90 2000 tensor(0.1700) tensor(0.2231)
# 90 3000 tensor(0.1545) tensor(0.2227)
# Removing:./trained_VDNN_84_D_4_30_theta.dat
# ./trained_VDNN_90_D_4_30_theta.dat
# 91 0 tensor(0.2202) tensor(0.2229)
# 91 1000 tensor(0.2481) tensor(0.2226)
# 91 2000 tensor(0.1617) tensor(0.2221)
# 91 3000 tensor(0.1749) tensor(0.2226)
# Removing:./trained_VDNN_85_D_4_30_theta.dat
# ./trained_VDNN_91_D_4_30_theta.dat
# 92 0 tensor(0.2021) tensor(0.2222)
# 92 1000 tensor(0.2306) tensor(0.2223)
# 92 2000 tensor(0.2619) tensor(0.2221)
# 92 3000 tensor(0.2037) tensor(0.2222)
# Removing:./trained_VDNN_86_D_4_30_theta.dat
# ./trained_VDNN_92_D_4_30_theta.dat
# 93 0 tensor(0.2381) tensor(0.2223)
# 93 1000 tensor(0.2776) tensor(0.2223)
# 93 2000 tensor(0.2275) tensor(0.2220)
# 93 3000 tensor(0.2184) tensor(0.2223)
# Removing:./trained_VDNN_87_D_4_30_theta.dat
# ./trained_VDNN_93_D_4_30_theta.dat
# 94 0 tensor(0.1791) tensor(0.2222)
# 94 1000 tensor(0.2946) tensor(0.2225)
# 94 2000 tensor(0.2525) tensor(0.2223)
# 94 3000 tensor(0.1913) tensor(0.2222)
# Removing:./trained_VDNN_88_D_4_30_theta.dat
# ./trained_VDNN_94_D_4_30_theta.dat
# 95 0 tensor(0.2265) tensor(0.2222)
# 95 1000 tensor(0.3069) tensor(0.2219)
# 95 2000 tensor(0.1794) tensor(0.2219)
# 95 3000 tensor(0.2137) tensor(0.2218)
# Removing:./trained_VDNN_89_D_4_30_theta.dat
# ./trained_VDNN_95_D_4_30_theta.dat
# 96 0 tensor(0.2284) tensor(0.2222)
# 96 1000 tensor(0.2204) tensor(0.2216)
# 96 2000 tensor(0.1693) tensor(0.2217)
# 96 3000 tensor(0.1845) tensor(0.2216)
# Removing:./trained_VDNN_90_D_4_30_theta.dat
# ./trained_VDNN_96_D_4_30_theta.dat
# 97 0 tensor(0.1548) tensor(0.2217)
# 97 1000 tensor(0.2370) tensor(0.2219)
# 97 2000 tensor(0.1972) tensor(0.2215)
# 97 3000 tensor(0.2114) tensor(0.2214)
# Removing:./trained_VDNN_91_D_4_30_theta.dat
# ./trained_VDNN_97_D_4_30_theta.dat
# 98 0 tensor(0.2464) tensor(0.2215)
# 98 1000 tensor(0.2554) tensor(0.2213)
# 98 2000 tensor(0.2473) tensor(0.2216)
# 98 3000 tensor(0.1498) tensor(0.2217)
# Removing:./trained_VDNN_92_D_4_30_theta.dat
# ./trained_VDNN_98_D_4_30_theta.dat
# 99 0 tensor(0.2572) tensor(0.2216)
# 99 1000 tensor(0.2068) tensor(0.2214)
# 99 2000 tensor(0.2076) tensor(0.2213)
# 99 3000 tensor(0.1981) tensor(0.2214)
# Removing:./trained_VDNN_93_D_4_30_theta.dat
# ./trained_VDNN_99_D_4_30_theta.dat
# 100 0 tensor(0.1617) tensor(0.2210)
# 100 1000 tensor(0.2103) tensor(0.2209)
# 100 2000 tensor(0.2259) tensor(0.2210)
# 100 3000 tensor(0.1857) tensor(0.2213)
# Removing:./trained_VDNN_94_D_4_30_theta.dat
# ./trained_VDNN_100_D_4_30_theta.dat
# 101 0 tensor(0.2217) tensor(0.2211)
# 101 1000 tensor(0.2294) tensor(0.2208)
# 101 2000 tensor(0.1804) tensor(0.2210)
# 101 3000 tensor(0.2734) tensor(0.2208)
# Removing:./trained_VDNN_95_D_4_30_theta.dat
# ./trained_VDNN_101_D_4_30_theta.dat
# 102 0 tensor(0.2019) tensor(0.2207)
# 102 1000 tensor(0.2547) tensor(0.2205)
# 102 2000 tensor(0.2119) tensor(0.2207)
# 102 3000 tensor(0.1983) tensor(0.2211)
# Removing:./trained_VDNN_96_D_4_30_theta.dat
# ./trained_VDNN_102_D_4_30_theta.dat
# 103 0 tensor(0.1787) tensor(0.2208)
# 103 1000 tensor(0.2305) tensor(0.2206)
# 103 2000 tensor(0.2288) tensor(0.2203)
# 103 3000 tensor(0.1897) tensor(0.2201)
# Removing:./trained_VDNN_97_D_4_30_theta.dat
# ./trained_VDNN_103_D_4_30_theta.dat
# 104 0 tensor(0.1905) tensor(0.2206)
# 104 1000 tensor(0.1967) tensor(0.2201)
# 104 2000 tensor(0.2371) tensor(0.2202)
# 104 3000 tensor(0.1751) tensor(0.2204)
# Removing:./trained_VDNN_98_D_4_30_theta.dat
# ./trained_VDNN_104_D_4_30_theta.dat
# 105 0 tensor(0.1965) tensor(0.2202)
# 105 1000 tensor(0.2389) tensor(0.2201)
# 105 2000 tensor(0.1406) tensor(0.2201)
# 105 3000 tensor(0.2059) tensor(0.2200)
# Removing:./trained_VDNN_99_D_4_30_theta.dat
# ./trained_VDNN_105_D_4_30_theta.dat
# 106 0 tensor(0.2956) tensor(0.2206)
# 106 1000 tensor(0.2233) tensor(0.2202)
# 106 2000 tensor(0.1673) tensor(0.2200)
# 106 3000 tensor(0.1781) tensor(0.2204)
# Removing:./trained_VDNN_100_D_4_30_theta.dat
# ./trained_VDNN_106_D_4_30_theta.dat
# 107 0 tensor(0.2347) tensor(0.2202)
# 107 1000 tensor(0.2325) tensor(0.2203)
# 107 2000 tensor(0.2509) tensor(0.2199)
# 107 3000 tensor(0.2001) tensor(0.2202)
# Removing:./trained_VDNN_101_D_4_30_theta.dat
# ./trained_VDNN_107_D_4_30_theta.dat
# 108 0 tensor(0.2040) tensor(0.2204)
# 108 1000 tensor(0.1976) tensor(0.2198)
# 108 2000 tensor(0.2429) tensor(0.2195)
# 108 3000 tensor(0.2286) tensor(0.2196)
# Removing:./trained_VDNN_102_D_4_30_theta.dat
# ./trained_VDNN_108_D_4_30_theta.dat
# 109 0 tensor(0.2434) tensor(0.2198)
# 109 1000 tensor(0.2191) tensor(0.2197)
# 109 2000 tensor(0.2242) tensor(0.2197)
# 109 3000 tensor(0.1513) tensor(0.2195)
# Removing:./trained_VDNN_103_D_4_30_theta.dat
# ./trained_VDNN_109_D_4_30_theta.dat
# 110 0 tensor(0.3092) tensor(0.2198)
# 110 1000 tensor(0.2317) tensor(0.2197)
# 110 2000 tensor(0.1953) tensor(0.2195)
# 110 3000 tensor(0.1720) tensor(0.2195)
# Removing:./trained_VDNN_104_D_4_30_theta.dat
# ./trained_VDNN_110_D_4_30_theta.dat
# 111 0 tensor(0.1167) tensor(0.2194)
# 111 1000 tensor(0.1923) tensor(0.2195)
# 111 2000 tensor(0.2150) tensor(0.2192)
# 111 3000 tensor(0.2308) tensor(0.2192)
# Removing:./trained_VDNN_105_D_4_30_theta.dat
# ./trained_VDNN_111_D_4_30_theta.dat
# 112 0 tensor(0.2112) tensor(0.2190)
# 112 1000 tensor(0.2269) tensor(0.2195)
# 112 2000 tensor(0.2003) tensor(0.2196)
# 112 3000 tensor(0.2362) tensor(0.2194)
# Removing:./trained_VDNN_106_D_4_30_theta.dat
# ./trained_VDNN_112_D_4_30_theta.dat
# 113 0 tensor(0.2167) tensor(0.2195)
# 113 1000 tensor(0.2707) tensor(0.2193)
# 113 2000 tensor(0.1900) tensor(0.2189)
# 113 3000 tensor(0.1912) tensor(0.2190)
# Removing:./trained_VDNN_107_D_4_30_theta.dat
# ./trained_VDNN_113_D_4_30_theta.dat
# 114 0 tensor(0.2780) tensor(0.2189)
# 114 1000 tensor(0.2426) tensor(0.2191)
# 114 2000 tensor(0.1902) tensor(0.2190)
# 114 3000 tensor(0.2327) tensor(0.2185)
# Removing:./trained_VDNN_108_D_4_30_theta.dat
# ./trained_VDNN_114_D_4_30_theta.dat
# 115 0 tensor(0.2238) tensor(0.2186)
# 115 1000 tensor(0.1342) tensor(0.2186)
# 115 2000 tensor(0.1976) tensor(0.2189)
# 115 3000 tensor(0.1955) tensor(0.2189)
# Removing:./trained_VDNN_109_D_4_30_theta.dat
# ./trained_VDNN_115_D_4_30_theta.dat
# 116 0 tensor(0.2494) tensor(0.2187)
# 116 1000 tensor(0.1831) tensor(0.2189)
# 116 2000 tensor(0.2531) tensor(0.2188)
# 116 3000 tensor(0.2173) tensor(0.2185)
# Removing:./trained_VDNN_110_D_4_30_theta.dat
# ./trained_VDNN_116_D_4_30_theta.dat
# 117 0 tensor(0.1889) tensor(0.2187)
# 117 1000 tensor(0.2479) tensor(0.2189)
# 117 2000 tensor(0.2747) tensor(0.2189)
# 117 3000 tensor(0.2364) tensor(0.2185)
# Removing:./trained_VDNN_111_D_4_30_theta.dat
# ./trained_VDNN_117_D_4_30_theta.dat
# 118 0 tensor(0.1882) tensor(0.2188)
# 118 1000 tensor(0.1559) tensor(0.2187)
# 118 2000 tensor(0.2374) tensor(0.2188)
# 118 3000 tensor(0.1855) tensor(0.2188)
# Removing:./trained_VDNN_112_D_4_30_theta.dat
# ./trained_VDNN_118_D_4_30_theta.dat
# 119 0 tensor(0.2296) tensor(0.2185)
# 119 1000 tensor(0.1937) tensor(0.2187)
# 119 2000 tensor(0.2318) tensor(0.2184)
# 119 3000 tensor(0.1922) tensor(0.2186)
# Removing:./trained_VDNN_113_D_4_30_theta.dat
# ./trained_VDNN_119_D_4_30_theta.dat
# 120 0 tensor(0.2436) tensor(0.2183)
# 120 1000 tensor(0.1654) tensor(0.2182)
# 120 2000 tensor(0.2451) tensor(0.2186)
# 120 3000 tensor(0.2272) tensor(0.2182)
# Removing:./trained_VDNN_114_D_4_30_theta.dat
# ./trained_VDNN_120_D_4_30_theta.dat
# 121 0 tensor(0.2220) tensor(0.2181)
# 121 1000 tensor(0.1964) tensor(0.2182)
# 121 2000 tensor(0.2822) tensor(0.2180)
# 121 3000 tensor(0.3201) tensor(0.2179)
# Removing:./trained_VDNN_115_D_4_30_theta.dat
# ./trained_VDNN_121_D_4_30_theta.dat
# 122 0 tensor(0.2347) tensor(0.2185)
# 122 1000 tensor(0.2378) tensor(0.2181)
# 122 2000 tensor(0.1881) tensor(0.2183)
# 122 3000 tensor(0.1668) tensor(0.2180)
# Removing:./trained_VDNN_116_D_4_30_theta.dat
# ./trained_VDNN_122_D_4_30_theta.dat
# 123 0 tensor(0.2038) tensor(0.2184)
# 123 1000 tensor(0.2510) tensor(0.2182)
# 123 2000 tensor(0.2129) tensor(0.2178)
# 123 3000 tensor(0.2426) tensor(0.2177)
# Removing:./trained_VDNN_117_D_4_30_theta.dat
# ./trained_VDNN_123_D_4_30_theta.dat
# 124 0 tensor(0.2208) tensor(0.2179)
# 124 1000 tensor(0.2025) tensor(0.2177)
# 124 2000 tensor(0.1599) tensor(0.2175)
# 124 3000 tensor(0.1870) tensor(0.2176)
# Removing:./trained_VDNN_118_D_4_30_theta.dat
# ./trained_VDNN_124_D_4_30_theta.dat
# 125 0 tensor(0.2352) tensor(0.2174)
# 125 1000 tensor(0.2058) tensor(0.2173)
# 125 2000 tensor(0.2509) tensor(0.2175)
# 125 3000 tensor(0.2025) tensor(0.2173)
# Removing:./trained_VDNN_119_D_4_30_theta.dat
# ./trained_VDNN_125_D_4_30_theta.dat
# 126 0 tensor(0.2378) tensor(0.2174)
# 126 1000 tensor(0.2488) tensor(0.2173)
# 126 2000 tensor(0.2194) tensor(0.2173)
# 126 3000 tensor(0.1988) tensor(0.2175)
# Removing:./trained_VDNN_120_D_4_30_theta.dat
# ./trained_VDNN_126_D_4_30_theta.dat
# 127 0 tensor(0.2110) tensor(0.2177)
# 127 1000 tensor(0.2477) tensor(0.2172)
# 127 2000 tensor(0.2239) tensor(0.2175)
# 127 3000 tensor(0.2294) tensor(0.2173)
# Removing:./trained_VDNN_121_D_4_30_theta.dat
# ./trained_VDNN_127_D_4_30_theta.dat
# 128 0 tensor(0.2075) tensor(0.2173)
# 128 1000 tensor(0.2621) tensor(0.2174)
# 128 2000 tensor(0.1375) tensor(0.2172)
# 128 3000 tensor(0.2165) tensor(0.2168)
# Removing:./trained_VDNN_122_D_4_30_theta.dat
# ./trained_VDNN_128_D_4_30_theta.dat
# 129 0 tensor(0.2978) tensor(0.2170)
# 129 1000 tensor(0.2314) tensor(0.2171)
# 129 2000 tensor(0.2415) tensor(0.2169)
# 129 3000 tensor(0.2415) tensor(0.2170)
# Removing:./trained_VDNN_123_D_4_30_theta.dat
# ./trained_VDNN_129_D_4_30_theta.dat
# 130 0 tensor(0.2153) tensor(0.2174)
# 130 1000 tensor(0.2518) tensor(0.2169)
# 130 2000 tensor(0.2306) tensor(0.2166)
# 130 3000 tensor(0.2187) tensor(0.2168)
# Removing:./trained_VDNN_124_D_4_30_theta.dat
# ./trained_VDNN_130_D_4_30_theta.dat
# 131 0 tensor(0.2021) tensor(0.2169)
# 131 1000 tensor(0.1668) tensor(0.2169)
# 131 2000 tensor(0.1876) tensor(0.2166)
# 131 3000 tensor(0.1947) tensor(0.2168)
# Removing:./trained_VDNN_125_D_4_30_theta.dat
# ./trained_VDNN_131_D_4_30_theta.dat
# 132 0 tensor(0.3098) tensor(0.2170)
# 132 1000 tensor(0.1884) tensor(0.2170)
# 132 2000 tensor(0.1905) tensor(0.2169)
# 132 3000 tensor(0.1970) tensor(0.2166)
# Removing:./trained_VDNN_126_D_4_30_theta.dat
# ./trained_VDNN_132_D_4_30_theta.dat
# 133 0 tensor(0.1928) tensor(0.2168)
# 133 1000 tensor(0.2400) tensor(0.2165)
# 133 2000 tensor(0.2350) tensor(0.2165)
# 133 3000 tensor(0.1641) tensor(0.2165)
# Removing:./trained_VDNN_127_D_4_30_theta.dat
# ./trained_VDNN_133_D_4_30_theta.dat
# 134 0 tensor(0.1893) tensor(0.2165)
# 134 1000 tensor(0.2086) tensor(0.2165)
# 134 2000 tensor(0.2490) tensor(0.2171)
# 134 3000 tensor(0.2077) tensor(0.2166)
# Removing:./trained_VDNN_128_D_4_30_theta.dat
# ./trained_VDNN_134_D_4_30_theta.dat
# 135 0 tensor(0.2653) tensor(0.2164)
# 135 1000 tensor(0.2466) tensor(0.2167)
# 135 2000 tensor(0.2357) tensor(0.2167)
# 135 3000 tensor(0.1919) tensor(0.2171)
# Removing:./trained_VDNN_129_D_4_30_theta.dat
# ./trained_VDNN_135_D_4_30_theta.dat
# 136 0 tensor(0.2174) tensor(0.2166)
# 136 1000 tensor(0.1704) tensor(0.2164)
# 136 2000 tensor(0.2449) tensor(0.2166)
# 136 3000 tensor(0.2234) tensor(0.2165)
# Removing:./trained_VDNN_130_D_4_30_theta.dat
# ./trained_VDNN_136_D_4_30_theta.dat
# 137 0 tensor(0.2874) tensor(0.2164)
# 137 1000 tensor(0.1166) tensor(0.2165)
# 137 2000 tensor(0.1688) tensor(0.2164)
# 137 3000 tensor(0.1611) tensor(0.2166)
# Removing:./trained_VDNN_131_D_4_30_theta.dat
# ./trained_VDNN_137_D_4_30_theta.dat
# 138 0 tensor(0.1906) tensor(0.2165)
# 138 1000 tensor(0.1748) tensor(0.2167)
# 138 2000 tensor(0.2151) tensor(0.2177)
# 138 3000 tensor(0.1406) tensor(0.2161)
# Removing:./trained_VDNN_132_D_4_30_theta.dat
# ./trained_VDNN_138_D_4_30_theta.dat
# 139 0 tensor(0.2089) tensor(0.2162)
# 139 1000 tensor(0.2257) tensor(0.2162)
# 139 2000 tensor(0.2167) tensor(0.2160)
# 139 3000 tensor(0.1950) tensor(0.2165)
# Removing:./trained_VDNN_133_D_4_30_theta.dat
# ./trained_VDNN_139_D_4_30_theta.dat
# 140 0 tensor(0.2224) tensor(0.2160)
# 140 1000 tensor(0.1820) tensor(0.2162)
# 140 2000 tensor(0.2717) tensor(0.2163)
# 140 3000 tensor(0.2931) tensor(0.2157)
# Removing:./trained_VDNN_134_D_4_30_theta.dat
# ./trained_VDNN_140_D_4_30_theta.dat
# 141 0 tensor(0.1859) tensor(0.2161)
# 141 1000 tensor(0.1647) tensor(0.2160)
# 141 2000 tensor(0.2009) tensor(0.2169)
# 141 3000 tensor(0.2414) tensor(0.2157)
# Removing:./trained_VDNN_135_D_4_30_theta.dat
# ./trained_VDNN_141_D_4_30_theta.dat
# 142 0 tensor(0.2722) tensor(0.2157)
# 142 1000 tensor(0.2415) tensor(0.2159)
# 142 2000 tensor(0.2064) tensor(0.2157)
# 142 3000 tensor(0.2451) tensor(0.2156)
# Removing:./trained_VDNN_136_D_4_30_theta.dat
# ./trained_VDNN_142_D_4_30_theta.dat
# 143 0 tensor(0.1896) tensor(0.2158)
# 143 1000 tensor(0.2752) tensor(0.2157)
# 143 2000 tensor(0.2086) tensor(0.2160)
# 143 3000 tensor(0.1667) tensor(0.2157)
# Removing:./trained_VDNN_137_D_4_30_theta.dat
# ./trained_VDNN_143_D_4_30_theta.dat
# 144 0 tensor(0.2015) tensor(0.2157)
# 144 1000 tensor(0.2288) tensor(0.2158)
# 144 2000 tensor(0.2217) tensor(0.2157)
# 144 3000 tensor(0.1479) tensor(0.2159)
# Removing:./trained_VDNN_138_D_4_30_theta.dat
# ./trained_VDNN_144_D_4_30_theta.dat
# 145 0 tensor(0.1716) tensor(0.2156)
# 145 1000 tensor(0.1855) tensor(0.2157)
# 145 2000 tensor(0.2530) tensor(0.2158)
# 145 3000 tensor(0.1564) tensor(0.2156)
# Removing:./trained_VDNN_139_D_4_30_theta.dat
# ./trained_VDNN_145_D_4_30_theta.dat
# 146 0 tensor(0.1574) tensor(0.2155)
# 146 1000 tensor(0.2553) tensor(0.2157)
# 146 2000 tensor(0.1913) tensor(0.2157)
# 146 3000 tensor(0.1760) tensor(0.2154)
# Removing:./trained_VDNN_140_D_4_30_theta.dat
# ./trained_VDNN_146_D_4_30_theta.dat
# 147 0 tensor(0.2274) tensor(0.2154)
# 147 1000 tensor(0.2185) tensor(0.2152)
# 147 2000 tensor(0.2287) tensor(0.2163)
# 147 3000 tensor(0.3095) tensor(0.2154)
# Removing:./trained_VDNN_141_D_4_30_theta.dat
# ./trained_VDNN_147_D_4_30_theta.dat
# 148 0 tensor(0.1697) tensor(0.2150)
# 148 1000 tensor(0.1499) tensor(0.2153)
# 148 2000 tensor(0.2189) tensor(0.2150)
# 148 3000 tensor(0.2322) tensor(0.2153)
# Removing:./trained_VDNN_142_D_4_30_theta.dat
# ./trained_VDNN_148_D_4_30_theta.dat
# 149 0 tensor(0.1924) tensor(0.2152)
# 149 1000 tensor(0.1845) tensor(0.2152)
# 149 2000 tensor(0.1819) tensor(0.2154)
# 149 3000 tensor(0.2171) tensor(0.2151)
# Removing:./trained_VDNN_143_D_4_30_theta.dat
# ./trained_VDNN_149_D_4_30_theta.dat
# 150 0 tensor(0.2267) tensor(0.2152)
# 150 1000 tensor(0.2773) tensor(0.2160)
# 150 2000 tensor(0.2257) tensor(0.2150)
# 150 3000 tensor(0.1990) tensor(0.2150)
# Removing:./trained_VDNN_144_D_4_30_theta.dat
# ./trained_VDNN_150_D_4_30_theta.dat
# 151 0 tensor(0.1890) tensor(0.2150)
# 151 1000 tensor(0.2690) tensor(0.2149)
# 151 2000 tensor(0.2225) tensor(0.2151)
# 151 3000 tensor(0.1979) tensor(0.2149)
# Removing:./trained_VDNN_145_D_4_30_theta.dat
# ./trained_VDNN_151_D_4_30_theta.dat
# 152 0 tensor(0.1512) tensor(0.2151)
# 152 1000 tensor(0.1701) tensor(0.2147)
# 152 2000 tensor(0.2422) tensor(0.2149)
# 152 3000 tensor(0.1875) tensor(0.2151)
# Removing:./trained_VDNN_146_D_4_30_theta.dat
# ./trained_VDNN_152_D_4_30_theta.dat
# 153 0 tensor(0.2154) tensor(0.2147)
# 153 1000 tensor(0.2315) tensor(0.2148)
# 153 2000 tensor(0.2082) tensor(0.2145)
# 153 3000 tensor(0.2747) tensor(0.2150)
# Removing:./trained_VDNN_147_D_4_30_theta.dat
# ./trained_VDNN_153_D_4_30_theta.dat
# 154 0 tensor(0.1962) tensor(0.2145)
# 154 1000 tensor(0.1323) tensor(0.2142)
# 154 2000 tensor(0.1673) tensor(0.2147)
# 154 3000 tensor(0.1709) tensor(0.2146)
# Removing:./trained_VDNN_148_D_4_30_theta.dat
# ./trained_VDNN_154_D_4_30_theta.dat
# 155 0 tensor(0.1513) tensor(0.2145)
# 155 1000 tensor(0.2377) tensor(0.2144)
# 155 2000 tensor(0.3021) tensor(0.2144)
# 155 3000 tensor(0.1517) tensor(0.2143)
# Removing:./trained_VDNN_149_D_4_30_theta.dat
# ./trained_VDNN_155_D_4_30_theta.dat
# 156 0 tensor(0.2039) tensor(0.2143)
# 156 1000 tensor(0.2528) tensor(0.2146)
# 156 2000 tensor(0.1279) tensor(0.2145)
# 156 3000 tensor(0.2670) tensor(0.2144)
# Removing:./trained_VDNN_150_D_4_30_theta.dat
# ./trained_VDNN_156_D_4_30_theta.dat
# 157 0 tensor(0.2136) tensor(0.2142)
# 157 1000 tensor(0.1925) tensor(0.2143)
# 157 2000 tensor(0.1883) tensor(0.2142)
# 157 3000 tensor(0.1845) tensor(0.2144)
# Removing:./trained_VDNN_151_D_4_30_theta.dat
# ./trained_VDNN_157_D_4_30_theta.dat
# 158 0 tensor(0.1562) tensor(0.2147)
# 158 1000 tensor(0.1891) tensor(0.2143)
# 158 2000 tensor(0.2274) tensor(0.2144)
# 158 3000 tensor(0.1598) tensor(0.2144)
# Removing:./trained_VDNN_152_D_4_30_theta.dat
# ./trained_VDNN_158_D_4_30_theta.dat
# 159 0 tensor(0.2143) tensor(0.2142)
# 159 1000 tensor(0.1896) tensor(0.2142)
# 159 2000 tensor(0.1741) tensor(0.2141)
# 159 3000 tensor(0.2120) tensor(0.2140)
# Removing:./trained_VDNN_153_D_4_30_theta.dat
# ./trained_VDNN_159_D_4_30_theta.dat
# 160 0 tensor(0.2237) tensor(0.2149)
# 160 1000 tensor(0.1713) tensor(0.2142)
# 160 2000 tensor(0.2208) tensor(0.2141)
# 160 3000 tensor(0.1811) tensor(0.2140)
# Removing:./trained_VDNN_154_D_4_30_theta.dat
# ./trained_VDNN_160_D_4_30_theta.dat
# 161 0 tensor(0.1857) tensor(0.2141)
# 161 1000 tensor(0.2834) tensor(0.2139)
# 161 2000 tensor(0.1511) tensor(0.2142)
# 161 3000 tensor(0.2317) tensor(0.2140)
# Removing:./trained_VDNN_155_D_4_30_theta.dat
# ./trained_VDNN_161_D_4_30_theta.dat
# 162 0 tensor(0.2036) tensor(0.2140)
# 162 1000 tensor(0.1808) tensor(0.2137)
# 162 2000 tensor(0.2150) tensor(0.2139)
# 162 3000 tensor(0.1661) tensor(0.2142)
# Removing:./trained_VDNN_156_D_4_30_theta.dat
# ./trained_VDNN_162_D_4_30_theta.dat
# 163 0 tensor(0.1853) tensor(0.2141)
# 163 1000 tensor(0.2056) tensor(0.2142)
# 163 2000 tensor(0.2068) tensor(0.2138)
# 163 3000 tensor(0.1902) tensor(0.2140)
# Removing:./trained_VDNN_157_D_4_30_theta.dat
# ./trained_VDNN_163_D_4_30_theta.dat
# 164 0 tensor(0.1864) tensor(0.2142)
# 164 1000 tensor(0.2791) tensor(0.2141)
# 164 2000 tensor(0.2136) tensor(0.2137)
# 164 3000 tensor(0.1874) tensor(0.2139)
# Removing:./trained_VDNN_158_D_4_30_theta.dat
# ./trained_VDNN_164_D_4_30_theta.dat
# 165 0 tensor(0.1927) tensor(0.2144)
# 165 1000 tensor(0.2479) tensor(0.2139)
# 165 2000 tensor(0.1719) tensor(0.2138)
# 165 3000 tensor(0.2458) tensor(0.2139)
# Removing:./trained_VDNN_159_D_4_30_theta.dat
# ./trained_VDNN_165_D_4_30_theta.dat
# 166 0 tensor(0.1761) tensor(0.2141)
# 166 1000 tensor(0.2526) tensor(0.2139)
# 166 2000 tensor(0.1592) tensor(0.2142)
# 166 3000 tensor(0.2098) tensor(0.2141)
# Removing:./trained_VDNN_160_D_4_30_theta.dat
# ./trained_VDNN_166_D_4_30_theta.dat
# 167 0 tensor(0.2108) tensor(0.2141)
# 167 1000 tensor(0.1968) tensor(0.2136)
# 167 2000 tensor(0.1719) tensor(0.2135)
# 167 3000 tensor(0.1619) tensor(0.2134)
# Removing:./trained_VDNN_161_D_4_30_theta.dat
# ./trained_VDNN_167_D_4_30_theta.dat
# 168 0 tensor(0.1577) tensor(0.2134)
# 168 1000 tensor(0.2850) tensor(0.2134)
# 168 2000 tensor(0.1453) tensor(0.2134)
# 168 3000 tensor(0.2205) tensor(0.2133)
# Removing:./trained_VDNN_162_D_4_30_theta.dat
# ./trained_VDNN_168_D_4_30_theta.dat
# 169 0 tensor(0.1980) tensor(0.2134)
# 169 1000 tensor(0.1718) tensor(0.2133)
# 169 2000 tensor(0.2082) tensor(0.2132)
# 169 3000 tensor(0.2459) tensor(0.2132)
# Removing:./trained_VDNN_163_D_4_30_theta.dat
# ./trained_VDNN_169_D_4_30_theta.dat
# 170 0 tensor(0.2222) tensor(0.2132)
# 170 1000 tensor(0.2173) tensor(0.2132)
# 170 2000 tensor(0.2640) tensor(0.2133)
# 170 3000 tensor(0.1759) tensor(0.2132)
# Removing:./trained_VDNN_164_D_4_30_theta.dat
# ./trained_VDNN_170_D_4_30_theta.dat
# 171 0 tensor(0.3275) tensor(0.2132)
# 171 1000 tensor(0.2245) tensor(0.2131)
# 171 2000 tensor(0.2446) tensor(0.2131)
# 171 3000 tensor(0.2033) tensor(0.2132)
# Removing:./trained_VDNN_165_D_4_30_theta.dat
# ./trained_VDNN_171_D_4_30_theta.dat
# 172 0 tensor(0.2430) tensor(0.2131)
# 172 1000 tensor(0.1915) tensor(0.2131)
# 172 2000 tensor(0.2088) tensor(0.2131)
# 172 3000 tensor(0.1756) tensor(0.2131)
# Removing:./trained_VDNN_166_D_4_30_theta.dat
# ./trained_VDNN_172_D_4_30_theta.dat
# 173 0 tensor(0.1632) tensor(0.2131)
# 173 1000 tensor(0.2377) tensor(0.2131)
# 173 2000 tensor(0.2360) tensor(0.2130)
# 173 3000 tensor(0.2091) tensor(0.2130)
# Removing:./trained_VDNN_167_D_4_30_theta.dat
# ./trained_VDNN_173_D_4_30_theta.dat
# 174 0 tensor(0.1716) tensor(0.2131)
# 174 1000 tensor(0.2529) tensor(0.2130)
# 174 2000 tensor(0.1682) tensor(0.2131)
# 174 3000 tensor(0.1995) tensor(0.2130)
# Removing:./trained_VDNN_168_D_4_30_theta.dat
# ./trained_VDNN_174_D_4_30_theta.dat
# 175 0 tensor(0.2356) tensor(0.2130)
# 175 1000 tensor(0.2063) tensor(0.2131)
# 175 2000 tensor(0.2132) tensor(0.2130)
# 175 3000 tensor(0.1754) tensor(0.2130)
# Removing:./trained_VDNN_169_D_4_30_theta.dat
# ./trained_VDNN_175_D_4_30_theta.dat
# 176 0 tensor(0.2471) tensor(0.2130)
# 176 1000 tensor(0.2167) tensor(0.2129)
# 176 2000 tensor(0.2433) tensor(0.2129)
# 176 3000 tensor(0.1754) tensor(0.2129)
# Removing:./trained_VDNN_170_D_4_30_theta.dat
# ./trained_VDNN_176_D_4_30_theta.dat
# 177 0 tensor(0.1733) tensor(0.2129)
# 177 1000 tensor(0.2501) tensor(0.2129)
# 177 2000 tensor(0.1678) tensor(0.2129)
# 177 3000 tensor(0.2045) tensor(0.2128)
# Removing:./trained_VDNN_171_D_4_30_theta.dat
# ./trained_VDNN_177_D_4_30_theta.dat
# 178 0 tensor(0.2108) tensor(0.2129)
# 178 1000 tensor(0.1674) tensor(0.2129)
# 178 2000 tensor(0.2514) tensor(0.2129)
# 178 3000 tensor(0.1935) tensor(0.2129)
# Removing:./trained_VDNN_172_D_4_30_theta.dat
# ./trained_VDNN_178_D_4_30_theta.dat
# 179 0 tensor(0.1995) tensor(0.2129)
# 179 1000 tensor(0.2323) tensor(0.2129)
# 179 2000 tensor(0.2201) tensor(0.2128)
# 179 3000 tensor(0.1828) tensor(0.2129)
# Removing:./trained_VDNN_173_D_4_30_theta.dat
# ./trained_VDNN_179_D_4_30_theta.dat
# 180 0 tensor(0.1708) tensor(0.2129)
# 180 1000 tensor(0.2880) tensor(0.2129)
# 180 2000 tensor(0.2580) tensor(0.2129)
# 180 3000 tensor(0.1924) tensor(0.2128)
# Removing:./trained_VDNN_174_D_4_30_theta.dat
# ./trained_VDNN_180_D_4_30_theta.dat
# 181 0 tensor(0.1945) tensor(0.2128)
# 181 1000 tensor(0.2115) tensor(0.2128)
# 181 2000 tensor(0.3029) tensor(0.2128)
# 181 3000 tensor(0.2477) tensor(0.2128)
# Removing:./trained_VDNN_175_D_4_30_theta.dat
# ./trained_VDNN_181_D_4_30_theta.dat
# 182 0 tensor(0.2187) tensor(0.2128)
# 182 1000 tensor(0.2285) tensor(0.2128)
# 182 2000 tensor(0.1786) tensor(0.2128)
# 182 3000 tensor(0.2297) tensor(0.2128)
# Removing:./trained_VDNN_176_D_4_30_theta.dat
# ./trained_VDNN_182_D_4_30_theta.dat
# 183 0 tensor(0.1866) tensor(0.2128)
# 183 1000 tensor(0.2240) tensor(0.2128)
# 183 2000 tensor(0.2107) tensor(0.2128)
# 183 3000 tensor(0.1640) tensor(0.2128)
# Removing:./trained_VDNN_177_D_4_30_theta.dat
# ./trained_VDNN_183_D_4_30_theta.dat
# 184 0 tensor(0.2251) tensor(0.2128)
# 184 1000 tensor(0.2051) tensor(0.2128)
# 184 2000 tensor(0.2167) tensor(0.2128)
# 184 3000 tensor(0.1659) tensor(0.2128)
# Removing:./trained_VDNN_178_D_4_30_theta.dat
# ./trained_VDNN_184_D_4_30_theta.dat
# 185 0 tensor(0.2261) tensor(0.2128)
# 185 1000 tensor(0.2865) tensor(0.2128)
# 185 2000 tensor(0.1730) tensor(0.2128)
# 185 3000 tensor(0.1990) tensor(0.2128)
# Removing:./trained_VDNN_179_D_4_30_theta.dat
# ./trained_VDNN_185_D_4_30_theta.dat
# 186 0 tensor(0.2095) tensor(0.2128)
# 186 1000 tensor(0.2421) tensor(0.2128)
# 186 2000 tensor(0.2271) tensor(0.2128)
# 186 3000 tensor(0.2644) tensor(0.2128)
# Removing:./trained_VDNN_180_D_4_30_theta.dat
# ./trained_VDNN_186_D_4_30_theta.dat
# 187 0 tensor(0.2488) tensor(0.2128)
# 187 1000 tensor(0.2372) tensor(0.2128)
# 187 2000 tensor(0.1881) tensor(0.2128)
# 187 3000 tensor(0.2363) tensor(0.2128)
# Removing:./trained_VDNN_181_D_4_30_theta.dat
# ./trained_VDNN_187_D_4_30_theta.dat
# 188 0 tensor(0.2836) tensor(0.2128)
# 188 1000 tensor(0.2113) tensor(0.2128)
# 188 2000 tensor(0.2245) tensor(0.2128)
# 188 3000 tensor(0.1992) tensor(0.2128)
# Removing:./trained_VDNN_182_D_4_30_theta.dat
# ./trained_VDNN_188_D_4_30_theta.dat
# 189 0 tensor(0.2275) tensor(0.2128)
# 189 1000 tensor(0.1738) tensor(0.2128)
# 189 2000 tensor(0.2310) tensor(0.2128)
# 189 3000 tensor(0.2504) tensor(0.2128)
# Removing:./trained_VDNN_183_D_4_30_theta.dat
# ./trained_VDNN_189_D_4_30_theta.dat
# 190 0 tensor(0.2231) tensor(0.2128)
# 190 1000 tensor(0.2009) tensor(0.2128)
# 190 2000 tensor(0.1639) tensor(0.2128)
# 190 3000 tensor(0.1900) tensor(0.2128)
# Removing:./trained_VDNN_184_D_4_30_theta.dat
# ./trained_VDNN_190_D_4_30_theta.dat
# 191 0 tensor(0.2387) tensor(0.2128)
# 191 1000 tensor(0.2374) tensor(0.2128)
# 191 2000 tensor(0.1467) tensor(0.2128)
# 191 3000 tensor(0.1947) tensor(0.2128)
# Removing:./trained_VDNN_185_D_4_30_theta.dat
# ./trained_VDNN_191_D_4_30_theta.dat
# 192 0 tensor(0.2494) tensor(0.2128)
# 192 1000 tensor(0.2136) tensor(0.2128)
# 192 2000 tensor(0.1874) tensor(0.2127)
# 192 3000 tensor(0.2183) tensor(0.2128)
# Removing:./trained_VDNN_186_D_4_30_theta.dat
# ./trained_VDNN_192_D_4_30_theta.dat
# 193 0 tensor(0.3176) tensor(0.2128)
# 193 1000 tensor(0.1905) tensor(0.2127)
# 193 2000 tensor(0.1895) tensor(0.2127)
# 193 3000 tensor(0.2089) tensor(0.2128)
# Removing:./trained_VDNN_187_D_4_30_theta.dat
# ./trained_VDNN_193_D_4_30_theta.dat
# 194 0 tensor(0.2739) tensor(0.2128)
# 194 1000 tensor(0.2122) tensor(0.2128)
# 194 2000 tensor(0.2204) tensor(0.2128)
# 194 3000 tensor(0.2448) tensor(0.2127)
# Removing:./trained_VDNN_188_D_4_30_theta.dat
# ./trained_VDNN_194_D_4_30_theta.dat
# 195 0 tensor(0.2387) tensor(0.2127)
# 195 1000 tensor(0.1864) tensor(0.2128)
# 195 2000 tensor(0.2103) tensor(0.2128)
# 195 3000 tensor(0.2031) tensor(0.2128)
# Removing:./trained_VDNN_189_D_4_30_theta.dat
# ./trained_VDNN_195_D_4_30_theta.dat
# 196 0 tensor(0.2919) tensor(0.2128)
# 196 1000 tensor(0.3039) tensor(0.2128)
# 196 2000 tensor(0.1614) tensor(0.2128)
# 196 3000 tensor(0.1741) tensor(0.2127)
# Removing:./trained_VDNN_190_D_4_30_theta.dat
# ./trained_VDNN_196_D_4_30_theta.dat
# 197 0 tensor(0.1448) tensor(0.2127)
# 197 1000 tensor(0.1722) tensor(0.2127)
# 197 2000 tensor(0.2079) tensor(0.2127)
# 197 3000 tensor(0.2033) tensor(0.2127)
# Removing:./trained_VDNN_191_D_4_30_theta.dat
# ./trained_VDNN_197_D_4_30_theta.dat
# 198 0 tensor(0.2217) tensor(0.2127)
# 198 1000 tensor(0.1850) tensor(0.2127)
# 198 2000 tensor(0.2569) tensor(0.2127)
# 198 3000 tensor(0.2233) tensor(0.2127)
# Removing:./trained_VDNN_192_D_4_30_theta.dat
# ./trained_VDNN_198_D_4_30_theta.dat
# 199 0 tensor(0.1754) tensor(0.2127)
# 199 1000 tensor(0.2433) tensor(0.2127)
# 199 2000 tensor(0.1472) tensor(0.2127)
# 199 3000 tensor(0.1878) tensor(0.2127)
# Removing:./trained_VDNN_193_D_4_30_theta.dat
# ./trained_VDNN_199_D_4_30_theta.dat
# 200 0 tensor(0.2002) tensor(0.2127)
# 200 1000 tensor(0.1961) tensor(0.2127)
# 200 2000 tensor(0.2513) tensor(0.2127)
# 200 3000 tensor(0.1591) tensor(0.2127)
# Removing:./trained_VDNN_194_D_4_30_theta.dat
# ./trained_VDNN_200_D_4_30_theta.dat
# 201 0 tensor(0.2238) tensor(0.2127)
# 201 1000 tensor(0.1599) tensor(0.2127)
# 201 2000 tensor(0.2099) tensor(0.2127)
# 201 3000 tensor(0.2031) tensor(0.2127)
# Removing:./trained_VDNN_195_D_4_30_theta.dat
# ./trained_VDNN_201_D_4_30_theta.dat
# 202 0 tensor(0.1425) tensor(0.2127)
# 202 1000 tensor(0.2252) tensor(0.2127)
# 202 2000 tensor(0.1896) tensor(0.2127)
# 202 3000 tensor(0.1757) tensor(0.2127)
# Removing:./trained_VDNN_196_D_4_30_theta.dat
# ./trained_VDNN_202_D_4_30_theta.dat
# 203 0 tensor(0.2101) tensor(0.2127)
# 203 1000 tensor(0.1731) tensor(0.2127)
# 203 2000 tensor(0.1640) tensor(0.2127)
# 203 3000 tensor(0.2533) tensor(0.2127)
# Removing:./trained_VDNN_197_D_4_30_theta.dat
# ./trained_VDNN_203_D_4_30_theta.dat
# 204 0 tensor(0.2931) tensor(0.2127)
# 204 1000 tensor(0.2481) tensor(0.2127)
# 204 2000 tensor(0.2336) tensor(0.2127)
# 204 3000 tensor(0.2515) tensor(0.2127)
# Removing:./trained_VDNN_198_D_4_30_theta.dat
# ./trained_VDNN_204_D_4_30_theta.dat
# 205 0 tensor(0.2246) tensor(0.2127)
# 205 1000 tensor(0.2338) tensor(0.2127)
# 205 2000 tensor(0.2272) tensor(0.2127)
# 205 3000 tensor(0.1407) tensor(0.2127)
# Removing:./trained_VDNN_199_D_4_30_theta.dat
# ./trained_VDNN_205_D_4_30_theta.dat
# 206 0 tensor(0.2204) tensor(0.2127)
# 206 1000 tensor(0.1864) tensor(0.2127)
# 206 2000 tensor(0.1715) tensor(0.2127)
# 206 3000 tensor(0.2198) tensor(0.2127)
# Removing:./trained_VDNN_200_D_4_30_theta.dat
# ./trained_VDNN_206_D_4_30_theta.dat
# 207 0 tensor(0.2965) tensor(0.2127)
# 207 1000 tensor(0.2315) tensor(0.2127)
# 207 2000 tensor(0.2519) tensor(0.2127)
# 207 3000 tensor(0.2013) tensor(0.2127)
# Removing:./trained_VDNN_201_D_4_30_theta.dat
# ./trained_VDNN_207_D_4_30_theta.dat
# 208 0 tensor(0.2146) tensor(0.2127)
# 208 1000 tensor(0.2445) tensor(0.2127)
# 208 2000 tensor(0.1566) tensor(0.2127)
# 208 3000 tensor(0.2213) tensor(0.2127)
# Removing:./trained_VDNN_202_D_4_30_theta.dat
# ./trained_VDNN_208_D_4_30_theta.dat
# 209 0 tensor(0.2101) tensor(0.2127)
# 209 1000 tensor(0.2470) tensor(0.2127)
# ...
# 432 0 tensor(0.1988) tensor(0.2127)
# 432 1000 tensor(0.2304) tensor(0.2127)
# 432 2000 tensor(0.2833) tensor(0.2127)
# 432 3000 tensor(0.1947) tensor(0.2127)
# Removing:./trained_VDNN_426_D_4_30_theta.dat
# ./trained_VDNN_432_D_4_30_theta.dat
# 433 0 tensor(0.2139) tensor(0.2127)
# 433 1000 tensor(0.1997) tensor(0.2127)
# 433 2000 tensor(0.1699) tensor(0.2127)
# 433 3000 tensor(0.2287) tensor(0.2127)
# Removing:./trained_VDNN_427_D_4_30_theta.dat
# ./trained_VDNN_433_D_4_30_theta.dat
# 434 0 tensor(0.1950) tensor(0.2127)
# 434 1000 tensor(0.1923) tensor(0.2127)
# 434 2000 tensor(0.2041) tensor(0.2127)
# 434 3000 tensor(0.1895) tensor(0.2127)
# Removing:./trained_VDNN_428_D_4_30_theta.dat
# ./trained_VDNN_434_D_4_30_theta.dat
# 435 0 tensor(0.2304) tensor(0.2127)
# 435 1000 tensor(0.1942) tensor(0.2127)
# 435 2000 tensor(0.1622) tensor(0.2127)
# 435 3000 tensor(0.1804) tensor(0.2127)
# Removing:./trained_VDNN_429_D_4_30_theta.dat
# ./trained_VDNN_435_D_4_30_theta.dat
# 436 0 tensor(0.1347) tensor(0.2127)
# 436 1000 tensor(0.1642) tensor(0.2127)
# 436 2000 tensor(0.2071) tensor(0.2127)
# 436 3000 tensor(0.2271) tensor(0.2127)
# Removing:./trained_VDNN_430_D_4_30_theta.dat
# ./trained_VDNN_436_D_4_30_theta.dat
# 437 0 tensor(0.1863) tensor(0.2127)
# 437 1000 tensor(0.1787) tensor(0.2127)
# 437 2000 tensor(0.1928) tensor(0.2127)
# 437 3000 tensor(0.2178) tensor(0.2127)
# Removing:./trained_VDNN_431_D_4_30_theta.dat
# ./trained_VDNN_437_D_4_30_theta.dat
# 438 0 tensor(0.1437) tensor(0.2127)
# 438 1000 tensor(0.2050) tensor(0.2127)
# 438 2000 tensor(0.2668) tensor(0.2127)
# 438 3000 tensor(0.2827) tensor(0.2127)
# Removing:./trained_VDNN_432_D_4_30_theta.dat
# ./trained_VDNN_438_D_4_30_theta.dat
# 439 0 tensor(0.1919) tensor(0.2127)
# 439 1000 tensor(0.2814) tensor(0.2127)
# 439 2000 tensor(0.2126) tensor(0.2127)
# 439 3000 tensor(0.1999) tensor(0.2127)
# Removing:./trained_VDNN_433_D_4_30_theta.dat
# ./trained_VDNN_439_D_4_30_theta.dat
# 440 0 tensor(0.2663) tensor(0.2127)
# 440 1000 tensor(0.1231) tensor(0.2127)
# 440 2000 tensor(0.1845) tensor(0.2127)
# 440 3000 tensor(0.2226) tensor(0.2127)
# Removing:./trained_VDNN_434_D_4_30_theta.dat
# ./trained_VDNN_440_D_4_30_theta.dat
# 441 0 tensor(0.2166) tensor(0.2127)
# 441 1000 tensor(0.2314) tensor(0.2127)
# 441 2000 tensor(0.1893) tensor(0.2127)
# 441 3000 tensor(0.2151) tensor(0.2127)
# Removing:./trained_VDNN_435_D_4_30_theta.dat
# ./trained_VDNN_441_D_4_30_theta.dat
# 442 0 tensor(0.2122) tensor(0.2127)
# 442 1000 tensor(0.2099) tensor(0.2127)
# 442 2000 tensor(0.2210) tensor(0.2127)
# 442 3000 tensor(0.2182) tensor(0.2127)
# Removing:./trained_VDNN_436_D_4_30_theta.dat
# ./trained_VDNN_442_D_4_30_theta.dat
# 443 0 tensor(0.2632) tensor(0.2127)
# 443 1000 tensor(0.2011) tensor(0.2127)
# 443 2000 tensor(0.1782) tensor(0.2127)
# 443 3000 tensor(0.1890) tensor(0.2127)
# Removing:./trained_VDNN_437_D_4_30_theta.dat
# ./trained_VDNN_443_D_4_30_theta.dat
# 444 0 tensor(0.1873) tensor(0.2127)
# 444 1000 tensor(0.1968) tensor(0.2127)
# 444 2000 tensor(0.1977) tensor(0.2127)
# 444 3000 tensor(0.2065) tensor(0.2127)
# Removing:./trained_VDNN_438_D_4_30_theta.dat
# ./trained_VDNN_444_D_4_30_theta.dat
# 445 0 tensor(0.2463) tensor(0.2127)
# 445 1000 tensor(0.2374) tensor(0.2127)
# 445 2000 tensor(0.1979) tensor(0.2127)
# 445 3000 tensor(0.1589) tensor(0.2127)
# Removing:./trained_VDNN_439_D_4_30_theta.dat
# ./trained_VDNN_445_D_4_30_theta.dat
# 446 0 tensor(0.1620) tensor(0.2127)
# 446 1000 tensor(0.2101) tensor(0.2127)
# 446 2000 tensor(0.2248) tensor(0.2127)
# 446 3000 tensor(0.2102) tensor(0.2127)
# Removing:./trained_VDNN_440_D_4_30_theta.dat
# ./trained_VDNN_446_D_4_30_theta.dat
# 447 0 tensor(0.2329) tensor(0.2127)
# 447 1000 tensor(0.1876) tensor(0.2127)
# 447 2000 tensor(0.1822) tensor(0.2127)
# 447 3000 tensor(0.2116) tensor(0.2127)
# Removing:./trained_VDNN_441_D_4_30_theta.dat
# ./trained_VDNN_447_D_4_30_theta.dat
# 448 0 tensor(0.2117) tensor(0.2127)
# 448 1000 tensor(0.1855) tensor(0.2127)
# 448 2000 tensor(0.2581) tensor(0.2127)
# 448 3000 tensor(0.1434) tensor(0.2127)
# Removing:./trained_VDNN_442_D_4_30_theta.dat
# ./trained_VDNN_448_D_4_30_theta.dat
# 449 0 tensor(0.1577) tensor(0.2127)
# 449 1000 tensor(0.2423) tensor(0.2127)
# 449 2000 tensor(0.2006) tensor(0.2127)
# 449 3000 tensor(0.1778) tensor(0.2127)
# Removing:./trained_VDNN_443_D_4_30_theta.dat
# ./trained_VDNN_449_D_4_30_theta.dat
# 450 0 tensor(0.2428) tensor(0.2127)
# 450 1000 tensor(0.2837) tensor(0.2127)
# 450 2000 tensor(0.1895) tensor(0.2127)
# 450 3000 tensor(0.2102) tensor(0.2127)
# Removing:./trained_VDNN_444_D_4_30_theta.dat
# ./trained_VDNN_450_D_4_30_theta.dat
# 451 0 tensor(0.1714) tensor(0.2127)
# 451 1000 tensor(0.2928) tensor(0.2127)
# 451 2000 tensor(0.2149) tensor(0.2127)
# 451 3000 tensor(0.1868) tensor(0.2127)
# Removing:./trained_VDNN_445_D_4_30_theta.dat
# ./trained_VDNN_451_D_4_30_theta.dat
# 452 0 tensor(0.1965) tensor(0.2127)
# 452 1000 tensor(0.1998) tensor(0.2127)
# 452 2000 tensor(0.2514) tensor(0.2127)
# 452 3000 tensor(0.2435) tensor(0.2127)
# Removing:./trained_VDNN_446_D_4_30_theta.dat
# ./trained_VDNN_452_D_4_30_theta.dat
# 453 0 tensor(0.1885) tensor(0.2127)
# 453 1000 tensor(0.2394) tensor(0.2127)
# 453 2000 tensor(0.2344) tensor(0.2127)
# 453 3000 tensor(0.2759) tensor(0.2127)
# Removing:./trained_VDNN_447_D_4_30_theta.dat
# ./trained_VDNN_453_D_4_30_theta.dat
# 454 0 tensor(0.2298) tensor(0.2127)
# 454 1000 tensor(0.1839) tensor(0.2127)
# 454 2000 tensor(0.1863) tensor(0.2127)
# 454 3000 tensor(0.2367) tensor(0.2127)
# Removing:./trained_VDNN_448_D_4_30_theta.dat
# ./trained_VDNN_454_D_4_30_theta.dat
# 455 0 tensor(0.2417) tensor(0.2127)
# 455 1000 tensor(0.1934) tensor(0.2127)
# 455 2000 tensor(0.2032) tensor(0.2127)
# 455 3000 tensor(0.1865) tensor(0.2127)
# Removing:./trained_VDNN_449_D_4_30_theta.dat
# ./trained_VDNN_455_D_4_30_theta.dat
# 456 0 tensor(0.1926) tensor(0.2127)
# 456 1000 tensor(0.2713) tensor(0.2127)
# 456 2000 tensor(0.2452) tensor(0.2127)
# 456 3000 tensor(0.1955) tensor(0.2127)
# Removing:./trained_VDNN_450_D_4_30_theta.dat
# ./trained_VDNN_456_D_4_30_theta.dat
# 457 0 tensor(0.1586) tensor(0.2127)
# 457 1000 tensor(0.2832) tensor(0.2127)
# 457 2000 tensor(0.2581) tensor(0.2127)
# 457 3000 tensor(0.2254) tensor(0.2127)
# Removing:./trained_VDNN_451_D_4_30_theta.dat
# ./trained_VDNN_457_D_4_30_theta.dat
# 458 0 tensor(0.1741) tensor(0.2127)
# 458 1000 tensor(0.1929) tensor(0.2127)
# 458 2000 tensor(0.2508) tensor(0.2127)
# 458 3000 tensor(0.2004) tensor(0.2127)
# Removing:./trained_VDNN_452_D_4_30_theta.dat
# ./trained_VDNN_458_D_4_30_theta.dat
# 459 0 tensor(0.2088) tensor(0.2127)
# 459 1000 tensor(0.2156) tensor(0.2127)
# 459 2000 tensor(0.1549) tensor(0.2127)
# 459 3000 tensor(0.1091) tensor(0.2127)
# Removing:./trained_VDNN_453_D_4_30_theta.dat
# ./trained_VDNN_459_D_4_30_theta.dat
# 460 0 tensor(0.2017) tensor(0.2127)
# 460 1000 tensor(0.2136) tensor(0.2127)
# 460 2000 tensor(0.2375) tensor(0.2127)
# 460 3000 tensor(0.1975) tensor(0.2127)
# Removing:./trained_VDNN_454_D_4_30_theta.dat
# ./trained_VDNN_460_D_4_30_theta.dat
# 461 0 tensor(0.2224) tensor(0.2127)
# 461 1000 tensor(0.1730) tensor(0.2127)
# 461 2000 tensor(0.2688) tensor(0.2127)
# 461 3000 tensor(0.2438) tensor(0.2127)
# Removing:./trained_VDNN_455_D_4_30_theta.dat
# ./trained_VDNN_461_D_4_30_theta.dat
# 462 0 tensor(0.1437) tensor(0.2127)
# 462 1000 tensor(0.2572) tensor(0.2127)
# 462 2000 tensor(0.2219) tensor(0.2127)
# 462 3000 tensor(0.2510) tensor(0.2127)
# Removing:./trained_VDNN_456_D_4_30_theta.dat
# ./trained_VDNN_462_D_4_30_theta.dat
# 463 0 tensor(0.2358) tensor(0.2127)
# 463 1000 tensor(0.2871) tensor(0.2127)
# 463 2000 tensor(0.1911) tensor(0.2127)
# 463 3000 tensor(0.2021) tensor(0.2127)
# Removing:./trained_VDNN_457_D_4_30_theta.dat
# ./trained_VDNN_463_D_4_30_theta.dat
# 464 0 tensor(0.2207) tensor(0.2127)
# 464 1000 tensor(0.1751) tensor(0.2127)
# 464 2000 tensor(0.1689) tensor(0.2127)
# 464 3000 tensor(0.2208) tensor(0.2127)
# Removing:./trained_VDNN_458_D_4_30_theta.dat
# ./trained_VDNN_464_D_4_30_theta.dat
# 465 0 tensor(0.1606) tensor(0.2127)
# 465 1000 tensor(0.2040) tensor(0.2127)
# 465 2000 tensor(0.2428) tensor(0.2127)
# 465 3000 tensor(0.1941) tensor(0.2127)
# Removing:./trained_VDNN_459_D_4_30_theta.dat
# ./trained_VDNN_465_D_4_30_theta.dat
# 466 0 tensor(0.1857) tensor(0.2127)
# 466 1000 tensor(0.2185) tensor(0.2127)
# 466 2000 tensor(0.2593) tensor(0.2127)
# 466 3000 tensor(0.2504) tensor(0.2127)
# Removing:./trained_VDNN_460_D_4_30_theta.dat
# ./trained_VDNN_466_D_4_30_theta.dat
# 467 0 tensor(0.1482) tensor(0.2127)
# 467 1000 tensor(0.2400) tensor(0.2127)
# 467 2000 tensor(0.2223) tensor(0.2127)
# 467 3000 tensor(0.2469) tensor(0.2127)
# Removing:./trained_VDNN_461_D_4_30_theta.dat
# ./trained_VDNN_467_D_4_30_theta.dat
# 468 0 tensor(0.2804) tensor(0.2127)
# 468 1000 tensor(0.2345) tensor(0.2127)
# 468 2000 tensor(0.2162) tensor(0.2127)
# 468 3000 tensor(0.2466) tensor(0.2127)
# Removing:./trained_VDNN_462_D_4_30_theta.dat
# ./trained_VDNN_468_D_4_30_theta.dat
# 469 0 tensor(0.2310) tensor(0.2127)
# 469 1000 tensor(0.2268) tensor(0.2127)
# 469 2000 tensor(0.2044) tensor(0.2127)
# 469 3000 tensor(0.1619) tensor(0.2127)
# Removing:./trained_VDNN_463_D_4_30_theta.dat
# ./trained_VDNN_469_D_4_30_theta.dat
# 470 0 tensor(0.1632) tensor(0.2127)
# 470 1000 tensor(0.1882) tensor(0.2127)
# 470 2000 tensor(0.2293) tensor(0.2127)
# 470 3000 tensor(0.1518) tensor(0.2127)
# Removing:./trained_VDNN_464_D_4_30_theta.dat
# ./trained_VDNN_470_D_4_30_theta.dat
# 471 0 tensor(0.2023) tensor(0.2127)
# 471 1000 tensor(0.1615) tensor(0.2127)
# 471 2000 tensor(0.1668) tensor(0.2127)
# 471 3000 tensor(0.2690) tensor(0.2127)
# Removing:./trained_VDNN_465_D_4_30_theta.dat
# ./trained_VDNN_471_D_4_30_theta.dat
# 472 0 tensor(0.2635) tensor(0.2127)
# 472 1000 tensor(0.2358) tensor(0.2127)
# 472 2000 tensor(0.1936) tensor(0.2127)
# 472 3000 tensor(0.2463) tensor(0.2127)
# Removing:./trained_VDNN_466_D_4_30_theta.dat
# ./trained_VDNN_472_D_4_30_theta.dat
# 473 0 tensor(0.2017) tensor(0.2127)
# 473 1000 tensor(0.1574) tensor(0.2127)
# 473 2000 tensor(0.1823) tensor(0.2127)
# 473 3000 tensor(0.2485) tensor(0.2127)
# Removing:./trained_VDNN_467_D_4_30_theta.dat
# ./trained_VDNN_473_D_4_30_theta.dat
# 474 0 tensor(0.1842) tensor(0.2127)
# 474 1000 tensor(0.2151) tensor(0.2127)
# 474 2000 tensor(0.2571) tensor(0.2127)
# 474 3000 tensor(0.1829) tensor(0.2127)
# Removing:./trained_VDNN_468_D_4_30_theta.dat
# ./trained_VDNN_474_D_4_30_theta.dat
# 475 0 tensor(0.2198) tensor(0.2127)
# 475 1000 tensor(0.1736) tensor(0.2127)
# 475 2000 tensor(0.2106) tensor(0.2127)
# 475 3000 tensor(0.1790) tensor(0.2127)
# Removing:./trained_VDNN_469_D_4_30_theta.dat
# ./trained_VDNN_475_D_4_30_theta.dat
# 476 0 tensor(0.2263) tensor(0.2127)
# 476 1000 tensor(0.2295) tensor(0.2127)
# 476 2000 tensor(0.2202) tensor(0.2127)
# 476 3000 tensor(0.2281) tensor(0.2127)
# Removing:./trained_VDNN_470_D_4_30_theta.dat
# ./trained_VDNN_476_D_4_30_theta.dat
# 477 0 tensor(0.2511) tensor(0.2127)
# 477 1000 tensor(0.1801) tensor(0.2127)
# 477 2000 tensor(0.2299) tensor(0.2127)
# 477 3000 tensor(0.1612) tensor(0.2127)
# Removing:./trained_VDNN_471_D_4_30_theta.dat
# ./trained_VDNN_477_D_4_30_theta.dat
# 478 0 tensor(0.2833) tensor(0.2127)
# 478 1000 tensor(0.1445) tensor(0.2127)
# 478 2000 tensor(0.1797) tensor(0.2127)
# 478 3000 tensor(0.1730) tensor(0.2127)
# Removing:./trained_VDNN_472_D_4_30_theta.dat
# ./trained_VDNN_478_D_4_30_theta.dat
# 479 0 tensor(0.1531) tensor(0.2127)
# 479 1000 tensor(0.2288) tensor(0.2127)
# 479 2000 tensor(0.2407) tensor(0.2127)
# 479 3000 tensor(0.2328) tensor(0.2127)
# Removing:./trained_VDNN_473_D_4_30_theta.dat
# ./trained_VDNN_479_D_4_30_theta.dat
# 480 0 tensor(0.2699) tensor(0.2127)
# 480 1000 tensor(0.2218) tensor(0.2127)
# 480 2000 tensor(0.1874) tensor(0.2127)
# 480 3000 tensor(0.1869) tensor(0.2127)
# Removing:./trained_VDNN_474_D_4_30_theta.dat
# ./trained_VDNN_480_D_4_30_theta.dat
# 481 0 tensor(0.2274) tensor(0.2127)
# 481 1000 tensor(0.1834) tensor(0.2127)
# 481 2000 tensor(0.1968) tensor(0.2127)
# 481 3000 tensor(0.1931) tensor(0.2127)
# Removing:./trained_VDNN_475_D_4_30_theta.dat
# ./trained_VDNN_481_D_4_30_theta.dat
# 482 0 tensor(0.1510) tensor(0.2127)
# 482 1000 tensor(0.2626) tensor(0.2127)
# 482 2000 tensor(0.2573) tensor(0.2127)
# 482 3000 tensor(0.1818) tensor(0.2127)
# Removing:./trained_VDNN_476_D_4_30_theta.dat
# ./trained_VDNN_482_D_4_30_theta.dat
# 483 0 tensor(0.3581) tensor(0.2127)
# 483 1000 tensor(0.1764) tensor(0.2127)
# 483 2000 tensor(0.1664) tensor(0.2127)
# 483 3000 tensor(0.2157) tensor(0.2127)
# Removing:./trained_VDNN_477_D_4_30_theta.dat
# ./trained_VDNN_483_D_4_30_theta.dat
# 484 0 tensor(0.1413) tensor(0.2127)
# 484 1000 tensor(0.2779) tensor(0.2127)
# 484 2000 tensor(0.1973) tensor(0.2127)
# 484 3000 tensor(0.1889) tensor(0.2127)
# Removing:./trained_VDNN_478_D_4_30_theta.dat
# ./trained_VDNN_484_D_4_30_theta.dat
# 485 0 tensor(0.2307) tensor(0.2127)
# 485 1000 tensor(0.1805) tensor(0.2127)
# 485 2000 tensor(0.2043) tensor(0.2127)
# 485 3000 tensor(0.1736) tensor(0.2127)
# Removing:./trained_VDNN_479_D_4_30_theta.dat
# ./trained_VDNN_485_D_4_30_theta.dat
# 486 0 tensor(0.2184) tensor(0.2127)
# 486 1000 tensor(0.2042) tensor(0.2127)
# 486 2000 tensor(0.2313) tensor(0.2127)
# 486 3000 tensor(0.1954) tensor(0.2127)
# Removing:./trained_VDNN_480_D_4_30_theta.dat
# ./trained_VDNN_486_D_4_30_theta.dat
# 487 0 tensor(0.2560) tensor(0.2127)
# 487 1000 tensor(0.2236) tensor(0.2127)
# 487 2000 tensor(0.2015) tensor(0.2127)
# 487 3000 tensor(0.1853) tensor(0.2127)
# Removing:./trained_VDNN_481_D_4_30_theta.dat
# ./trained_VDNN_487_D_4_30_theta.dat
# 488 0 tensor(0.2105) tensor(0.2127)
# 488 1000 tensor(0.2927) tensor(0.2127)
# 488 2000 tensor(0.2210) tensor(0.2127)
# 488 3000 tensor(0.1628) tensor(0.2127)
# Removing:./trained_VDNN_482_D_4_30_theta.dat
# ./trained_VDNN_488_D_4_30_theta.dat
# 489 0 tensor(0.2208) tensor(0.2127)
# 489 1000 tensor(0.2391) tensor(0.2127)
# 489 2000 tensor(0.1887) tensor(0.2127)
# 489 3000 tensor(0.2394) tensor(0.2127)
# Removing:./trained_VDNN_483_D_4_30_theta.dat
# ./trained_VDNN_489_D_4_30_theta.dat
# 490 0 tensor(0.2099) tensor(0.2127)
# 490 1000 tensor(0.2746) tensor(0.2127)
# 490 2000 tensor(0.1941) tensor(0.2127)
# 490 3000 tensor(0.1912) tensor(0.2127)
# Removing:./trained_VDNN_484_D_4_30_theta.dat
# ./trained_VDNN_490_D_4_30_theta.dat
# 491 0 tensor(0.2290) tensor(0.2127)
# 491 1000 tensor(0.2234) tensor(0.2127)
# 491 2000 tensor(0.1913) tensor(0.2127)
# 491 3000 tensor(0.2022) tensor(0.2127)
# Removing:./trained_VDNN_485_D_4_30_theta.dat
# ./trained_VDNN_491_D_4_30_theta.dat
# 492 0 tensor(0.2420) tensor(0.2127)
# 492 1000 tensor(0.2653) tensor(0.2127)
# 492 2000 tensor(0.2468) tensor(0.2127)
# 492 3000 tensor(0.2109) tensor(0.2127)
# Removing:./trained_VDNN_486_D_4_30_theta.dat
# ./trained_VDNN_492_D_4_30_theta.dat
# 493 0 tensor(0.2133) tensor(0.2127)
# 493 1000 tensor(0.2244) tensor(0.2127)
# 493 2000 tensor(0.1752) tensor(0.2127)
# 493 3000 tensor(0.2011) tensor(0.2127)
# Removing:./trained_VDNN_487_D_4_30_theta.dat
# ./trained_VDNN_493_D_4_30_theta.dat
# 494 0 tensor(0.1296) tensor(0.2127)
# 494 1000 tensor(0.2491) tensor(0.2127)
# 494 2000 tensor(0.1652) tensor(0.2127)
# 494 3000 tensor(0.2675) tensor(0.2127)
# Removing:./trained_VDNN_488_D_4_30_theta.dat
# ./trained_VDNN_494_D_4_30_theta.dat
# 495 0 tensor(0.2380) tensor(0.2127)
# 495 1000 tensor(0.1793) tensor(0.2127)
# 495 2000 tensor(0.2814) tensor(0.2127)
# 495 3000 tensor(0.1878) tensor(0.2127)
# Removing:./trained_VDNN_489_D_4_30_theta.dat
# ./trained_VDNN_495_D_4_30_theta.dat
# 496 0 tensor(0.1931) tensor(0.2127)
# 496 1000 tensor(0.2052) tensor(0.2127)
# 496 2000 tensor(0.1956) tensor(0.2127)
# 496 3000 tensor(0.2906) tensor(0.2127)
# Removing:./trained_VDNN_490_D_4_30_theta.dat
# ./trained_VDNN_496_D_4_30_theta.dat
# 497 0 tensor(0.1978) tensor(0.2127)
# 497 1000 tensor(0.2086) tensor(0.2127)
# 497 2000 tensor(0.1673) tensor(0.2127)
# 497 3000 tensor(0.2352) tensor(0.2127)
# Removing:./trained_VDNN_491_D_4_30_theta.dat
# ./trained_VDNN_497_D_4_30_theta.dat
# 498 0 tensor(0.1551) tensor(0.2127)
# 498 1000 tensor(0.2017) tensor(0.2127)
# 498 2000 tensor(0.2397) tensor(0.2127)
# 498 3000 tensor(0.2766) tensor(0.2127)
# Removing:./trained_VDNN_492_D_4_30_theta.dat
# ./trained_VDNN_498_D_4_30_theta.dat
# 499 0 tensor(0.2526) tensor(0.2127)
# 499 1000 tensor(0.2405) tensor(0.2127)
# 499 2000 tensor(0.1664) tensor(0.2127)
# 499 3000 tensor(0.1952) tensor(0.2127)
# Removing:./trained_VDNN_493_D_4_30_theta.dat
# ./trained_VDNN_499_D_4_30_theta.dat
# CPU times: user 5h 34min 52s, sys: 24min 8s, total: 5h 59min
# Wall time: 3h 16s

# %% [markdown]
# ## G = 0.0 Testing

# %%
#Plot the output
outputs=[]
outputs_01=[]
outputs2=[]
net_ordinary.eval()
with torch.no_grad():
    for i in torch.arange(Targs.shape[0]):
        d=data_validate[i,:,:]
        output=net_ordinary(torch.tensor(d,dtype=torch.float32))
        output_01=(output>0.5)
        outputs_01.append(output_01.squeeze().detach().numpy())
        shfl=np.random.permutation(np.arange(1600))
        output2=net_ordinary(torch.tensor(d[:,shfl],dtype=torch.float32))
        outputs.append(output.squeeze().detach().numpy())
        outputs2.append(output2.squeeze().detach().numpy())
    
#plt.plot(outputs.squeeze(),"o",alpha=0.02,color='red')
#plt.plot(labels_validate)
#depth=6
sns.set_style("whitegrid")
mu=np.average(np.fabs(np.average(data_validate[:,:2000,:],axis=2)),axis=1)
outputs=np.array(outputs)
outputs2=np.array(outputs2)
Tsn=Ts_G_0[Targs]
ax=plt.axes()

ax.scatter(np.repeat(Tsn,2000),np.concatenate(outputs),alpha=0.002,s=8.0,color='springgreen')

#plt.plot(Tsn,labels_tmp,"g.--")
ax.plot(Tsn,mu,"r--",alpha=0.4,label="\mu")
#plt.plot(Tsn,np.average(outputs,axis=1),"o-",markersize=4,color='darkgreen')
ax.plot(Tsn,np.average(outputs_01,axis=1),"o-",markersize=4,color='darkgreen',label='Model output')
T0,T1=Tsn[np.where(labels_tmp==1.0)[0][[0,-1]]]
ax.vlines(T0,0,1,color='magenta',linestyle='dashed')
ax.vlines(T1,0,1,color='magenta',linestyle='dashed')
ax.plot(Tsn,np.average(outputs2,axis=1),"*-",color='purple',label='Model output shuffled')
#plt.plot(Ts,probs)
# ax.plot(Tc,mu_avc,"r",alpha=0.4) # Ask Pallab - what is mu_avc

#plt.legend(loc="upper right")/
handles, labels = ax.get_legend_handles_labels()
plt.savefig("%s_testdata_g0.pdf"%(sfname[:-4]),dpi=300)

#

# %%
# -----------------Dileep's modification ---------------------
# Just to save the data for plotting later figures
df_ordinary_G_0 = pd.DataFrame()
df_ordinary_G_0["Ts"] = Ts_G_0
df_ordinary_G_0["mu"] = mu
df_ordinary_G_0["ordinary_data_avg_pred"] = np.average(outputs_01,axis=1)
df_ordinary_G_0["shuffled_data_avg_pred"] = np.average(outputs2,axis=1)
# ------------------------------------------------------------

# %% [markdown]
# # G = 0.1 Testing

# %%
#Plot the output
outputs=[]
outputs_01=[]
outputs2=[]
net_ordinary.eval()
with torch.no_grad():
    for i in torch.arange(Targs.shape[0]):
        d=data_validate_new[i,:,:]
        output=net_ordinary(torch.tensor(d,dtype=torch.float32))
        output_01=(output>0.5)
        outputs_01.append(output_01.squeeze().detach().numpy())
        shfl=np.random.permutation(np.arange(1600))
        output2=net_ordinary(torch.tensor(d[:,shfl],dtype=torch.float32))
        outputs.append(output.squeeze().detach().numpy())
        outputs2.append(output2.squeeze().detach().numpy())
    
#plt.plot(outputs.squeeze(),"o",alpha=0.02,color='red')
#plt.plot(labels_validate)
#depth=6
sns.set_style("whitegrid")
mu=np.average(np.fabs(np.average(data_validate_new[:,:2000,:],axis=2)),axis=1)
outputs=np.array(outputs)
outputs2=np.array(outputs2)
Tsn=Ts_G_0_1[Targs]
ax=plt.axes()

ax.scatter(np.repeat(Tsn,2000),np.concatenate(outputs),alpha=0.002,s=8.0,color='springgreen')

#plt.plot(Tsn,labels_tmp,"g.--")
ax.plot(Tsn,mu,"r--",alpha=0.4,label="\mu")
#plt.plot(Tsn,np.average(outputs,axis=1),"o-",markersize=4,color='darkgreen')
ax.plot(Tsn,np.average(outputs_01,axis=1),"o-",markersize=4,color='darkgreen',label='Model output')
T0,T1=Tsn[np.where(labels_tmp==1.0)[0][[0,-1]]]
# ax.vlines(T0,0,1,color='magenta',linestyle='dashed')
# ax.vlines(T1,0,1,color='magenta',linestyle='dashed')
ax.plot(Tsn,np.average(outputs2,axis=1),"*-",color='purple',label='Model output shuffled')
#plt.plot(Ts,probs)
# ax.plot(Tc,mu_avc,"r",alpha=0.4) # Ask Pallab - what is mu_avc

#plt.legend(loc="upper right")/
handles, labels = ax.get_legend_handles_labels()
plt.savefig("%s_testdata_g0.pdf"%(sfname[:-4]),dpi=300)

# %%
# -----------------Dileep's modification ---------------------
# Just to save the data for plotting later figures
df_ordinary_G_0_1 = pd.DataFrame()
df_ordinary_G_0_1["Ts"] = Ts_G_0_1
df_ordinary_G_0_1["mu"] = mu
df_ordinary_G_0_1["ordinary_data_avg_pred"] = np.average(outputs_01,axis=1)
df_ordinary_G_0_1["shuffled_data_avg_pred"] = np.average(outputs2,axis=1)
# ------------------------------------------------------------

# %% [markdown]
# ## G = 0.5 Testing

# %%
#Plot the output
outputs=[]
outputs_01=[]
outputs2=[]
net_ordinary.eval()
with torch.no_grad():
    for i in torch.arange(Targs.shape[0]):
        d=data_validate_new2[i,:,:]
        output=net_ordinary(torch.tensor(d,dtype=torch.float32))
        output_01=(output>0.5)
        outputs_01.append(output_01.squeeze().detach().numpy())
        shfl=np.random.permutation(np.arange(1600))
        output2=net_ordinary(torch.tensor(d[:,shfl],dtype=torch.float32))
        outputs.append(output.squeeze().detach().numpy())
        outputs2.append(output2.squeeze().detach().numpy())
    
#plt.plot(outputs.squeeze(),"o",alpha=0.02,color='red')
#plt.plot(labels_validate)
#depth=6
sns.set_style("whitegrid")
mu=np.average(np.fabs(np.average(data_validate_new2[:,:2000,:],axis=2)),axis=1)
outputs=np.array(outputs)
outputs2=np.array(outputs2)
Tsn=Ts_G_0_5[Targs]
ax=plt.axes()

ax.scatter(np.repeat(Tsn,2000),np.concatenate(outputs),alpha=0.002,s=8.0,color='springgreen')

#plt.plot(Tsn,labels_tmp,"g.--")
ax.plot(Tsn,mu,"r--",alpha=0.4,label="\mu")
#plt.plot(Tsn,np.average(outputs,axis=1),"o-",markersize=4,color='darkgreen')
ax.plot(Tsn,np.average(outputs_01,axis=1),"o-",markersize=4,color='darkgreen',label='Model output')
T0,T1=Tsn[np.where(labels_tmp==1.0)[0][[0,-1]]]
# ax.vlines(T0,0,1,color='magenta',linestyle='dashed')
# ax.vlines(T1,0,1,color='magenta',linestyle='dashed')
ax.plot(Tsn,np.average(outputs2,axis=1),"*-",color='purple',label='Model output shuffled')
#plt.plot(Ts,probs)
# ax.plot(Tc,mu_avc,"r",alpha=0.4) # Ask Pallab - what is mu_avc

#plt.legend(loc="upper right")/
handles, labels = ax.get_legend_handles_labels()
plt.savefig("%s_testdata_g0.pdf"%(sfname[:-4]),dpi=300)

# %%
# -----------------Dileep's modification ---------------------
# Just to save the data for plotting later figures
df_ordinary_G_0_5 = pd.DataFrame()
df_ordinary_G_0_5["Ts"] = Ts_G_0_5
df_ordinary_G_0_5["mu"] = mu
df_ordinary_G_0_5["ordinary_data_avg_pred"] = np.average(outputs_01,axis=1)
df_ordinary_G_0_5["shuffled_data_avg_pred"] = np.average(outputs2,axis=1)
# ------------------------------------------------------------

# %% [markdown]
# # <span style="color:green"> Final Plots</span>

# %%
if not os.path.isdir("Generated_plots"):
    os.mkdir("Generated_plots")
    
    
# Ploting for G=0.0
plt.figure(dpi=150)
plt.plot(df_adversarial_G_0["Ts"], df_adversarial_G_0["mu"], "r--", alpha=0.4, label="Magnetization")
plt.plot(df_adversarial_G_0["Ts"],df_adversarial_G_0["ordinary_data_avg_pred"], "o-", markersize=4, color='darkgreen', label="adve_ord")
plt.plot(df_adversarial_G_0["Ts"],df_adversarial_G_0["shuffled_data_avg_pred"], "*-", color='purple', label="adve_shuff")
# plt.plot(df_ordinary_G_0["Ts"],df_ordinary_G_0["ordinary_data_avg_pred"],label="*****")
plt.plot(df_ordinary_G_0["Ts"],df_ordinary_G_0["shuffled_data_avg_pred"], '.-', label="ord_shuff")
# --------------------------------------------------------------------
Ts = G_0_adversarial_scatter_plot_info_dict["Ts"]
outputs = G_0_adversarial_scatter_plot_info_dict["outputs"]
T0 = G_0_adversarial_scatter_plot_info_dict["T0"]
T1 = G_0_adversarial_scatter_plot_info_dict["T1"]
plt.scatter(Ts,outputs,alpha=0.002,s=8.0,color='springgreen')
# plt.vlines(T0,0,1,color='magenta',linestyle='dashed')
# plt.vlines(T1,0,1,color='magenta',linestyle='dashed')
# --------------------------------------------------------------------
plt.xlabel("T--->")
plt.ylabel("Accuracies--->")
plt.legend()
plt.grid(True)
plt.title(f"G=0")
figure_file_name = f"G_0_accuracies_vs_T.jpg"
figure_file_path = os.path.join("Generated_plots",figure_file_name)
plt.tight_layout()
plt.savefig(figure_file_path)


# Ploting for G=0.1
plt.figure(dpi=150)
plt.plot(df_adversarial_G_0_1["Ts"],df_adversarial_G_0_1["mu"], "r--", alpha=0.4, label="Magnetization")
plt.plot(df_adversarial_G_0_1["Ts"],df_adversarial_G_0_1["ordinary_data_avg_pred"], "o-", markersize=4, color='darkgreen', label="adve_ord")
plt.plot(df_adversarial_G_0_1["Ts"],df_adversarial_G_0_1["shuffled_data_avg_pred"], "*-", color='purple', label="adve_shuff")
# plt.plot(df_ordinary_G_0_1["Ts"],df_ordinary_G_0_1["ordinary_data_avg_pred"],label="*****")
plt.plot(df_ordinary_G_0_1["Ts"],df_ordinary_G_0_1["shuffled_data_avg_pred"], '.-', label="ord_shuff")
# --------------------------------------------------------------------
Ts = G_0_1_adversarial_scatter_plot_info_dict["Ts"]
outputs = G_0_1_adversarial_scatter_plot_info_dict["outputs"]
T0 = G_0_1_adversarial_scatter_plot_info_dict["T0"]
T1 = G_0_1_adversarial_scatter_plot_info_dict["T1"]
plt.scatter(Ts,outputs,alpha=0.002,s=8.0,color='springgreen')
# plt.vlines(T0,0,1,color='magenta',linestyle='dashed')
# plt.vlines(T1,0,1,color='magenta',linestyle='dashed')
# --------------------------------------------------------------------
plt.xlabel("T--->")
plt.ylabel("Accuracies--->")
plt.legend()
plt.grid(True)
plt.title(f"G=0.1")
figure_file_name = f"G_0_1_accuracies_vs_T.jpg"
figure_file_path = os.path.join("Generated_plots",figure_file_name)
plt.tight_layout()
plt.savefig(figure_file_path)


# Ploting for G=0.5
plt.figure(dpi=150)
plt.plot(df_adversarial_G_0_5["Ts"],df_adversarial_G_0_5["mu"], "r--", alpha=0.4, label="Magnetization")
plt.plot(df_adversarial_G_0_5["Ts"],df_adversarial_G_0_5["ordinary_data_avg_pred"], "o-", markersize=4, color='darkgreen', label="adve_ord")
plt.plot(df_adversarial_G_0_5["Ts"],df_adversarial_G_0_5["shuffled_data_avg_pred"], "*-", color='purple', label="adve_shuff")
# plt.plot(df_ordinary_G_0_5["Ts"],df_ordinary_G_0_5["ordinary_data_avg_pred"],label="*****")
plt.plot(df_ordinary_G_0_5["Ts"],df_ordinary_G_0_5["shuffled_data_avg_pred"], '.-', label="ord_shuff")
# --------------------------------------------------------------------
Ts = G_0_5_adversarial_scatter_plot_info_dict["Ts"]
outputs = G_0_5_adversarial_scatter_plot_info_dict["outputs"]
T0 = G_0_5_adversarial_scatter_plot_info_dict["T0"]
T1 = G_0_5_adversarial_scatter_plot_info_dict["T1"]
plt.scatter(Ts,outputs,alpha=0.002,s=8.0,color='springgreen')
# plt.vlines(T0,0,1,color='magenta',linestyle='dashed')
# plt.vlines(T1,0,1,color='magenta',linestyle='dashed')
# --------------------------------------------------------------------
plt.xlabel("T--->")
plt.ylabel("Accuracies--->")
plt.legend()
plt.grid(True)
plt.title(f"G=0.5")
figure_file_name = f"G_0_5_accuracies_vs_T.jpg"
figure_file_path = os.path.join("Generated_plots",figure_file_name)
plt.tight_layout()
plt.savefig(figure_file_path)
